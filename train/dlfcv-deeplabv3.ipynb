# %% [markdown]
# # **Imports**

# %%
# !pip install -q segmentation-models-pytorch torchmetrics transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.5 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.7 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.3 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.

# %%
import json
from pathlib import Path
from tqdm import tqdm

import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset

import segmentation_models_pytorch as smp
from torchmetrics import JaccardIndex, Accuracy, F1Score
from torchmetrics.segmentation import DiceScore
from torchvision import transforms
from torchvision.transforms import InterpolationMode
from torch.amp import GradScaler, autocast

from PIL import Image
import numpy as np

from IPython.display import FileLink

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# # **Setup**

# %% [markdown]
# ## **Dataset**

# %%
# Initial setup
DATA_ROOT = Path("/kaggle/input/data-clean")
IMG_DIR = DATA_ROOT / "images"
MSK_DIR = DATA_ROOT / "masks"

train_img_dir = IMG_DIR / "train"
val_img_dir   = IMG_DIR / "validation"
test_img_dir  = IMG_DIR / "test"

train_msk_dir = MSK_DIR / "train"
val_msk_dir   = MSK_DIR / "validation"
test_msk_dir  = MSK_DIR / "test"

CONFIG = {
    "experiment_name": "deeplabv3plus_resnet50_dacl10k_512",
    "model": "DeepLabV3Plus",
    "encoder": "resnet50",
    "encoder_weights": "imagenet",
    "num_classes": 14,
    "image_size": [512, 512],
    "batch_size": 8,
    "epochs": 40,
    "learning_rate": 1e-4,
    "loss": "CrossEntropyLoss",
    "optimizer": "Adam",
    "scheduler": "ReduceLROnPlateau",
    "metrics": [
        "mean_iou_per_class",
        "dice_macro",
        "f1_macro",
        "global_pixel_accuracy",
    ],
}


NUM_CLASSES = CONFIG["num_classes"]
BATCH_SIZE  = CONFIG["batch_size"]
EPOCHS      = CONFIG["epochs"]
LR          = CONFIG["learning_rate"]
IMAGE_SIZE  = CONFIG["image_size"]

# %%
# Dataset setup
class Dacl10kDataset(Dataset):
    def __init__(self, img_dir, msk_dir, image_size=(512, 512)):
        self.img_dir = Path(img_dir)
        self.msk_dir = Path(msk_dir)
        self.image_size = image_size

        self.img_paths = sorted([p for p in self.img_dir.iterdir()])

        # Transformations for training images
        self.img_transform = transforms.Compose([
            transforms.Resize(self.image_size, interpolation=transforms.InterpolationMode.BILINEAR),
            transforms.ToTensor(),
            transforms.Normalize(  # Normalize each channel with ImageNet normalization values
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
        ])

        self.mask_resize = transforms.Resize(
            self.image_size,
            interpolation=transforms.InterpolationMode.NEAREST, # Change interpolation value to keep integers
        )

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        msk_path = self.msk_dir / img_path.name.replace("jpg", "png") # same filename, jpg -> png

        # Image
        img = Image.open(img_path).convert("RGB")
        img = self.img_transform(img)

        # Mask
        mask = Image.open(msk_path)
        mask = self.mask_resize(mask)
        mask = torch.from_numpy(np.array(mask, dtype=np.int64))

        return img, mask

# %%
# Dataset definition
train_dataset = Dacl10kDataset(train_img_dir, train_msk_dir, IMAGE_SIZE)
val_dataset   = Dacl10kDataset(val_img_dir,   val_msk_dir,   IMAGE_SIZE)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2,
    pin_memory=True,
)

print("Train samples:", len(train_dataset), " | batches:", len(train_loader))
print("Val samples:  ", len(val_dataset),   " | batches:", len(val_loader))
# Out:
# Train samples: 5895  | batches: 737
# Val samples:   1040  | batches: 130

# %% [markdown]
# ## **Model, loss, optimizer, metrics**

# %%
# Model
model = smp.DeepLabV3Plus(
    encoder_name=CONFIG["encoder"],
    encoder_weights=CONFIG["encoder_weights"],
    in_channels=3,
    classes=NUM_CLASSES,
).to(device)

# Loss and optimizer. Scheduler will decrease learning rate by half when val_loss does not improve for 3 epochs
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=3,
    verbose=True,
)

# Metrics
# 1) Mean IoU per class (Jaccard)
miou_metric = JaccardIndex(
    task="multiclass",
    num_classes=NUM_CLASSES,
).to(device)

# 2) Dice score (macro over classes)
dice_metric = DiceScore(
    num_classes=NUM_CLASSES,
    average="macro",
).to(device)

# 3) F1 Score (macro over classes)
f1_metric = F1Score(
    task="multiclass",
    num_classes=NUM_CLASSES,
    average="macro",
).to(device)

# 4) Global Pixel Accuracy
acc_metric = Accuracy(
    task="multiclass",
    num_classes=NUM_CLASSES,
).to(device)

print("DeepLabV3+ params (M):", sum(p.numel() for p in model.parameters()) / 1e6)
# Out:
# config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# DeepLabV3+ params (M): 26.680926

# %% [markdown]
# # **Train**

# %%
scaler = GradScaler(enabled=(device.type == "cuda")) # Uses AMP to speed up training

CHECKPOINT_EVERY = 2  # epochs

def train_one_epoch(model, loader, optimizer, criterion, epoch):
    model.train() # set model to training mode
    running_loss = 0.0 # start total loss at 0.0

    for step, (images, masks) in enumerate(loader, start=1):
        images = images.to(device, non_blocking=True)
        masks  = masks.to(device, non_blocking=True)

        optimizer.zero_grad() # zero the gradients

         # Uses AMP to speed up training
        with autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs = model(images)           
            loss = criterion(outputs, masks)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item() # add losses in each step

        if step % 50 == 0 or step == 1:
            print(f"[Epoch {epoch}] Step {step}/{len(loader)} - Loss: {loss.item():.4f}")

    return running_loss / len(loader) # return mean loss across an epoch


@torch.no_grad()
def evaluate(model, loader, criterion):
    model.eval()
    val_loss = 0.0

    # Reset metrics each evaluation
    miou_metric.reset()
    dice_metric.reset()
    f1_metric.reset()
    acc_metric.reset()

    for images, masks in loader:
        images = images.to(device, non_blocking=True)
        masks  = masks.to(device, non_blocking=True)

        # Uses AMP to speed up training
        with autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs = model(images)
            loss = criterion(outputs, masks)

        val_loss += loss.item()

        preds = torch.argmax(outputs, dim=1)  # Get class index with highest probability

        # Update metrics 
        miou_metric.update(preds, masks)
        dice_metric.update(preds, masks)
        f1_metric.update(preds, masks)
        acc_metric.update(preds, masks)

    val_loss /= len(loader) # compute mean loss

    miou = miou_metric.compute().item() 
    dice = dice_metric.compute().item()   
    mf1  = f1_metric.compute().item()   
    acc  = acc_metric.compute().item() 

    return val_loss, miou, dice, mf1, acc

# %%
history = [] 
best_miou = 0.0

for epoch in range(1, EPOCHS + 1):
    print(f"\n===== Epoch {epoch}/{EPOCHS} =====")

    # Training epoch
    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, epoch)

    # Metrics for train and validation sets
    train_loss_eval, train_miou, train_dice, train_f1, train_acc = evaluate(model, train_loader, criterion)
    val_loss, val_miou, val_dice, val_f1, val_acc = evaluate(model, val_loader, criterion)

    # step scheduler on val_loss
    scheduler.step(val_loss)

    current_lr = optimizer.param_groups[0]["lr"]
    
    print(
        f"Epoch {epoch:03d} | "
        f"TrainLoss(step): {train_loss:.4f} | "
        f"TrainLoss(eval): {train_loss_eval:.4f} | "
        f"ValLoss: {val_loss:.4f} | "
        f"Train mIoU: {train_miou:.4f} | "
        f"Val mIoU: {val_miou:.4f} | "
        f"Val Dice: {val_dice:.4f} | "
        f"Val F1: {val_f1:.4f} | "
        f"Val Acc: {val_acc:.4f} | "
        f"LR: {current_lr:.6f}"
    )

    # Store metrics
    history.append({
        "epoch": epoch,
        # training loss from the actual training loop
        "train_loss_step": float(train_loss),
        # training loss recomputed in eval mode
        "train_loss_eval": float(train_loss_eval),
        "train_miou": float(train_miou),
        "train_dice": float(train_dice),
        "train_f1_macro": float(train_f1),
        "train_global_pixel_accuracy": float(train_acc),
        "val_loss": float(val_loss),
        "val_miou": float(val_miou),
        "val_dice": float(val_dice),
        "val_f1_macro": float(val_f1),
        "val_global_pixel_accuracy": float(val_acc),
        "lr": float(current_lr),
    })

    # save best model by mIoU
    if val_miou > best_miou:
        best_miou = val_miou
        torch.save(model.state_dict(), "deeplab_best_miou.pth")
        print("  -> New best mIoU; weights saved to deeplab_best_miou.pth")

    # periodic full checkpoint save
    if epoch % CHECKPOINT_EVERY == 0:
        ckpt_path = f"deeplab_checkpoint_epoch_{epoch}.pth"
        torch.save({
            "config": CONFIG,
            "epoch": epoch,
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "scheduler_state_dict": scheduler.state_dict(),
            "best_miou": best_miou,
            "history": history,
        }, ckpt_path)
        print(f"  -> Checkpoint saved to {ckpt_path}")

# final "last" checkpoint
torch.save({
    "config": CONFIG,
    "epoch": EPOCHS,
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "scheduler_state_dict": scheduler.state_dict(),
    "best_miou": best_miou,
    "history": history,
}, "deeplab_last.pth")

print("\nTraining complete. Best mIoU:", best_miou)

# Store training logs in JSON format

output_path = Path("/kaggle/working/deeplab_results.json")

results = {
    "config": CONFIG,
    "history": history,
}

with open(output_path, "w") as f:
    json.dump(results, f, indent=2)

print("Saved metrics to:", output_path)

# Download link for results
FileLink('/kaggle/working/deeplab_results.json')
# Out:
# ===== Epoch 1/40 =====
# [Epoch 1] Step 1/737 - Loss: 0.6450
# [Epoch 1] Step 50/737 - Loss: 0.6377
# [Epoch 1] Step 100/737 - Loss: 0.4635
# [Epoch 1] Step 150/737 - Loss: 0.7103
# [Epoch 1] Step 200/737 - Loss: 0.5733
# [Epoch 1] Step 250/737 - Loss: 0.8020
# [Epoch 1] Step 300/737 - Loss: 0.7949
# [Epoch 1] Step 350/737 - Loss: 0.6793
# [Epoch 1] Step 400/737 - Loss: 0.6238
# [Epoch 1] Step 450/737 - Loss: 0.8973
# [Epoch 1] Step 500/737 - Loss: 0.6295
# [Epoch 1] Step 550/737 - Loss: 0.9504
# [Epoch 1] Step 600/737 - Loss: 0.7980
# [Epoch 1] Step 650/737 - Loss: 0.7801
# [Epoch 1] Step 700/737 - Loss: 0.7992
# Epoch 001 | TrainLoss(step): 0.8234 | TrainLoss(eval): 0.7466 | ValLoss: 0.7847 | Train mIoU: 0.1897 | Val mIoU: 0.1705 | Val Dice: 1.6069 | Val F1: 0.2452 | Val Acc: 0.7593 | LR: 0.000100
#   -> New best mIoU; weights saved to deeplab_best_miou.pth
#
# ===== Epoch 2/40 =====
# [Epoch 2] Step 1/737 - Loss: 0.7732
# [Epoch 2] Step 50/737 - Loss: 0.6691
# [Epoch 2] Step 100/737 - Loss: 0.5755
# [Epoch 2] Step 150/737 - Loss: 0.4297
# [Epoch 2] Step 200/737 - Loss: 0.5712
# [Epoch 2] Step 250/737 - Loss: 0.9323
# [Epoch 2] Step 300/737 - Loss: 1.1534
# [Epoch 2] Step 350/737 - Loss: 1.5954
# [Epoch 2] Step 400/737 - Loss: 0.5299
# [Epoch 2] Step 450/737 - Loss: 0.4776
# [Epoch 2] Step 500/737 - Loss: 0.4687
# [Epoch 2] Step 550/737 - Loss: 0.8939
# [Epoch 2] Step 600/737 - Loss: 0.6620
# [Epoch 2] Step 650/737 - Loss: 0.9375
# [Epoch 2] Step 700/737 - Loss: 0.9163
# Epoch 002 | TrainLoss(step): 0.7406 | TrainLoss(eval): 0.6937 | ValLoss: 0.7676 | Train mIoU: 0.2150 | Val mIoU: 0.1926 | Val Dice: 1.8166 | Val F1: 0.2812 | Val Acc: 0.7647 | LR: 0.000100
#   -> New best mIoU; weights saved to deeplab_best_miou.pth
#   -> Checkpoint saved to deeplab_checkpoint_epoch_2.pth
#
# ===== Epoch 3/40 =====
# [Epoch 3] Step 1/737 - Loss: 0.8354
# [Epoch 3] Step 50/737 - Loss: 0.6692
# [Epoch 3] Step 100/737 - Loss: 0.7762
# [Epoch 3] Step 150/737 - Loss: 0.5313
# [Epoch 3] Step 200/737 - Loss: 0.7068
# [Epoch 3] Step 250/737 - Loss: 0.5859
# [Epoch 3] Step 300/737 - Loss: 0.7629
# [Epoch 3] Step 350/737 - Loss: 0.5641
# [Epoch 3] Step 400/737 - Loss: 0.6370
# [Epoch 3] Step 450/737 - Loss: 0.6944
# [Epoch 3] Step 500/737 - Loss: 0.4757
# [Epoch 3] Step 550/737 - Loss: 0.7306
# [Epoch 3] Step 600/737 - Loss: 0.5288
# [Epoch 3] Step 650/737 - Loss: 0.7118
# [Epoch 3] Step 700/737 - Loss: 0.8582
# Epoch 003 | TrainLoss(step): 0.6852 | TrainLoss(eval): 0.6039 | ValLoss: 0.7168 | Train mIoU: 0.2530 | Val mIoU: 0.2040 | Val Dice: 1.6481 | Val F1: 0.2911 | Val Acc: 0.7790 | LR: 0.000100
#   -> New best mIoU; weights saved to deeplab_best_miou.pth
#
# ===== Epoch 4/40 =====
# [Epoch 4] Step 1/737 - Loss: 0.5153
# [Epoch 4] Step 50/737 - Loss: 0.5151
# [Epoch 4] Step 100/737 - Loss: 0.4269
# [Epoch 4] Step 150/737 - Loss: 0.5464
# [Epoch 4] Step 200/737 - Loss: 0.5045
# [Epoch 4] Step 250/737 - Loss: 0.4770
# [Epoch 4] Step 300/737 - Loss: 0.6216
# [Epoch 4] Step 350/737 - Loss: 0.9068
# [Epoch 4] Step 400/737 - Loss: 0.8044
# [Epoch 4] Step 450/737 - Loss: 0.5886
# [Epoch 4] Step 500/737 - Loss: 0.4358
# [Epoch 4] Step 550/737 - Loss: 0.5843
# [Epoch 4] Step 600/737 - Loss: 0.8004
# [Epoch 4] Step 650/737 - Loss: 0.6291
# [Epoch 4] Step 700/737 - Loss: 0.4532
# Epoch 004 | TrainLoss(step): 0.6416 | TrainLoss(eval): 0.5387 | ValLoss: 0.6827 | Train mIoU: 0.3122 | Val mIoU: 0.2484 | Val Dice: 2.0188 | Val F1: 0.3578 | Val Acc: 0.7885 | LR: 0.000100
#   -> New best mIoU; weights saved to deeplab_best_miou.pth
#   -> Checkpoint saved to deeplab_checkpoint_epoch_4.pth
#
# ===== Epoch 5/40 =====
# [Epoch 5] Step 1/737 - Loss: 0.6253
# [Epoch 5] Step 50/737 - Loss: 0.3361
# [Epoch 5] Step 100/737 - Loss: 0.4235
# [Epoch 5] Step 150/737 - Loss: 0.5908
# [Epoch 5] Step 200/737 - Loss: 0.4959
# [Epoch 5] Step 250/737 - Loss: 0.4591
# [Epoch 5] Step 300/737 - Loss: 0.7225
# [Epoch 5] Step 350/737 - Loss: 0.5707
# [Epoch 5] Step 400/737 - Loss: 0.5917
# [Epoch 5] Step 450/737 - Loss: 0.3387
# [Epoch 5] Step 500/737 - Loss: 0.7380
# [Epoch 5] Step 550/737 - Loss: 0.9732
# [Epoch 5] Step 600/737 - Loss: 0.3820
# [Epoch 5] Step 650/737 - Loss: 0.5261
# [Epoch 5] Step 700/737 - Loss: 0.6293
# Epoch 005 | TrainLoss(step): 0.5944 | TrainLoss(eval): 0.5480 | ValLoss: 0.7674 | Train mIoU: 0.3168 | Val mIoU: 0.2363 | Val Dice: 2.2740 | Val F1: 0.3424 | Val Acc: 0.7574 | LR: 0.000100
#
# ===== Epoch 6/40 =====
# [Epoch 6] Step 1/737 - Loss: 0.5385
# [Epoch 6] Step 50/737 - Loss: 0.5922
# [Epoch 6] Step 100/737 - Loss: 0.7169
# [Epoch 6] Step 150/737 - Loss: 0.5859
# [Epoch 6] Step 200/737 - Loss: 0.8009
# [Epoch 6] Step 250/737 - Loss: 1.1750
# [Epoch 6] Step 300/737 - Loss: 1.3018
# [Epoch 6] Step 350/737 - Loss: 0.5277
# [Epoch 6] Step 400/737 - Loss: 0.3470
# [Epoch 6] Step 450/737 - Loss: 0.4981
# [Epoch 6] Step 500/737 - Loss: 0.7202
# [Epoch 6] Step 550/737 - Loss: 0.7427
# [Epoch 6] Step 600/737 - Loss: 0.4076
# [Epoch 6] Step 650/737 - Loss: 0.6313
# [Epoch 6] Step 700/737 - Loss: 0.8687
# Epoch 006 | TrainLoss(step): 0.5534 | TrainLoss(eval): 0.4849 | ValLoss: 0.7189 | Train mIoU: 0.3506 | Val mIoU: 0.2506 | Val Dice: 1.9910 | Val F1: 0.3597 | Val Acc: 0.7871 | LR: 0.000100
#   -> New best mIoU; weights saved to deeplab_best_miou.pth
#   -> Checkpoint saved to deeplab_checkpoint_epoch_6.pth
#
# ===== Epoch 7/40 =====
# [Epoch 7] Step 1/737 - Loss: 0.3573
# [Epoch 7] Step 50/737 - Loss: 0.6370
# [Epoch 7] Step 100/737 - Loss: 0.4256
# [Epoch 7] Step 150/737 - Loss: 0.4855
# [Epoch 7] Step 200/737 - Loss: 0.8167
# [Epoch 7] Step 250/737 - Loss: 0.9016
# [Epoch 7] Step 300/737 - Loss: 0.4102
# [Epoch 7] Step 350/737 - Loss: 0.5522
# [Epoch 7] Step 400/737 - Loss: 0.5887
# [Epoch 7] Step 450/737 - Loss: 0.7163
# [Epoch 7] Step 500/737 - Loss: 0.3359
# [Epoch 7] Step 550/737 - Loss: 0.5954
# [Epoch 7] Step 600/737 - Loss: 0.3485
# [Epoch 7] Step 650/737 - Loss: 0.4241
# [Epoch 7] Step 700/737 - Loss: 0.3841
# Epoch 007 | TrainLoss(step): 0.5047 | TrainLoss(eval): 0.4384 | ValLoss: 0.7429 | Train mIoU: 0.3955 | Val mIoU: 0.2481 | Val Dice: 2.3446 | Val F1: 0.3614 | Val Acc: 0.7734 | LR: 0.000100
#
# ===== Epoch 8/40 =====
# [Epoch 8] Step 1/737 - Loss: 1.2085
# [Epoch 8] Step 50/737 - Loss: 0.3461
# [Epoch 8] Step 100/737 - Loss: 0.3473
# [Epoch 8] Step 150/737 - Loss: 0.3694
# [Epoch 8] Step 200/737 - Loss: 0.3732
# [Epoch 8] Step 250/737 - Loss: 0.4818
# [Epoch 8] Step 300/737 - Loss: 0.4710
# [Epoch 8] Step 350/737 - Loss: 0.2668
# [Epoch 8] Step 400/737 - Loss: 0.3553
# [Epoch 8] Step 450/737 - Loss: 0.3127
# [Epoch 8] Step 500/737 - Loss: 0.5800
# [Epoch 8] Step 550/737 - Loss: 0.4526
# [Epoch 8] Step 600/737 - Loss: 0.2972
# [Epoch 8] Step 650/737 - Loss: 0.4280
# [Epoch 8] Step 700/737 - Loss: 0.3449
# Epoch 008 | TrainLoss(step): 0.4684 | TrainLoss(eval): 0.3771 | ValLoss: 0.7028 | Train mIoU: 0.4166 | Val mIoU: 0.2605 | Val Dice: 2.2953 | Val F1: 0.3691 | Val Acc: 0.7921 | LR: 0.000050
#   -> New best mIoU; weights saved to deeplab_best_miou.pth
#   -> Checkpoint saved to deeplab_checkpoint_epoch_8.pth
#
# ===== Epoch 9/40 =====
# [Epoch 9] Step 1/737 - Loss: 0.3771
# [Epoch 9] Step 50/737 - Loss: 0.7571
# [Epoch 9] Step 100/737 - Loss: 0.6104
# [Epoch 9] Step 150/737 - Loss: 0.8746
# [Epoch 9] Step 200/737 - Loss: 0.5632
# [Epoch 9] Step 250/737 - Loss: 0.1976
# [Epoch 9] Step 300/737 - Loss: 0.3045
# [Epoch 9] Step 350/737 - Loss: 0.6013
# [Epoch 9] Step 400/737 - Loss: 0.2867
# [Epoch 9] Step 450/737 - Loss: 0.3623
# [Epoch 9] Step 500/737 - Loss: 0.4047
# [Epoch 9] Step 550/737 - Loss: 0.4764
# [Epoch 9] Step 600/737 - Loss: 0.2086
# [Epoch 9] Step 650/737 - Loss: 0.2034
# [Epoch 9] Step 700/737 - Loss: 0.3014
# Epoch 009 | TrainLoss(step): 0.3841 | TrainLoss(eval): 0.2891 | ValLoss: 0.7015 | Train mIoU: 0.5183 | Val mIoU: 0.2928 | Val Dice: 2.5879 | Val F1: 0.4165 | Val Acc: 0.7952 | LR: 0.000050
#   -> New best mIoU; weights saved to deeplab_best_miou.pth
#
# ===== Epoch 10/40 =====
# [Epoch 10] Step 1/737 - Loss: 0.2619
# [Epoch 10] Step 50/737 - Loss: 0.2963
# [Epoch 10] Step 100/737 - Loss: 0.3046
# [Epoch 10] Step 150/737 - Loss: 0.2995
# [Epoch 10] Step 200/737 - Loss: 0.3466
# [Epoch 10] Step 250/737 - Loss: 0.3431
# [Epoch 10] Step 300/737 - Loss: 0.5161
# [Epoch 10] Step 350/737 - Loss: 0.3836
# [Epoch 10] Step 400/737 - Loss: 0.1949
# [Epoch 10] Step 450/737 - Loss: 0.2636
# [Epoch 10] Step 500/737 - Loss: 0.2873
# [Epoch 10] Step 550/737 - Loss: 0.2823
# [Epoch 10] Step 600/737 - Loss: 0.4051
# [Epoch 10] Step 650/737 - Loss: 0.2374
# [Epoch 10] Step 700/737 - Loss: 0.2460
# Epoch 010 | TrainLoss(step): 0.3351 | TrainLoss(eval): 0.2612 | ValLoss: 0.7305 | Train mIoU: 0.5450 | Val mIoU: 0.2906 | Val Dice: 2.5695 | Val F1: 0.4165 | Val Acc: 0.7925 | LR: 0.000050
#   -> Checkpoint saved to deeplab_checkpoint_epoch_10.pth
#
# ===== Epoch 11/40 =====
# [Epoch 11] Step 1/737 - Loss: 0.2881
# [Epoch 11] Step 50/737 - Loss: 0.2238
# [Epoch 11] Step 100/737 - Loss: 0.2304
# [Epoch 11] Step 150/737 - Loss: 0.3682
# [Epoch 11] Step 200/737 - Loss: 0.3144
# [Epoch 11] Step 250/737 - Loss: 0.1543
# [Epoch 11] Step 300/737 - Loss: 0.2015
# [Epoch 11] Step 350/737 - Loss: 0.3362
# [Epoch 11] Step 400/737 - Loss: 0.1891
# [Epoch 11] Step 450/737 - Loss: 0.3799
# [Epoch 11] Step 500/737 - Loss: 0.4038
# [Epoch 11] Step 550/737 - Loss: 0.3649
# [Epoch 11] Step 600/737 - Loss: 0.3382
# [Epoch 11] Step 650/737 - Loss: 0.3067
# [Epoch 11] Step 700/737 - Loss: 0.1810
# Epoch 011 | TrainLoss(step): 0.3067 | TrainLoss(eval): 0.2335 | ValLoss: 0.7330 | Train mIoU: 0.5766 | Val mIoU: 0.3041 | Val Dice: 2.5731 | Val F1: 0.4375 | Val Acc: 0.7948 | LR: 0.000050
#   -> New best mIoU; weights saved to deeplab_best_miou.pth
#
# ===== Epoch 12/40 =====
# [Epoch 12] Step 1/737 - Loss: 0.1997
# [Epoch 12] Step 50/737 - Loss: 0.2119
# [Epoch 12] Step 100/737 - Loss: 0.1775
# [Epoch 12] Step 150/737 - Loss: 0.1686
# [Epoch 12] Step 200/737 - Loss: 0.3194
# [Epoch 12] Step 250/737 - Loss: 0.2367
# [Epoch 12] Step 300/737 - Loss: 0.2651
# [Epoch 12] Step 350/737 - Loss: 0.5126
# [Epoch 12] Step 400/737 - Loss: 0.1347
# [Epoch 12] Step 450/737 - Loss: 0.1673
# [Epoch 12] Step 500/737 - Loss: 0.1823
# [Epoch 12] Step 550/737 - Loss: 0.2271
# [Epoch 12] Step 600/737 - Loss: 0.2670
# [Epoch 12] Step 650/737 - Loss: 0.5076
# [Epoch 12] Step 700/737 - Loss: 0.2548
# Epoch 012 | TrainLoss(step): 0.2777 | TrainLoss(eval): 0.2184 | ValLoss: 0.7394 | Train mIoU: 0.5966 | Val mIoU: 0.3038 | Val Dice: 2.8321 | Val F1: 0.4344 | Val Acc: 0.7895 | LR: 0.000025
#   -> Checkpoint saved to deeplab_checkpoint_epoch_12.pth
#
# ===== Epoch 13/40 =====
# [Epoch 13] Step 1/737 - Loss: 0.2283
# [Epoch 13] Step 50/737 - Loss: 0.2721
# [Epoch 13] Step 100/737 - Loss: 0.1195
# [Epoch 13] Step 150/737 - Loss: 0.1874
# [Epoch 13] Step 200/737 - Loss: 0.2340
# [Epoch 13] Step 250/737 - Loss: 0.2075
# [Epoch 13] Step 300/737 - Loss: 0.2013
# [Epoch 13] Step 350/737 - Loss: 0.1724
# [Epoch 13] Step 400/737 - Loss: 0.1305
# [Epoch 13] Step 450/737 - Loss: 0.2761
# [Epoch 13] Step 500/737 - Loss: 0.2241
# [Epoch 13] Step 550/737 - Loss: 0.2646
# [Epoch 13] Step 600/737 - Loss: 0.2155
# [Epoch 13] Step 650/737 - Loss: 0.3022
# [Epoch 13] Step 700/737 - Loss: 0.3198
# Epoch 013 | TrainLoss(step): 0.2394 | TrainLoss(eval): 0.1898 | ValLoss: 0.7433 | Train mIoU: 0.6244 | Val mIoU: 0.3070 | Val Dice: 2.7265 | Val F1: 0.4402 | Val Acc: 0.7939 | LR: 0.000025
#   -> New best mIoU; weights saved to deeplab_best_miou.pth
#
# ===== Epoch 14/40 =====
# [Epoch 14] Step 1/737 - Loss: 0.1502
# [Epoch 14] Step 50/737 - Loss: 0.2461
# [Epoch 14] Step 100/737 - Loss: 0.3476
# [Epoch 14] Step 150/737 - Loss: 0.2424
# [Epoch 14] Step 200/737 - Loss: 0.3256
# [Epoch 14] Step 250/737 - Loss: 0.1399
# [Epoch 14] Step 300/737 - Loss: 0.1842
# [Epoch 14] Step 350/737 - Loss: 0.2038
# [Epoch 14] Step 400/737 - Loss: 0.1547
# [Epoch 14] Step 450/737 - Loss: 0.1873
# [Epoch 14] Step 500/737 - Loss: 0.1966
# [Epoch 14] Step 550/737 - Loss: 0.1962
# [Epoch 14] Step 600/737 - Loss: 0.2511
# [Epoch 14] Step 650/737 - Loss: 0.1820
# [Epoch 14] Step 700/737 - Loss: 0.2399
# Epoch 014 | TrainLoss(step): 0.2200 | TrainLoss(eval): 0.1736 | ValLoss: 0.7742 | Train mIoU: 0.6470 | Val mIoU: 0.3056 | Val Dice: 2.6461 | Val F1: 0.4381 | Val Acc: 0.7961 | LR: 0.000025
#   -> Checkpoint saved to deeplab_checkpoint_epoch_14.pth
#
# ===== Epoch 15/40 =====
# [Epoch 15] Step 1/737 - Loss: 0.2391
# [Epoch 15] Step 50/737 - Loss: 0.2219
# [Epoch 15] Step 100/737 - Loss: 0.1290
# [Epoch 15] Step 150/737 - Loss: 0.1445
# [Epoch 15] Step 200/737 - Loss: 0.2221
# [Epoch 15] Step 250/737 - Loss: 0.1244
# [Epoch 15] Step 300/737 - Loss: 0.1256
# [Epoch 15] Step 350/737 - Loss: 0.1718
# [Epoch 15] Step 400/737 - Loss: 0.3908
# [Epoch 15] Step 450/737 - Loss: 0.1838
# [Epoch 15] Step 500/737 - Loss: 0.2237
# [Epoch 15] Step 550/737 - Loss: 0.3383
# [Epoch 15] Step 600/737 - Loss: 0.1618
# [Epoch 15] Step 650/737 - Loss: 0.1626
# [Epoch 15] Step 700/737 - Loss: 0.1524
# Epoch 015 | TrainLoss(step): 0.2026 | TrainLoss(eval): 0.1678 | ValLoss: 0.7736 | Train mIoU: 0.6578 | Val mIoU: 0.3129 | Val Dice: 2.7599 | Val F1: 0.4492 | Val Acc: 0.7921 | LR: 0.000025
#   -> New best mIoU; weights saved to deeplab_best_miou.pth
#
# ===== Epoch 16/40 =====
# [Epoch 16] Step 1/737 - Loss: 0.1562
# [Epoch 16] Step 50/737 - Loss: 0.2020
# [Epoch 16] Step 100/737 - Loss: 0.1491
# [Epoch 16] Step 150/737 - Loss: 0.1777
# [Epoch 16] Step 200/737 - Loss: 0.1911
# [Epoch 16] Step 250/737 - Loss: 0.2595
# [Epoch 16] Step 300/737 - Loss: 0.1099
# [Epoch 16] Step 350/737 - Loss: 0.0802
# [Epoch 16] Step 400/737 - Loss: 0.1457
# [Epoch 16] Step 450/737 - Loss: 0.3026
# [Epoch 16] Step 500/737 - Loss: 0.0737
# [Epoch 16] Step 550/737 - Loss: 0.2236
# [Epoch 16] Step 600/737 - Loss: 0.2324
# [Epoch 16] Step 650/737 - Loss: 0.2219
# [Epoch 16] Step 700/737 - Loss: 0.1889
# Epoch 016 | TrainLoss(step): 0.1908 | TrainLoss(eval): 0.1553 | ValLoss: 0.8118 | Train mIoU: 0.6675 | Val mIoU: 0.3048 | Val Dice: 2.5943 | Val F1: 0.4378 | Val Acc: 0.7953 | LR: 0.000013
#   -> Checkpoint saved to deeplab_checkpoint_epoch_16.pth
#
# ===== Epoch 17/40 =====
# [Epoch 17] Step 1/737 - Loss: 0.1853
# [Epoch 17] Step 50/737 - Loss: 0.1716
# [Epoch 17] Step 100/737 - Loss: 0.1619
# [Epoch 17] Step 150/737 - Loss: 0.1460
# [Epoch 17] Step 200/737 - Loss: 0.1873
# [Epoch 17] Step 250/737 - Loss: 0.1764
# [Epoch 17] Step 300/737 - Loss: 0.1238
# [Epoch 17] Step 350/737 - Loss: 0.1791
# [Epoch 17] Step 400/737 - Loss: 0.1434
# [Epoch 17] Step 450/737 - Loss: 0.2133
# [Epoch 17] Step 500/737 - Loss: 0.1908
# [Epoch 17] Step 550/737 - Loss: 0.1407
# [Epoch 17] Step 600/737 - Loss: 0.0817
# [Epoch 17] Step 650/737 - Loss: 0.2223
# [Epoch 17] Step 700/737 - Loss: 0.1988
# Epoch 017 | TrainLoss(step): 0.1758 | TrainLoss(eval): 0.1431 | ValLoss: 0.8454 | Train mIoU: 0.6878 | Val mIoU: 0.3009 | Val Dice: 2.5649 | Val F1: 0.4319 | Val Acc: 0.7982 | LR: 0.000013
#
# ===== Epoch 18/40 =====
# [Epoch 18] Step 1/737 - Loss: 0.1416
# [Epoch 18] Step 50/737 - Loss: 0.1563
# [Epoch 18] Step 100/737 - Loss: 0.1817
# [Epoch 18] Step 150/737 - Loss: 0.0873
# [Epoch 18] Step 200/737 - Loss: 0.1752
# [Epoch 18] Step 250/737 - Loss: 0.1839
# [Epoch 18] Step 300/737 - Loss: 0.1164
# [Epoch 18] Step 350/737 - Loss: 0.1976
# [Epoch 18] Step 400/737 - Loss: 0.1262
# [Epoch 18] Step 450/737 - Loss: 0.1008
# [Epoch 18] Step 500/737 - Loss: 0.1796
# [Epoch 18] Step 550/737 - Loss: 0.1490
# [Epoch 18] Step 600/737 - Loss: 0.1089
# [Epoch 18] Step 650/737 - Loss: 0.1837
# [Epoch 18] Step 700/737 - Loss: 0.1408
# Epoch 018 | TrainLoss(step): 0.1655 | TrainLoss(eval): 0.1372 | ValLoss: 0.8312 | Train mIoU: 0.6955 | Val mIoU: 0.3111 | Val Dice: 2.7342 | Val F1: 0.4459 | Val Acc: 0.7944 | LR: 0.000013
#   -> Checkpoint saved to deeplab_checkpoint_epoch_18.pth
#
# ===== Epoch 19/40 =====
# [Epoch 19] Step 1/737 - Loss: 0.0972
# [Epoch 19] Step 50/737 - Loss: 0.1534
# [Epoch 19] Step 100/737 - Loss: 0.1577
# [Epoch 19] Step 150/737 - Loss: 0.1393
# [Epoch 19] Step 200/737 - Loss: 0.1460
# [Epoch 19] Step 250/737 - Loss: 0.1644
# [Epoch 19] Step 300/737 - Loss: 0.0983
# [Epoch 19] Step 350/737 - Loss: 0.1941
# [Epoch 19] Step 400/737 - Loss: 0.1120
# [Epoch 19] Step 450/737 - Loss: 0.1817
# [Epoch 19] Step 500/737 - Loss: 0.1219
# [Epoch 19] Step 550/737 - Loss: 0.1212
# [Epoch 19] Step 600/737 - Loss: 0.1683
# [Epoch 19] Step 650/737 - Loss: 0.1190
# [Epoch 19] Step 700/737 - Loss: 0.1084
# Epoch 019 | TrainLoss(step): 0.1589 | TrainLoss(eval): 0.1313 | ValLoss: 0.8608 | Train mIoU: 0.7016 | Val mIoU: 0.3031 | Val Dice: 2.6216 | Val F1: 0.4357 | Val Acc: 0.7957 | LR: 0.000013
#
# ===== Epoch 20/40 =====
# [Epoch 20] Step 1/737 - Loss: 0.2187
# [Epoch 20] Step 50/737 - Loss: 0.1072
# [Epoch 20] Step 100/737 - Loss: 0.1362
# [Epoch 20] Step 150/737 - Loss: 0.1044
# [Epoch 20] Step 200/737 - Loss: 0.1242
# [Epoch 20] Step 250/737 - Loss: 0.2109
# [Epoch 20] Step 300/737 - Loss: 0.3162
# [Epoch 20] Step 350/737 - Loss: 0.1114
# [Epoch 20] Step 400/737 - Loss: 0.1735
# [Epoch 20] Step 450/737 - Loss: 0.3037
# [Epoch 20] Step 500/737 - Loss: 0.2786
# [Epoch 20] Step 550/737 - Loss: 0.1155
# [Epoch 20] Step 600/737 - Loss: 0.1573
# [Epoch 20] Step 650/737 - Loss: 0.1303
# [Epoch 20] Step 700/737 - Loss: 0.1634
# Epoch 020 | TrainLoss(step): 0.1553 | TrainLoss(eval): 0.1277 | ValLoss: 0.8604 | Train mIoU: 0.7091 | Val mIoU: 0.3037 | Val Dice: 2.6678 | Val F1: 0.4368 | Val Acc: 0.7945 | LR: 0.000006
#   -> Checkpoint saved to deeplab_checkpoint_epoch_20.pth
#
# ===== Epoch 21/40 =====
# [Epoch 21] Step 1/737 - Loss: 0.1143
# [Epoch 21] Step 50/737 - Loss: 0.1551
# [Epoch 21] Step 100/737 - Loss: 0.1705
# [Epoch 21] Step 150/737 - Loss: 0.1081
# [Epoch 21] Step 200/737 - Loss: 0.0776
# [Epoch 21] Step 250/737 - Loss: 0.0601
# [Epoch 21] Step 300/737 - Loss: 0.2455
# [Epoch 21] Step 350/737 - Loss: 0.1380
# [Epoch 21] Step 400/737 - Loss: 0.1031
# [Epoch 21] Step 450/737 - Loss: 0.1193
# [Epoch 21] Step 500/737 - Loss: 0.2513
# [Epoch 21] Step 550/737 - Loss: 0.1391
# [Epoch 21] Step 600/737 - Loss: 0.0973
# [Epoch 21] Step 650/737 - Loss: 0.1938
# [Epoch 21] Step 700/737 - Loss: 0.1530
# Epoch 021 | TrainLoss(step): 0.1476 | TrainLoss(eval): 0.1227 | ValLoss: 0.8499 | Train mIoU: 0.7177 | Val mIoU: 0.3066 | Val Dice: 2.6882 | Val F1: 0.4404 | Val Acc: 0.7927 | LR: 0.000006
#
# ===== Epoch 22/40 =====
# [Epoch 22] Step 1/737 - Loss: 0.1113
# [Epoch 22] Step 50/737 - Loss: 0.0901
# [Epoch 22] Step 100/737 - Loss: 0.1032
# [Epoch 22] Step 150/737 - Loss: 0.1035
# [Epoch 22] Step 200/737 - Loss: 0.1081
# [Epoch 22] Step 250/737 - Loss: 0.1405
# [Epoch 22] Step 300/737 - Loss: 0.0909
# [Epoch 22] Step 350/737 - Loss: 0.1539
# [Epoch 22] Step 400/737 - Loss: 0.1477
# [Epoch 22] Step 450/737 - Loss: 0.2396
# [Epoch 22] Step 500/737 - Loss: 0.1986
# [Epoch 22] Step 550/737 - Loss: 0.1210
# [Epoch 22] Step 600/737 - Loss: 0.1489
# [Epoch 22] Step 650/737 - Loss: 0.2464
# [Epoch 22] Step 700/737 - Loss: 0.1914
# Epoch 022 | TrainLoss(step): 0.1445 | TrainLoss(eval): 0.1200 | ValLoss: 0.8894 | Train mIoU: 0.7208 | Val mIoU: 0.2995 | Val Dice: 2.6450 | Val F1: 0.4305 | Val Acc: 0.7946 | LR: 0.000006
#   -> Checkpoint saved to deeplab_checkpoint_epoch_22.pth
#
# ===== Epoch 23/40 =====
# [Epoch 23] Step 1/737 - Loss: 0.1176
# [Epoch 23] Step 50/737 - Loss: 0.1563
# [Epoch 23] Step 100/737 - Loss: 0.1476
# [Epoch 23] Step 150/737 - Loss: 0.2703
# [Epoch 23] Step 200/737 - Loss: 0.0936
# [Epoch 23] Step 250/737 - Loss: 0.1359
# [Epoch 23] Step 300/737 - Loss: 0.2433
# [Epoch 23] Step 350/737 - Loss: 0.0997
# [Epoch 23] Step 400/737 - Loss: 0.1863
# [Epoch 23] Step 450/737 - Loss: 0.1433
# [Epoch 23] Step 500/737 - Loss: 0.1584
# [Epoch 23] Step 550/737 - Loss: 0.1314
# [Epoch 23] Step 600/737 - Loss: 0.0848
# [Epoch 23] Step 650/737 - Loss: 0.0929
# [Epoch 23] Step 700/737 - Loss: 0.1540
# Epoch 023 | TrainLoss(step): 0.1399 | TrainLoss(eval): 0.1156 | ValLoss: 0.8708 | Train mIoU: 0.7302 | Val mIoU: 0.3105 | Val Dice: 2.6791 | Val F1: 0.4447 | Val Acc: 0.7943 | LR: 0.000006
#
# ===== Epoch 24/40 =====
# [Epoch 24] Step 1/737 - Loss: 0.1250
# [Epoch 24] Step 50/737 - Loss: 0.0868
# [Epoch 24] Step 100/737 - Loss: 0.1038
# [Epoch 24] Step 150/737 - Loss: 0.1223
# [Epoch 24] Step 200/737 - Loss: 0.1759
# [Epoch 24] Step 250/737 - Loss: 0.1559
# [Epoch 24] Step 300/737 - Loss: 0.2197
# [Epoch 24] Step 350/737 - Loss: 0.1241
# [Epoch 24] Step 400/737 - Loss: 0.1215
# [Epoch 24] Step 450/737 - Loss: 0.1449
# [Epoch 24] Step 500/737 - Loss: 0.1418
# [Epoch 24] Step 550/737 - Loss: 0.2775
# [Epoch 24] Step 600/737 - Loss: 0.1345
# [Epoch 24] Step 650/737 - Loss: 0.0630
# [Epoch 24] Step 700/737 - Loss: 0.1212
# Epoch 024 | TrainLoss(step): 0.1377 | TrainLoss(eval): 0.1151 | ValLoss: 0.8964 | Train mIoU: 0.7241 | Val mIoU: 0.2981 | Val Dice: 2.6685 | Val F1: 0.4301 | Val Acc: 0.7922 | LR: 0.000003
#   -> Checkpoint saved to deeplab_checkpoint_epoch_24.pth
#
# ===== Epoch 25/40 =====
# [Epoch 25] Step 1/737 - Loss: 0.1238
# [Epoch 25] Step 50/737 - Loss: 0.1474
# [Epoch 25] Step 100/737 - Loss: 0.2482
# [Epoch 25] Step 150/737 - Loss: 0.1395
# [Epoch 25] Step 200/737 - Loss: 0.1219
# [Epoch 25] Step 250/737 - Loss: 0.1586
# [Epoch 25] Step 300/737 - Loss: 0.2028
# [Epoch 25] Step 350/737 - Loss: 0.1318
# [Epoch 25] Step 400/737 - Loss: 0.1589
# [Epoch 25] Step 450/737 - Loss: 0.1128
# [Epoch 25] Step 500/737 - Loss: 0.1241
# [Epoch 25] Step 550/737 - Loss: 0.1345
# [Epoch 25] Step 600/737 - Loss: 0.1533
# [Epoch 25] Step 650/737 - Loss: 0.0724
# [Epoch 25] Step 700/737 - Loss: 0.1782
# Epoch 025 | TrainLoss(step): 0.1340 | TrainLoss(eval): 0.1117 | ValLoss: 0.8795 | Train mIoU: 0.7342 | Val mIoU: 0.3041 | Val Dice: 2.7049 | Val F1: 0.4375 | Val Acc: 0.7921 | LR: 0.000003
#
# ===== Epoch 26/40 =====
# [Epoch 26] Step 1/737 - Loss: 0.0974
# [Epoch 26] Step 50/737 - Loss: 0.0878
# [Epoch 26] Step 100/737 - Loss: 0.1330
# [Epoch 26] Step 150/737 - Loss: 0.1483
# [Epoch 26] Step 200/737 - Loss: 0.1838
# [Epoch 26] Step 250/737 - Loss: 0.0921
# [Epoch 26] Step 300/737 - Loss: 0.1392
# [Epoch 26] Step 350/737 - Loss: 0.1055
# [Epoch 26] Step 400/737 - Loss: 0.1754
# [Epoch 26] Step 450/737 - Loss: 0.2515
# [Epoch 26] Step 500/737 - Loss: 0.1126
# [Epoch 26] Step 550/737 - Loss: 0.1087
# [Epoch 26] Step 600/737 - Loss: 0.1454
# [Epoch 26] Step 650/737 - Loss: 0.1680
# [Epoch 26] Step 700/737 - Loss: 0.2344
# Epoch 026 | TrainLoss(step): 0.1323 | TrainLoss(eval): 0.1118 | ValLoss: 0.8872 | Train mIoU: 0.7318 | Val mIoU: 0.3021 | Val Dice: 2.6877 | Val F1: 0.4355 | Val Acc: 0.7921 | LR: 0.000003
#   -> Checkpoint saved to deeplab_checkpoint_epoch_26.pth
#
# ===== Epoch 27/40 =====
# [Epoch 27] Step 1/737 - Loss: 0.1631
# [Epoch 27] Step 50/737 - Loss: 0.1759
# [Epoch 27] Step 100/737 - Loss: 0.1192
# [Epoch 27] Step 150/737 - Loss: 0.1399
# [Epoch 27] Step 200/737 - Loss: 0.0355
# [Epoch 27] Step 250/737 - Loss: 0.1062
# [Epoch 27] Step 300/737 - Loss: 0.1010
# [Epoch 27] Step 350/737 - Loss: 0.0813
# [Epoch 27] Step 400/737 - Loss: 0.1275
# [Epoch 27] Step 450/737 - Loss: 0.2112
# [Epoch 27] Step 500/737 - Loss: 0.1253
# [Epoch 27] Step 550/737 - Loss: 0.1911
# [Epoch 27] Step 600/737 - Loss: 0.1687
# [Epoch 27] Step 650/737 - Loss: 0.1550
# [Epoch 27] Step 700/737 - Loss: 0.1920
# Epoch 027 | TrainLoss(step): 0.1313 | TrainLoss(eval): 0.1083 | ValLoss: 0.9015 | Train mIoU: 0.7400 | Val mIoU: 0.3034 | Val Dice: 2.6538 | Val F1: 0.4357 | Val Acc: 0.7944 | LR: 0.000003
#
# ===== Epoch 28/40 =====
# [Epoch 28] Step 1/737 - Loss: 0.1418
# [Epoch 28] Step 50/737 - Loss: 0.1429
# [Epoch 28] Step 100/737 - Loss: 0.0851
# [Epoch 28] Step 150/737 - Loss: 0.0975
# [Epoch 28] Step 200/737 - Loss: 0.0929
# [Epoch 28] Step 250/737 - Loss: 0.1499
# [Epoch 28] Step 300/737 - Loss: 0.1737
# [Epoch 28] Step 350/737 - Loss: 0.0984
# [Epoch 28] Step 400/737 - Loss: 0.1471
# [Epoch 28] Step 450/737 - Loss: 0.1392
# [Epoch 28] Step 500/737 - Loss: 0.1171
# [Epoch 28] Step 550/737 - Loss: 0.1536
# [Epoch 28] Step 600/737 - Loss: 0.1130
# [Epoch 28] Step 650/737 - Loss: 0.1252
# [Epoch 28] Step 700/737 - Loss: 0.1199
# Epoch 028 | TrainLoss(step): 0.1301 | TrainLoss(eval): 0.1088 | ValLoss: 0.9007 | Train mIoU: 0.7345 | Val mIoU: 0.3022 | Val Dice: 2.6524 | Val F1: 0.4348 | Val Acc: 0.7946 | LR: 0.000002
#   -> Checkpoint saved to deeplab_checkpoint_epoch_28.pth
#
# ===== Epoch 29/40 =====
# [Epoch 29] Step 1/737 - Loss: 0.1098
# [Epoch 29] Step 50/737 - Loss: 0.0717
# [Epoch 29] Step 100/737 - Loss: 0.1003
# [Epoch 29] Step 150/737 - Loss: 0.1455
# [Epoch 29] Step 200/737 - Loss: 0.1628
# [Epoch 29] Step 250/737 - Loss: 0.1614
# [Epoch 29] Step 300/737 - Loss: 0.0915
# [Epoch 29] Step 350/737 - Loss: 0.1004
# [Epoch 29] Step 400/737 - Loss: 0.1173
# [Epoch 29] Step 450/737 - Loss: 0.1692
# [Epoch 29] Step 500/737 - Loss: 0.0678
# [Epoch 29] Step 550/737 - Loss: 0.1622
# [Epoch 29] Step 600/737 - Loss: 0.1266
# [Epoch 29] Step 650/737 - Loss: 0.1118
# [Epoch 29] Step 700/737 - Loss: 0.1862
# Epoch 029 | TrainLoss(step): 0.1276 | TrainLoss(eval): 0.1080 | ValLoss: 0.9115 | Train mIoU: 0.7408 | Val mIoU: 0.3041 | Val Dice: 2.6113 | Val F1: 0.4376 | Val Acc: 0.7951 | LR: 0.000002
#
# ===== Epoch 30/40 =====
# [Epoch 30] Step 1/737 - Loss: 0.1339
# [Epoch 30] Step 50/737 - Loss: 0.1339
# [Epoch 30] Step 100/737 - Loss: 0.1140
# [Epoch 30] Step 150/737 - Loss: 0.1089
# [Epoch 30] Step 200/737 - Loss: 0.1021
# [Epoch 30] Step 250/737 - Loss: 0.1602
# [Epoch 30] Step 300/737 - Loss: 0.0821
# [Epoch 30] Step 350/737 - Loss: 0.1321
# [Epoch 30] Step 400/737 - Loss: 0.1135
# [Epoch 30] Step 450/737 - Loss: 0.1294
# [Epoch 30] Step 500/737 - Loss: 0.1559
# [Epoch 30] Step 550/737 - Loss: 0.0886
# [Epoch 30] Step 600/737 - Loss: 0.1292
# [Epoch 30] Step 650/737 - Loss: 0.2161
# [Epoch 30] Step 700/737 - Loss: 0.0922
# Epoch 030 | TrainLoss(step): 0.1258 | TrainLoss(eval): 0.1064 | ValLoss: 0.9003 | Train mIoU: 0.7430 | Val mIoU: 0.3023 | Val Dice: 2.6595 | Val F1: 0.4354 | Val Acc: 0.7943 | LR: 0.000002
#   -> Checkpoint saved to deeplab_checkpoint_epoch_30.pth
#
# ===== Epoch 31/40 =====
# [Epoch 31] Step 1/737 - Loss: 0.1384
# [Epoch 31] Step 50/737 - Loss: 0.2031
# [Epoch 31] Step 100/737 - Loss: 0.1360
# [Epoch 31] Step 150/737 - Loss: 0.1160
# [Epoch 31] Step 200/737 - Loss: 0.1351
# [Epoch 31] Step 250/737 - Loss: 0.1186
# [Epoch 31] Step 300/737 - Loss: 0.1428
# [Epoch 31] Step 350/737 - Loss: 0.0768
# [Epoch 31] Step 400/737 - Loss: 0.1188
# [Epoch 31] Step 450/737 - Loss: 0.0812
# [Epoch 31] Step 500/737 - Loss: 0.2396
# [Epoch 31] Step 550/737 - Loss: 0.1491
# [Epoch 31] Step 600/737 - Loss: 0.1364
# [Epoch 31] Step 650/737 - Loss: 0.0852
# [Epoch 31] Step 700/737 - Loss: 0.1348
# Epoch 031 | TrainLoss(step): 0.1259 | TrainLoss(eval): 0.1072 | ValLoss: 0.9057 | Train mIoU: 0.7423 | Val mIoU: 0.3061 | Val Dice: 2.6757 | Val F1: 0.4411 | Val Acc: 0.7925 | LR: 0.000002
#
# ===== Epoch 32/40 =====
# [Epoch 32] Step 1/737 - Loss: 0.1363
# [Epoch 32] Step 50/737 - Loss: 0.1721
# [Epoch 32] Step 100/737 - Loss: 0.1351
# [Epoch 32] Step 150/737 - Loss: 0.1371
# [Epoch 32] Step 200/737 - Loss: 0.1412
# [Epoch 32] Step 250/737 - Loss: 0.0763
# [Epoch 32] Step 300/737 - Loss: 0.0775
# [Epoch 32] Step 350/737 - Loss: 0.1503
# [Epoch 32] Step 400/737 - Loss: 0.1011
# [Epoch 32] Step 450/737 - Loss: 0.0693
# [Epoch 32] Step 500/737 - Loss: 0.1137
# [Epoch 32] Step 550/737 - Loss: 0.0828
# [Epoch 32] Step 600/737 - Loss: 0.1108
# [Epoch 32] Step 650/737 - Loss: 0.0907
# [Epoch 32] Step 700/737 - Loss: 0.0867
# Epoch 032 | TrainLoss(step): 0.1256 | TrainLoss(eval): 0.1061 | ValLoss: 0.9145 | Train mIoU: 0.7426 | Val mIoU: 0.3009 | Val Dice: 2.6355 | Val F1: 0.4327 | Val Acc: 0.7948 | LR: 0.000001
#   -> Checkpoint saved to deeplab_checkpoint_epoch_32.pth
#
# ===== Epoch 33/40 =====
# [Epoch 33] Step 1/737 - Loss: 0.1485
# [Epoch 33] Step 50/737 - Loss: 0.0624
# [Epoch 33] Step 100/737 - Loss: 0.1188
# [Epoch 33] Step 150/737 - Loss: 0.1221
# [Epoch 33] Step 200/737 - Loss: 0.0833
# [Epoch 33] Step 250/737 - Loss: 0.1305
# [Epoch 33] Step 300/737 - Loss: 0.0711
# [Epoch 33] Step 350/737 - Loss: 0.0500
# [Epoch 33] Step 400/737 - Loss: 0.1320
# [Epoch 33] Step 450/737 - Loss: 0.1707
# [Epoch 33] Step 500/737 - Loss: 0.1801
# [Epoch 33] Step 550/737 - Loss: 0.1637
# [Epoch 33] Step 600/737 - Loss: 0.1333
# [Epoch 33] Step 650/737 - Loss: 0.1033
# [Epoch 33] Step 700/737 - Loss: 0.1160
# Epoch 033 | TrainLoss(step): 0.1247 | TrainLoss(eval): 0.1058 | ValLoss: 0.8981 | Train mIoU: 0.7434 | Val mIoU: 0.3033 | Val Dice: 2.7098 | Val F1: 0.4373 | Val Acc: 0.7907 | LR: 0.000001
#
# ===== Epoch 34/40 =====
# [Epoch 34] Step 1/737 - Loss: 0.1560
# [Epoch 34] Step 50/737 - Loss: 0.1197
# [Epoch 34] Step 100/737 - Loss: 0.1171
# [Epoch 34] Step 150/737 - Loss: 0.1150
# [Epoch 34] Step 200/737 - Loss: 0.1084
# [Epoch 34] Step 250/737 - Loss: 0.1011
# [Epoch 34] Step 300/737 - Loss: 0.0940
# [Epoch 34] Step 350/737 - Loss: 0.1199
# [Epoch 34] Step 400/737 - Loss: 0.1548
# [Epoch 34] Step 450/737 - Loss: 0.2648
# [Epoch 34] Step 500/737 - Loss: 0.0617
# [Epoch 34] Step 550/737 - Loss: 0.1041
# [Epoch 34] Step 600/737 - Loss: 0.1090
# [Epoch 34] Step 650/737 - Loss: 0.0809
# [Epoch 34] Step 700/737 - Loss: 0.1587
# Epoch 034 | TrainLoss(step): 0.1245 | TrainLoss(eval): 0.1050 | ValLoss: 0.9117 | Train mIoU: 0.7429 | Val mIoU: 0.2993 | Val Dice: 2.6680 | Val F1: 0.4314 | Val Acc: 0.7937 | LR: 0.000001
#   -> Checkpoint saved to deeplab_checkpoint_epoch_34.pth
#
# ===== Epoch 35/40 =====
# [Epoch 35] Step 1/737 - Loss: 0.1969
# [Epoch 35] Step 50/737 - Loss: 0.1165
# [Epoch 35] Step 100/737 - Loss: 0.1061
# [Epoch 35] Step 150/737 - Loss: 0.1699
# [Epoch 35] Step 200/737 - Loss: 0.1744
# [Epoch 35] Step 250/737 - Loss: 0.0897
# [Epoch 35] Step 300/737 - Loss: 0.1113
# [Epoch 35] Step 350/737 - Loss: 0.0897
# [Epoch 35] Step 400/737 - Loss: 0.1973
# [Epoch 35] Step 450/737 - Loss: 0.1504
# [Epoch 35] Step 500/737 - Loss: 0.1831
# [Epoch 35] Step 550/737 - Loss: 0.1402
# [Epoch 35] Step 600/737 - Loss: 0.1042
# [Epoch 35] Step 650/737 - Loss: 0.1378
# [Epoch 35] Step 700/737 - Loss: 0.1778
# Epoch 035 | TrainLoss(step): 0.1230 | TrainLoss(eval): 0.1044 | ValLoss: 0.9158 | Train mIoU: 0.7455 | Val mIoU: 0.3058 | Val Dice: 2.6798 | Val F1: 0.4398 | Val Acc: 0.7941 | LR: 0.000001
#
# ===== Epoch 36/40 =====
# [Epoch 36] Step 1/737 - Loss: 0.0849
# [Epoch 36] Step 50/737 - Loss: 0.1301
# [Epoch 36] Step 100/737 - Loss: 0.1465
# [Epoch 36] Step 150/737 - Loss: 0.1499
# [Epoch 36] Step 200/737 - Loss: 0.1394
# [Epoch 36] Step 250/737 - Loss: 0.0951
# [Epoch 36] Step 300/737 - Loss: 0.0723
# [Epoch 36] Step 350/737 - Loss: 0.1285
# [Epoch 36] Step 400/737 - Loss: 0.1385
# [Epoch 36] Step 450/737 - Loss: 0.0966
# [Epoch 36] Step 500/737 - Loss: 0.1458
# [Epoch 36] Step 550/737 - Loss: 0.1143
# [Epoch 36] Step 600/737 - Loss: 0.1108
# [Epoch 36] Step 650/737 - Loss: 0.1311
# [Epoch 36] Step 700/737 - Loss: 0.0730
# Epoch 036 | TrainLoss(step): 0.1231 | TrainLoss(eval): 0.1043 | ValLoss: 0.9112 | Train mIoU: 0.7456 | Val mIoU: 0.3026 | Val Dice: 2.6458 | Val F1: 0.4350 | Val Acc: 0.7958 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_36.pth
#
# ===== Epoch 37/40 =====
# [Epoch 37] Step 1/737 - Loss: 0.1247
# [Epoch 37] Step 50/737 - Loss: 0.1439
# [Epoch 37] Step 100/737 - Loss: 0.1019
# [Epoch 37] Step 150/737 - Loss: 0.0997
# [Epoch 37] Step 200/737 - Loss: 0.1220
# [Epoch 37] Step 250/737 - Loss: 0.0688
# [Epoch 37] Step 300/737 - Loss: 0.1386
# [Epoch 37] Step 350/737 - Loss: 0.1758
# [Epoch 37] Step 400/737 - Loss: 0.0885
# [Epoch 37] Step 450/737 - Loss: 0.0774
# [Epoch 37] Step 500/737 - Loss: 0.1230
# [Epoch 37] Step 550/737 - Loss: 0.0731
# [Epoch 37] Step 600/737 - Loss: 0.0950
# [Epoch 37] Step 650/737 - Loss: 0.1367
# [Epoch 37] Step 700/737 - Loss: 0.0963
# Epoch 037 | TrainLoss(step): 0.1233 | TrainLoss(eval): 0.1032 | ValLoss: 0.9037 | Train mIoU: 0.7497 | Val mIoU: 0.3012 | Val Dice: 2.6900 | Val F1: 0.4333 | Val Acc: 0.7916 | LR: 0.000000
#
# ===== Epoch 38/40 =====
# [Epoch 38] Step 1/737 - Loss: 0.1096
# [Epoch 38] Step 50/737 - Loss: 0.1196
# [Epoch 38] Step 100/737 - Loss: 0.1014
# [Epoch 38] Step 150/737 - Loss: 0.0806
# [Epoch 38] Step 200/737 - Loss: 0.1343
# [Epoch 38] Step 250/737 - Loss: 0.0833
# [Epoch 38] Step 300/737 - Loss: 0.0481
# [Epoch 38] Step 350/737 - Loss: 0.1236
# [Epoch 38] Step 400/737 - Loss: 0.1404
# [Epoch 38] Step 450/737 - Loss: 0.1182
# [Epoch 38] Step 500/737 - Loss: 0.0743
# [Epoch 38] Step 550/737 - Loss: 0.1439
# [Epoch 38] Step 600/737 - Loss: 0.1495
# [Epoch 38] Step 650/737 - Loss: 0.1185
# [Epoch 38] Step 700/737 - Loss: 0.0750
# Epoch 038 | TrainLoss(step): 0.1229 | TrainLoss(eval): 0.1046 | ValLoss: 0.9033 | Train mIoU: 0.7461 | Val mIoU: 0.3061 | Val Dice: 2.6939 | Val F1: 0.4406 | Val Acc: 0.7922 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_38.pth
#
# ===== Epoch 39/40 =====
# [Epoch 39] Step 1/737 - Loss: 0.1089
# [Epoch 39] Step 50/737 - Loss: 0.1111
# [Epoch 39] Step 100/737 - Loss: 0.1747
# [Epoch 39] Step 150/737 - Loss: 0.1330
# [Epoch 39] Step 200/737 - Loss: 0.0892
# [Epoch 39] Step 250/737 - Loss: 0.1277
# [Epoch 39] Step 300/737 - Loss: 0.0957
# [Epoch 39] Step 350/737 - Loss: 0.1083
# [Epoch 39] Step 400/737 - Loss: 0.1255
# [Epoch 39] Step 450/737 - Loss: 0.1619
# [Epoch 39] Step 500/737 - Loss: 0.1309
# [Epoch 39] Step 550/737 - Loss: 0.1109
# [Epoch 39] Step 600/737 - Loss: 0.1201
# [Epoch 39] Step 650/737 - Loss: 0.1221
# [Epoch 39] Step 700/737 - Loss: 0.1148
# Epoch 039 | TrainLoss(step): 0.1226 | TrainLoss(eval): 0.1034 | ValLoss: 0.8961 | Train mIoU: 0.7490 | Val mIoU: 0.3066 | Val Dice: 2.6820 | Val F1: 0.4409 | Val Acc: 0.7924 | LR: 0.000000
#
# ===== Epoch 40/40 =====
# [Epoch 40] Step 1/737 - Loss: 0.1000
# [Epoch 40] Step 50/737 - Loss: 0.1196
# [Epoch 40] Step 100/737 - Loss: 0.1069
# [Epoch 40] Step 150/737 - Loss: 0.1780
# [Epoch 40] Step 200/737 - Loss: 0.0908
# [Epoch 40] Step 250/737 - Loss: 0.0749
# [Epoch 40] Step 300/737 - Loss: 0.1011
# [Epoch 40] Step 350/737 - Loss: 0.1481
# [Epoch 40] Step 400/737 - Loss: 0.1190
# [Epoch 40] Step 450/737 - Loss: 0.1190
# [Epoch 40] Step 500/737 - Loss: 0.1117
# [Epoch 40] Step 550/737 - Loss: 0.1463
# [Epoch 40] Step 600/737 - Loss: 0.1105
# [Epoch 40] Step 650/737 - Loss: 0.3725
# [Epoch 40] Step 700/737 - Loss: 0.1029
# Epoch 040 | TrainLoss(step): 0.1235 | TrainLoss(eval): 0.1035 | ValLoss: 0.9046 | Train mIoU: 0.7465 | Val mIoU: 0.3039 | Val Dice: 2.7074 | Val F1: 0.4370 | Val Acc: 0.7906 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_40.pth
#
# Training complete. Best mIoU: 0.3128804564476013
# Saved metrics to: /kaggle/working/deeplab_results.json
# /kaggle/working/deeplab_results.json

# %% [markdown]
# # **Resume training with weighted CE loss**

# %%
# Load checkpoint
CKPT_PATH = "/kaggle/input/deeplab-last/deeplab_last.pth"

ckpt = torch.load(CKPT_PATH, map_location=device)

print("Checkpoint keys:", ckpt.keys())
print("Last epoch:", ckpt["epoch"])
print("Best mIoU so far:", ckpt["best_miou"])
# Out:
# Checkpoint keys: dict_keys(['config', 'epoch', 'model_state_dict', 'optimizer_state_dict', 'scheduler_state_dict', 'best_miou', 'history'])
# Last epoch: 40
# Best mIoU so far: 0.3128804564476013

# %%
# Define model, optimizer and metrics in the same way as in previous training
# Model
model = smp.DeepLabV3Plus(
    encoder_name=CONFIG["encoder"],
    encoder_weights=CONFIG["encoder_weights"],
    in_channels=3,
    classes=NUM_CLASSES,
).to(device)

model.load_state_dict(ckpt["model_state_dict"])

# Optimizer and scheduler
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=CONFIG["learning_rate"],
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=3,
    verbose=True,
)

optimizer.load_state_dict(ckpt["optimizer_state_dict"])
scheduler.load_state_dict(ckpt["scheduler_state_dict"])

best_miou = ckpt["best_miou"]
history   = ckpt["history"]    
start_epoch = ckpt["epoch"] + 1
print("Resuming from epoch", start_epoch)

# Metrics
# 1) Mean IoU per class (Jaccard)
miou_metric = JaccardIndex(
    task="multiclass",
    num_classes=NUM_CLASSES,
).to(device)

# 2) Dice score (macro over classes)
dice_metric = DiceScore(
    num_classes=NUM_CLASSES,
    average="macro",
).to(device)

# 3) F1 Score (macro over classes)
f1_metric = F1Score(
    task="multiclass",
    num_classes=NUM_CLASSES,
    average="macro",
).to(device)

# 4) Global Pixel Accuracy
acc_metric = Accuracy(
    task="multiclass",
    num_classes=NUM_CLASSES,
).to(device)
# Out:
# Resuming from epoch 41

# %%
# Compute class imbalance (pixel-wise) to define class weights
class_counts = torch.zeros(NUM_CLASSES, dtype=torch.long)

# Set model to evaluation
model.eval()

with torch.no_grad():
    for _, masks in tqdm(train_loader, desc="Computing class frequencies"):
        # masks: [B, H, W]
        masks = masks.view(-1)  # flatten
        values, freqs = torch.unique(masks, return_counts=True)
        class_counts[values] += freqs # accumulate pixel count per class

print("Class counts:", class_counts.tolist())

# Avoid division by zero
freq = class_counts.float() / class_counts.sum()
inv_freq = 1.0 / (freq + 1e-6)

# Normalize so average weight ~ 1
class_weights = inv_freq * (NUM_CLASSES / inv_freq.sum())

print("Class weights:", class_weights.tolist())
# Out:
# Computing class frequencies: 100%|██████████| 737/737 [04:03<00:00,  3.03it/s]
# Class counts: [1148926007, 5129526, 2217252, 37482497, 30849929, 19727449, 4548455, 34674896, 24742215, 10756736, 32937080, 161365569, 3466853, 28514416]
# Class weights: [0.008133492432534695, 1.8212167024612427, 4.2116475105285645, 0.24930056929588318, 0.3028961420059204, 0.47365784645080566, 2.053800582885742, 0.26948535442352295, 0.3776625692844391, 0.8686138987541199, 0.28370317816734314, 0.057910144329071045, 2.694267511367798, 0.32770389318466187]

# %%
# Define new loss: Same CrossEntropy but adding class weights
criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))

# %%
EXTRA_EPOCHS = 40
END_EPOCH = start_epoch + EXTRA_EPOCHS - 1

for epoch in range(start_epoch, END_EPOCH + 1):
    print(f"\n===== Epoch {epoch}/{END_EPOCH} (resumed with weighted CE) =====")

    # Training epoch
    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, epoch)

    # Metrics for train and validation sets
    train_loss_eval, train_miou, train_dice, train_f1, train_acc = evaluate(model, train_loader, criterion)
    val_loss, val_miou, val_dice, val_f1, val_acc = evaluate(model, val_loader, criterion)

    # step scheduler on val_loss
    scheduler.step(val_loss)

    current_lr = optimizer.param_groups[0]["lr"]
    
    print(
        f"Epoch {epoch:03d} | "
        f"TrainLoss(step): {train_loss:.4f} | "
        f"TrainLoss(eval): {train_loss_eval:.4f} | "
        f"ValLoss: {val_loss:.4f} | "
        f"Train mIoU: {train_miou:.4f} | "
        f"Val mIoU: {val_miou:.4f} | "
        f"Val Dice: {val_dice:.4f} | "
        f"Val F1: {val_f1:.4f} | "
        f"Val Acc: {val_acc:.4f} | "
        f"LR: {current_lr:.6f}"
    )

    # Store metrics
    history.append({
        "epoch": epoch,
        # training loss from the actual training loop
        "train_loss_step": float(train_loss),
        # training loss recomputed in eval mode
        "train_loss_eval": float(train_loss_eval),
        "train_miou": float(train_miou),
        "train_dice": float(train_dice),
        "train_f1_macro": float(train_f1),
        "train_global_pixel_accuracy": float(train_acc),
        "val_loss": float(val_loss),
        "val_miou": float(val_miou),
        "val_dice": float(val_dice),
        "val_f1_macro": float(val_f1),
        "val_global_pixel_accuracy": float(val_acc),
        "lr": float(current_lr),
    })

    # save best model by mIoU
    if val_miou > best_miou:
        best_miou = val_miou
        torch.save(model.state_dict(), "deeplab_best_miou_wce.pth")
        print("  -> New best mIoU; weights saved to deeplab_best_miou_wce.pth")

    # periodic full checkpoint save
    if epoch % CHECKPOINT_EVERY == 0:
        ckpt_path = f"deeplab_checkpoint_epoch_{epoch}_wce.pth"
        torch.save({
            "config": CONFIG,
            "epoch": epoch,
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "scheduler_state_dict": scheduler.state_dict(),
            "best_miou": best_miou,
            "history": history,
        }, ckpt_path)
        print(f"  -> Checkpoint saved to {ckpt_path}")

# final "last" checkpoint
torch.save({
    "config": CONFIG,
    "epoch": END_EPOCH,
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "scheduler_state_dict": scheduler.state_dict(),
    "best_miou": best_miou,
    "history": history,
}, "deeplab_last_wce.pth")

print("\nTraining complete. Best mIoU:", best_miou)

# Store training logs in JSON format

output_path = Path("/kaggle/working/deeplab_results_wce.json")

results = {
    "config": CONFIG,
    "history": history,
}

with open(output_path, "w") as f:
    json.dump(results, f, indent=2)

print("Saved metrics to:", output_path)

# Download link for results
FileLink('/kaggle/working/deeplab_results_wce.json')
# Out:
# ===== Epoch 41/80 (resumed with weighted CE) =====
# [Epoch 41] Step 1/737 - Loss: 0.7688
# [Epoch 41] Step 50/737 - Loss: 0.7984
# [Epoch 41] Step 100/737 - Loss: 0.5377
# [Epoch 41] Step 150/737 - Loss: 0.6618
# [Epoch 41] Step 200/737 - Loss: 0.5389
# [Epoch 41] Step 250/737 - Loss: 0.4518
# [Epoch 41] Step 300/737 - Loss: 0.4877
# [Epoch 41] Step 350/737 - Loss: 0.4679
# [Epoch 41] Step 400/737 - Loss: 0.2205
# [Epoch 41] Step 450/737 - Loss: 0.6048
# [Epoch 41] Step 500/737 - Loss: 0.5975
# [Epoch 41] Step 550/737 - Loss: 0.3584
# [Epoch 41] Step 600/737 - Loss: 0.4334
# [Epoch 41] Step 650/737 - Loss: 0.3878
# [Epoch 41] Step 700/737 - Loss: 0.4248
# Epoch 041 | TrainLoss(step): 0.4884 | TrainLoss(eval): 0.4021 | ValLoss: 2.2341 | Train mIoU: 0.7101 | Val mIoU: 0.3139 | Val Dice: 2.9194 | Val F1: 0.4527 | Val Acc: 0.7678 | LR: 0.000000
#   -> New best mIoU; weights saved to deeplab_best_miou_wce.pth
#
# ===== Epoch 42/80 (resumed with weighted CE) =====
# [Epoch 42] Step 1/737 - Loss: 0.1921
# [Epoch 42] Step 50/737 - Loss: 0.4154
# [Epoch 42] Step 100/737 - Loss: 1.0669
# [Epoch 42] Step 150/737 - Loss: 0.4295
# [Epoch 42] Step 200/737 - Loss: 0.7531
# [Epoch 42] Step 250/737 - Loss: 0.2840
# [Epoch 42] Step 300/737 - Loss: 0.2930
# [Epoch 42] Step 350/737 - Loss: 0.3957
# [Epoch 42] Step 400/737 - Loss: 0.6448
# [Epoch 42] Step 450/737 - Loss: 0.4854
# [Epoch 42] Step 500/737 - Loss: 0.5315
# [Epoch 42] Step 550/737 - Loss: 0.3391
# [Epoch 42] Step 600/737 - Loss: 1.1154
# [Epoch 42] Step 650/737 - Loss: 0.2383
# [Epoch 42] Step 700/737 - Loss: 0.1991
# Epoch 042 | TrainLoss(step): 0.4266 | TrainLoss(eval): 0.3554 | ValLoss: 2.0756 | Train mIoU: 0.6702 | Val mIoU: 0.3033 | Val Dice: 2.9476 | Val F1: 0.4391 | Val Acc: 0.7551 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_42_wce.pth
#
# ===== Epoch 43/80 (resumed with weighted CE) =====
# [Epoch 43] Step 1/737 - Loss: 0.9060
# [Epoch 43] Step 50/737 - Loss: 0.4093
# [Epoch 43] Step 100/737 - Loss: 0.3259
# [Epoch 43] Step 150/737 - Loss: 0.3888
# [Epoch 43] Step 200/737 - Loss: 0.5335
# [Epoch 43] Step 250/737 - Loss: 0.4683
# [Epoch 43] Step 300/737 - Loss: 0.2436
# [Epoch 43] Step 350/737 - Loss: 0.2272
# [Epoch 43] Step 400/737 - Loss: 0.4082
# [Epoch 43] Step 450/737 - Loss: 0.3088
# [Epoch 43] Step 500/737 - Loss: 0.1377
# [Epoch 43] Step 550/737 - Loss: 0.1724
# [Epoch 43] Step 600/737 - Loss: 0.5040
# [Epoch 43] Step 650/737 - Loss: 0.3638
# [Epoch 43] Step 700/737 - Loss: 0.2872
# Epoch 043 | TrainLoss(step): 0.4052 | TrainLoss(eval): 0.3540 | ValLoss: 2.0687 | Train mIoU: 0.6638 | Val mIoU: 0.3062 | Val Dice: 2.9829 | Val F1: 0.4430 | Val Acc: 0.7494 | LR: 0.000000
#
# ===== Epoch 44/80 (resumed with weighted CE) =====
# [Epoch 44] Step 1/737 - Loss: 0.4489
# [Epoch 44] Step 50/737 - Loss: 0.2071
# [Epoch 44] Step 100/737 - Loss: 0.8141
# [Epoch 44] Step 150/737 - Loss: 0.9348
# [Epoch 44] Step 200/737 - Loss: 0.2649
# [Epoch 44] Step 250/737 - Loss: 0.4398
# [Epoch 44] Step 300/737 - Loss: 0.5441
# [Epoch 44] Step 350/737 - Loss: 0.5752
# [Epoch 44] Step 400/737 - Loss: 0.2074
# [Epoch 44] Step 450/737 - Loss: 0.2457
# [Epoch 44] Step 500/737 - Loss: 0.4419
# [Epoch 44] Step 550/737 - Loss: 0.5580
# [Epoch 44] Step 600/737 - Loss: 0.2870
# [Epoch 44] Step 650/737 - Loss: 0.2860
# [Epoch 44] Step 700/737 - Loss: 0.2243
# Epoch 044 | TrainLoss(step): 0.3937 | TrainLoss(eval): 0.3260 | ValLoss: 1.9729 | Train mIoU: 0.6373 | Val mIoU: 0.2967 | Val Dice: 2.9459 | Val F1: 0.4299 | Val Acc: 0.7447 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_44_wce.pth
#
# ===== Epoch 45/80 (resumed with weighted CE) =====
# [Epoch 45] Step 1/737 - Loss: 0.3272
# [Epoch 45] Step 50/737 - Loss: 0.3095
# [Epoch 45] Step 100/737 - Loss: 0.3434
# [Epoch 45] Step 150/737 - Loss: 0.2677
# [Epoch 45] Step 200/737 - Loss: 0.5602
# [Epoch 45] Step 250/737 - Loss: 0.2418
# [Epoch 45] Step 300/737 - Loss: 0.3157
# [Epoch 45] Step 350/737 - Loss: 1.4176
# [Epoch 45] Step 400/737 - Loss: 0.7404
# [Epoch 45] Step 450/737 - Loss: 0.2197
# [Epoch 45] Step 500/737 - Loss: 0.5784
# [Epoch 45] Step 550/737 - Loss: 0.3952
# [Epoch 45] Step 600/737 - Loss: 0.1832
# [Epoch 45] Step 650/737 - Loss: 0.2677
# [Epoch 45] Step 700/737 - Loss: 0.7292
# Epoch 045 | TrainLoss(step): 0.3859 | TrainLoss(eval): 0.3244 | ValLoss: 2.0053 | Train mIoU: 0.6460 | Val mIoU: 0.2975 | Val Dice: 2.9388 | Val F1: 0.4316 | Val Acc: 0.7426 | LR: 0.000000
#
# ===== Epoch 46/80 (resumed with weighted CE) =====
# [Epoch 46] Step 1/737 - Loss: 0.5032
# [Epoch 46] Step 50/737 - Loss: 0.3083
# [Epoch 46] Step 100/737 - Loss: 0.4194
# [Epoch 46] Step 150/737 - Loss: 0.4187
# [Epoch 46] Step 200/737 - Loss: 0.6382
# [Epoch 46] Step 250/737 - Loss: 0.4777
# [Epoch 46] Step 300/737 - Loss: 0.3159
# [Epoch 46] Step 350/737 - Loss: 0.6389
# [Epoch 46] Step 400/737 - Loss: 0.6459
# [Epoch 46] Step 450/737 - Loss: 0.3688
# [Epoch 46] Step 500/737 - Loss: 0.3453
# [Epoch 46] Step 550/737 - Loss: 0.4461
# [Epoch 46] Step 600/737 - Loss: 0.2412
# [Epoch 46] Step 650/737 - Loss: 0.3365
# [Epoch 46] Step 700/737 - Loss: 0.2723
# Epoch 046 | TrainLoss(step): 0.3816 | TrainLoss(eval): 0.3249 | ValLoss: 2.0243 | Train mIoU: 0.6462 | Val mIoU: 0.2973 | Val Dice: 2.9204 | Val F1: 0.4313 | Val Acc: 0.7495 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_46_wce.pth
#
# ===== Epoch 47/80 (resumed with weighted CE) =====
# [Epoch 47] Step 1/737 - Loss: 0.3134
# [Epoch 47] Step 50/737 - Loss: 0.7966
# [Epoch 47] Step 100/737 - Loss: 0.2148
# [Epoch 47] Step 150/737 - Loss: 0.4984
# [Epoch 47] Step 200/737 - Loss: 0.3688
# [Epoch 47] Step 250/737 - Loss: 0.2140
# [Epoch 47] Step 300/737 - Loss: 0.5193
# [Epoch 47] Step 350/737 - Loss: 0.2208
# [Epoch 47] Step 400/737 - Loss: 0.4133
# [Epoch 47] Step 450/737 - Loss: 0.2062
# [Epoch 47] Step 500/737 - Loss: 0.4788
# [Epoch 47] Step 550/737 - Loss: 0.3242
# [Epoch 47] Step 600/737 - Loss: 0.2042
# [Epoch 47] Step 650/737 - Loss: 0.2249
# [Epoch 47] Step 700/737 - Loss: 0.5312
# Epoch 047 | TrainLoss(step): 0.3783 | TrainLoss(eval): 0.3157 | ValLoss: 1.9899 | Train mIoU: 0.6456 | Val mIoU: 0.2990 | Val Dice: 2.9552 | Val F1: 0.4331 | Val Acc: 0.7451 | LR: 0.000000
#
# ===== Epoch 48/80 (resumed with weighted CE) =====
# [Epoch 48] Step 1/737 - Loss: 0.4538
# [Epoch 48] Step 50/737 - Loss: 0.1834
# [Epoch 48] Step 100/737 - Loss: 0.5979
# [Epoch 48] Step 150/737 - Loss: 0.2053
# [Epoch 48] Step 200/737 - Loss: 0.6091
# [Epoch 48] Step 250/737 - Loss: 0.2604
# [Epoch 48] Step 300/737 - Loss: 0.3972
# [Epoch 48] Step 350/737 - Loss: 0.2511
# [Epoch 48] Step 400/737 - Loss: 0.3108
# [Epoch 48] Step 450/737 - Loss: 0.3727
# [Epoch 48] Step 500/737 - Loss: 0.3847
# [Epoch 48] Step 550/737 - Loss: 0.3361
# [Epoch 48] Step 600/737 - Loss: 0.1633
# [Epoch 48] Step 650/737 - Loss: 0.4096
# [Epoch 48] Step 700/737 - Loss: 0.2730
# Epoch 048 | TrainLoss(step): 0.3801 | TrainLoss(eval): 0.3141 | ValLoss: 1.9540 | Train mIoU: 0.6306 | Val mIoU: 0.2938 | Val Dice: 2.9372 | Val F1: 0.4269 | Val Acc: 0.7359 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_48_wce.pth
#
# ===== Epoch 49/80 (resumed with weighted CE) =====
# [Epoch 49] Step 1/737 - Loss: 0.6945
# [Epoch 49] Step 50/737 - Loss: 0.4516
# [Epoch 49] Step 100/737 - Loss: 0.4578
# [Epoch 49] Step 150/737 - Loss: 0.4286
# [Epoch 49] Step 200/737 - Loss: 0.6139
# [Epoch 49] Step 250/737 - Loss: 0.3951
# [Epoch 49] Step 300/737 - Loss: 0.5471
# [Epoch 49] Step 350/737 - Loss: 0.2105
# [Epoch 49] Step 400/737 - Loss: 0.4162
# [Epoch 49] Step 450/737 - Loss: 0.2221
# [Epoch 49] Step 500/737 - Loss: 0.2815
# [Epoch 49] Step 550/737 - Loss: 0.2659
# [Epoch 49] Step 600/737 - Loss: 0.4399
# [Epoch 49] Step 650/737 - Loss: 0.3070
# [Epoch 49] Step 700/737 - Loss: 0.2558
# Epoch 049 | TrainLoss(step): 0.3795 | TrainLoss(eval): 0.3203 | ValLoss: 1.9802 | Train mIoU: 0.6380 | Val mIoU: 0.2963 | Val Dice: 2.9509 | Val F1: 0.4303 | Val Acc: 0.7387 | LR: 0.000000
#
# ===== Epoch 50/80 (resumed with weighted CE) =====
# [Epoch 50] Step 1/737 - Loss: 0.4602
# [Epoch 50] Step 50/737 - Loss: 0.3325
# [Epoch 50] Step 100/737 - Loss: 0.2701
# [Epoch 50] Step 150/737 - Loss: 0.2706
# [Epoch 50] Step 200/737 - Loss: 0.4733
# [Epoch 50] Step 250/737 - Loss: 0.2430
# [Epoch 50] Step 300/737 - Loss: 0.3615
# [Epoch 50] Step 350/737 - Loss: 0.2878
# [Epoch 50] Step 400/737 - Loss: 0.2948
# [Epoch 50] Step 450/737 - Loss: 0.2134
# [Epoch 50] Step 500/737 - Loss: 0.6215
# [Epoch 50] Step 550/737 - Loss: 0.4573
# [Epoch 50] Step 600/737 - Loss: 0.3549
# [Epoch 50] Step 650/737 - Loss: 0.4464
# [Epoch 50] Step 700/737 - Loss: 0.1825
# Epoch 050 | TrainLoss(step): 0.3745 | TrainLoss(eval): 0.3233 | ValLoss: 2.0128 | Train mIoU: 0.6494 | Val mIoU: 0.2969 | Val Dice: 2.8992 | Val F1: 0.4318 | Val Acc: 0.7474 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_50_wce.pth
#
# ===== Epoch 51/80 (resumed with weighted CE) =====
# [Epoch 51] Step 1/737 - Loss: 0.6502
# [Epoch 51] Step 50/737 - Loss: 0.4676
# [Epoch 51] Step 100/737 - Loss: 0.2857
# [Epoch 51] Step 150/737 - Loss: 0.4548
# [Epoch 51] Step 200/737 - Loss: 0.1786
# [Epoch 51] Step 250/737 - Loss: 0.3760
# [Epoch 51] Step 300/737 - Loss: 0.3827
# [Epoch 51] Step 350/737 - Loss: 0.4724
# [Epoch 51] Step 400/737 - Loss: 0.4211
# [Epoch 51] Step 450/737 - Loss: 0.1745
# [Epoch 51] Step 500/737 - Loss: 0.1796
# [Epoch 51] Step 550/737 - Loss: 0.2873
# [Epoch 51] Step 600/737 - Loss: 0.4451
# [Epoch 51] Step 650/737 - Loss: 0.4963
# [Epoch 51] Step 700/737 - Loss: 0.2592
# Epoch 051 | TrainLoss(step): 0.3713 | TrainLoss(eval): 0.3201 | ValLoss: 1.9517 | Train mIoU: 0.6214 | Val mIoU: 0.2914 | Val Dice: 2.9479 | Val F1: 0.4243 | Val Acc: 0.7301 | LR: 0.000000
#
# ===== Epoch 52/80 (resumed with weighted CE) =====
# [Epoch 52] Step 1/737 - Loss: 0.4951
# [Epoch 52] Step 50/737 - Loss: 0.3455
# [Epoch 52] Step 100/737 - Loss: 0.7096
# [Epoch 52] Step 150/737 - Loss: 0.5345
# [Epoch 52] Step 200/737 - Loss: 0.1822
# [Epoch 52] Step 250/737 - Loss: 0.2032
# [Epoch 52] Step 300/737 - Loss: 0.2721
# [Epoch 52] Step 350/737 - Loss: 0.3002
# [Epoch 52] Step 400/737 - Loss: 0.4714
# [Epoch 52] Step 450/737 - Loss: 0.1520
# [Epoch 52] Step 500/737 - Loss: 0.2102
# [Epoch 52] Step 550/737 - Loss: 0.2652
# [Epoch 52] Step 600/737 - Loss: 0.4401
# [Epoch 52] Step 650/737 - Loss: 0.1804
# [Epoch 52] Step 700/737 - Loss: 0.9737
# Epoch 052 | TrainLoss(step): 0.3714 | TrainLoss(eval): 0.3129 | ValLoss: 1.9396 | Train mIoU: 0.6283 | Val mIoU: 0.2949 | Val Dice: 2.9326 | Val F1: 0.4277 | Val Acc: 0.7365 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_52_wce.pth
#
# ===== Epoch 53/80 (resumed with weighted CE) =====
# [Epoch 53] Step 1/737 - Loss: 0.7813
# [Epoch 53] Step 50/737 - Loss: 0.1713
# [Epoch 53] Step 100/737 - Loss: 0.4567
# [Epoch 53] Step 150/737 - Loss: 0.3583
# [Epoch 53] Step 200/737 - Loss: 0.3708
# [Epoch 53] Step 250/737 - Loss: 0.4682
# [Epoch 53] Step 300/737 - Loss: 0.2268
# [Epoch 53] Step 350/737 - Loss: 0.3083
# [Epoch 53] Step 400/737 - Loss: 0.3334
# [Epoch 53] Step 450/737 - Loss: 0.1619
# [Epoch 53] Step 500/737 - Loss: 0.1942
# [Epoch 53] Step 550/737 - Loss: 0.5578
# [Epoch 53] Step 600/737 - Loss: 0.4409
# [Epoch 53] Step 650/737 - Loss: 0.2170
# [Epoch 53] Step 700/737 - Loss: 0.2901
# Epoch 053 | TrainLoss(step): 0.3712 | TrainLoss(eval): 0.3150 | ValLoss: 2.0374 | Train mIoU: 0.6329 | Val mIoU: 0.2939 | Val Dice: 2.8884 | Val F1: 0.4266 | Val Acc: 0.7455 | LR: 0.000000
#
# ===== Epoch 54/80 (resumed with weighted CE) =====
# [Epoch 54] Step 1/737 - Loss: 0.2407
# [Epoch 54] Step 50/737 - Loss: 0.2529
# [Epoch 54] Step 100/737 - Loss: 0.3807
# [Epoch 54] Step 150/737 - Loss: 0.6085
# [Epoch 54] Step 200/737 - Loss: 0.2521
# [Epoch 54] Step 250/737 - Loss: 0.2382
# [Epoch 54] Step 300/737 - Loss: 0.2695
# [Epoch 54] Step 350/737 - Loss: 0.1866
# [Epoch 54] Step 400/737 - Loss: 0.2886
# [Epoch 54] Step 450/737 - Loss: 0.3271
# [Epoch 54] Step 500/737 - Loss: 0.2805
# [Epoch 54] Step 550/737 - Loss: 0.3582
# [Epoch 54] Step 600/737 - Loss: 0.3199
# [Epoch 54] Step 650/737 - Loss: 0.7303
# [Epoch 54] Step 700/737 - Loss: 0.5166
# Epoch 054 | TrainLoss(step): 0.3698 | TrainLoss(eval): 0.3152 | ValLoss: 1.9981 | Train mIoU: 0.6367 | Val mIoU: 0.2972 | Val Dice: 2.9001 | Val F1: 0.4305 | Val Acc: 0.7458 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_54_wce.pth
#
# ===== Epoch 55/80 (resumed with weighted CE) =====
# [Epoch 55] Step 1/737 - Loss: 0.4062
# [Epoch 55] Step 50/737 - Loss: 0.3843
# [Epoch 55] Step 100/737 - Loss: 0.3128
# [Epoch 55] Step 150/737 - Loss: 0.3520
# [Epoch 55] Step 200/737 - Loss: 0.3734
# [Epoch 55] Step 250/737 - Loss: 0.4627
# [Epoch 55] Step 300/737 - Loss: 0.2597
# [Epoch 55] Step 350/737 - Loss: 0.3968
# [Epoch 55] Step 400/737 - Loss: 0.6708
# [Epoch 55] Step 450/737 - Loss: 0.3612
# [Epoch 55] Step 500/737 - Loss: 0.3612
# [Epoch 55] Step 550/737 - Loss: 0.2991
# [Epoch 55] Step 600/737 - Loss: 0.2120
# [Epoch 55] Step 650/737 - Loss: 0.2934
# [Epoch 55] Step 700/737 - Loss: 0.3988
# Epoch 055 | TrainLoss(step): 0.3694 | TrainLoss(eval): 0.3128 | ValLoss: 1.9368 | Train mIoU: 0.6322 | Val mIoU: 0.2951 | Val Dice: 2.9291 | Val F1: 0.4293 | Val Acc: 0.7358 | LR: 0.000000
#
# ===== Epoch 56/80 (resumed with weighted CE) =====
# [Epoch 56] Step 1/737 - Loss: 0.5497
# [Epoch 56] Step 50/737 - Loss: 0.3470
# [Epoch 56] Step 100/737 - Loss: 0.4820
# [Epoch 56] Step 150/737 - Loss: 0.3903
# [Epoch 56] Step 200/737 - Loss: 0.3109
# [Epoch 56] Step 250/737 - Loss: 0.7980
# [Epoch 56] Step 300/737 - Loss: 0.7132
# [Epoch 56] Step 350/737 - Loss: 0.2154
# [Epoch 56] Step 400/737 - Loss: 0.2705
# [Epoch 56] Step 450/737 - Loss: 0.7063
# [Epoch 56] Step 500/737 - Loss: 0.2561
# [Epoch 56] Step 550/737 - Loss: 0.3345
# [Epoch 56] Step 600/737 - Loss: 0.7925
# [Epoch 56] Step 650/737 - Loss: 0.4963
# [Epoch 56] Step 700/737 - Loss: 0.2204
# Epoch 056 | TrainLoss(step): 0.3700 | TrainLoss(eval): 0.3146 | ValLoss: 1.9460 | Train mIoU: 0.6294 | Val mIoU: 0.2954 | Val Dice: 2.9367 | Val F1: 0.4288 | Val Acc: 0.7383 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_56_wce.pth
#
# ===== Epoch 57/80 (resumed with weighted CE) =====
# [Epoch 57] Step 1/737 - Loss: 0.3087
# [Epoch 57] Step 50/737 - Loss: 0.1346
# [Epoch 57] Step 100/737 - Loss: 0.5229
# [Epoch 57] Step 150/737 - Loss: 0.3925
# [Epoch 57] Step 200/737 - Loss: 0.1683
# [Epoch 57] Step 250/737 - Loss: 0.1512
# [Epoch 57] Step 300/737 - Loss: 0.3648
# [Epoch 57] Step 350/737 - Loss: 0.4665
# [Epoch 57] Step 400/737 - Loss: 0.2055
# [Epoch 57] Step 450/737 - Loss: 0.5011
# [Epoch 57] Step 500/737 - Loss: 0.2577
# [Epoch 57] Step 550/737 - Loss: 0.3016
# [Epoch 57] Step 600/737 - Loss: 0.5010
# [Epoch 57] Step 650/737 - Loss: 0.3680
# [Epoch 57] Step 700/737 - Loss: 0.2307
# Epoch 057 | TrainLoss(step): 0.3660 | TrainLoss(eval): 0.3071 | ValLoss: 1.9726 | Train mIoU: 0.6271 | Val mIoU: 0.2938 | Val Dice: 2.9143 | Val F1: 0.4261 | Val Acc: 0.7372 | LR: 0.000000
#
# ===== Epoch 58/80 (resumed with weighted CE) =====
# [Epoch 58] Step 1/737 - Loss: 0.2969
# [Epoch 58] Step 50/737 - Loss: 0.1998
# [Epoch 58] Step 100/737 - Loss: 0.2422
# [Epoch 58] Step 150/737 - Loss: 0.7298
# [Epoch 58] Step 200/737 - Loss: 0.6089
# [Epoch 58] Step 250/737 - Loss: 0.3361
# [Epoch 58] Step 300/737 - Loss: 0.3117
# [Epoch 58] Step 350/737 - Loss: 0.2874
# [Epoch 58] Step 400/737 - Loss: 0.1784
# [Epoch 58] Step 450/737 - Loss: 0.2414
# [Epoch 58] Step 500/737 - Loss: 0.6072
# [Epoch 58] Step 550/737 - Loss: 0.2287
# [Epoch 58] Step 600/737 - Loss: 0.4209
# [Epoch 58] Step 650/737 - Loss: 0.5292
# [Epoch 58] Step 700/737 - Loss: 0.5308
# Epoch 058 | TrainLoss(step): 0.3691 | TrainLoss(eval): 0.3186 | ValLoss: 1.9865 | Train mIoU: 0.6368 | Val mIoU: 0.2979 | Val Dice: 2.9299 | Val F1: 0.4316 | Val Acc: 0.7420 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_58_wce.pth
#
# ===== Epoch 59/80 (resumed with weighted CE) =====
# [Epoch 59] Step 1/737 - Loss: 0.1980
# [Epoch 59] Step 50/737 - Loss: 0.4809
# [Epoch 59] Step 100/737 - Loss: 0.3573
# [Epoch 59] Step 150/737 - Loss: 0.4457
# [Epoch 59] Step 200/737 - Loss: 0.3572
# [Epoch 59] Step 250/737 - Loss: 0.5647
# [Epoch 59] Step 300/737 - Loss: 0.2933
# [Epoch 59] Step 350/737 - Loss: 0.2460
# [Epoch 59] Step 400/737 - Loss: 0.2793
# [Epoch 59] Step 450/737 - Loss: 0.3552
# [Epoch 59] Step 500/737 - Loss: 0.2636
# [Epoch 59] Step 550/737 - Loss: 0.2863
# [Epoch 59] Step 600/737 - Loss: 0.1705
# [Epoch 59] Step 650/737 - Loss: 0.4091
# [Epoch 59] Step 700/737 - Loss: 0.4179
# Epoch 059 | TrainLoss(step): 0.3707 | TrainLoss(eval): 0.3145 | ValLoss: 1.9493 | Train mIoU: 0.6265 | Val mIoU: 0.2963 | Val Dice: 2.9197 | Val F1: 0.4284 | Val Acc: 0.7378 | LR: 0.000000
#
# ===== Epoch 60/80 (resumed with weighted CE) =====
# [Epoch 60] Step 1/737 - Loss: 0.5323
# [Epoch 60] Step 50/737 - Loss: 0.3658
# [Epoch 60] Step 100/737 - Loss: 0.2081
# [Epoch 60] Step 150/737 - Loss: 0.2788
# [Epoch 60] Step 200/737 - Loss: 0.4771
# [Epoch 60] Step 250/737 - Loss: 0.4137
# [Epoch 60] Step 300/737 - Loss: 0.6102
# [Epoch 60] Step 350/737 - Loss: 0.2818
# [Epoch 60] Step 400/737 - Loss: 0.4756
# [Epoch 60] Step 450/737 - Loss: 0.4540
# [Epoch 60] Step 500/737 - Loss: 0.6500
# [Epoch 60] Step 550/737 - Loss: 0.1266
# [Epoch 60] Step 600/737 - Loss: 0.3787
# [Epoch 60] Step 650/737 - Loss: 0.4770
# [Epoch 60] Step 700/737 - Loss: 0.3197
# Epoch 060 | TrainLoss(step): 0.3684 | TrainLoss(eval): 0.3256 | ValLoss: 2.1092 | Train mIoU: 0.6470 | Val mIoU: 0.3001 | Val Dice: 2.9154 | Val F1: 0.4341 | Val Acc: 0.7506 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_60_wce.pth
#
# ===== Epoch 61/80 (resumed with weighted CE) =====
# [Epoch 61] Step 1/737 - Loss: 0.4552
# [Epoch 61] Step 50/737 - Loss: 0.3184
# [Epoch 61] Step 100/737 - Loss: 0.4037
# [Epoch 61] Step 150/737 - Loss: 0.3298
# [Epoch 61] Step 200/737 - Loss: 0.3682
# [Epoch 61] Step 250/737 - Loss: 0.4654
# [Epoch 61] Step 300/737 - Loss: 0.2170
# [Epoch 61] Step 350/737 - Loss: 0.5299
# [Epoch 61] Step 400/737 - Loss: 0.4104
# [Epoch 61] Step 450/737 - Loss: 0.6644
# [Epoch 61] Step 500/737 - Loss: 0.2902
# [Epoch 61] Step 550/737 - Loss: 0.2489
# [Epoch 61] Step 600/737 - Loss: 0.3025
# [Epoch 61] Step 650/737 - Loss: 0.4271
# [Epoch 61] Step 700/737 - Loss: 0.3240
# Epoch 061 | TrainLoss(step): 0.3702 | TrainLoss(eval): 0.3048 | ValLoss: 1.9676 | Train mIoU: 0.6269 | Val mIoU: 0.2929 | Val Dice: 2.9108 | Val F1: 0.4247 | Val Acc: 0.7380 | LR: 0.000000
#
# ===== Epoch 62/80 (resumed with weighted CE) =====
# [Epoch 62] Step 1/737 - Loss: 0.4590
# [Epoch 62] Step 50/737 - Loss: 0.3181
# [Epoch 62] Step 100/737 - Loss: 0.3254
# [Epoch 62] Step 150/737 - Loss: 0.2401
# [Epoch 62] Step 200/737 - Loss: 0.2494
# [Epoch 62] Step 250/737 - Loss: 0.2025
# [Epoch 62] Step 300/737 - Loss: 0.3767
# [Epoch 62] Step 350/737 - Loss: 0.4964
# [Epoch 62] Step 400/737 - Loss: 0.3967
# [Epoch 62] Step 450/737 - Loss: 0.2412
# [Epoch 62] Step 500/737 - Loss: 0.5483
# [Epoch 62] Step 550/737 - Loss: 0.4074
# [Epoch 62] Step 600/737 - Loss: 0.2510
# [Epoch 62] Step 650/737 - Loss: 0.2715
# [Epoch 62] Step 700/737 - Loss: 0.1917
# Epoch 062 | TrainLoss(step): 0.3691 | TrainLoss(eval): 0.3137 | ValLoss: 1.9702 | Train mIoU: 0.6359 | Val mIoU: 0.2981 | Val Dice: 2.9124 | Val F1: 0.4311 | Val Acc: 0.7448 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_62_wce.pth
#
# ===== Epoch 63/80 (resumed with weighted CE) =====
# [Epoch 63] Step 1/737 - Loss: 0.3761
# [Epoch 63] Step 50/737 - Loss: 0.2861
# [Epoch 63] Step 100/737 - Loss: 0.2331
# [Epoch 63] Step 150/737 - Loss: 0.4147
# [Epoch 63] Step 200/737 - Loss: 0.2383
# [Epoch 63] Step 250/737 - Loss: 0.3606
# [Epoch 63] Step 300/737 - Loss: 0.3028
# [Epoch 63] Step 350/737 - Loss: 0.4025
# [Epoch 63] Step 400/737 - Loss: 0.5943
# [Epoch 63] Step 450/737 - Loss: 0.2118
# [Epoch 63] Step 500/737 - Loss: 0.1797
# [Epoch 63] Step 550/737 - Loss: 0.3478
# [Epoch 63] Step 600/737 - Loss: 0.2339
# [Epoch 63] Step 650/737 - Loss: 0.2090
# [Epoch 63] Step 700/737 - Loss: 0.2689
# Epoch 063 | TrainLoss(step): 0.3666 | TrainLoss(eval): 0.3100 | ValLoss: 1.9374 | Train mIoU: 0.6226 | Val mIoU: 0.2928 | Val Dice: 2.9381 | Val F1: 0.4250 | Val Acc: 0.7361 | LR: 0.000000
#
# ===== Epoch 64/80 (resumed with weighted CE) =====
# [Epoch 64] Step 1/737 - Loss: 0.1894
# [Epoch 64] Step 50/737 - Loss: 0.4722
# [Epoch 64] Step 100/737 - Loss: 0.2659
# [Epoch 64] Step 150/737 - Loss: 0.1033
# [Epoch 64] Step 200/737 - Loss: 0.2791
# [Epoch 64] Step 250/737 - Loss: 0.3297
# [Epoch 64] Step 300/737 - Loss: 0.2382
# [Epoch 64] Step 350/737 - Loss: 0.3991
# [Epoch 64] Step 400/737 - Loss: 0.1952
# [Epoch 64] Step 450/737 - Loss: 0.3294
# [Epoch 64] Step 500/737 - Loss: 0.2635
# [Epoch 64] Step 550/737 - Loss: 0.4511
# [Epoch 64] Step 600/737 - Loss: 0.3859
# [Epoch 64] Step 650/737 - Loss: 0.4285
# [Epoch 64] Step 700/737 - Loss: 0.3170
# Epoch 064 | TrainLoss(step): 0.3676 | TrainLoss(eval): 0.3117 | ValLoss: 1.9656 | Train mIoU: 0.6282 | Val mIoU: 0.2941 | Val Dice: 2.9293 | Val F1: 0.4267 | Val Acc: 0.7366 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_64_wce.pth
#
# ===== Epoch 65/80 (resumed with weighted CE) =====
# [Epoch 65] Step 1/737 - Loss: 0.4606
# [Epoch 65] Step 50/737 - Loss: 0.3949
# [Epoch 65] Step 100/737 - Loss: 0.4537
# [Epoch 65] Step 150/737 - Loss: 0.2700
# [Epoch 65] Step 200/737 - Loss: 0.3371
# [Epoch 65] Step 250/737 - Loss: 0.3508
# [Epoch 65] Step 300/737 - Loss: 0.3948
# [Epoch 65] Step 350/737 - Loss: 0.3863
# [Epoch 65] Step 400/737 - Loss: 0.1387
# [Epoch 65] Step 450/737 - Loss: 0.3394
# [Epoch 65] Step 500/737 - Loss: 0.3053
# [Epoch 65] Step 550/737 - Loss: 0.6347
# [Epoch 65] Step 600/737 - Loss: 0.4182
# [Epoch 65] Step 650/737 - Loss: 0.2139
# [Epoch 65] Step 700/737 - Loss: 0.2186
# Epoch 065 | TrainLoss(step): 0.3677 | TrainLoss(eval): 0.3116 | ValLoss: 1.9889 | Train mIoU: 0.6325 | Val mIoU: 0.2946 | Val Dice: 2.9264 | Val F1: 0.4277 | Val Acc: 0.7380 | LR: 0.000000
#
# ===== Epoch 66/80 (resumed with weighted CE) =====
# [Epoch 66] Step 1/737 - Loss: 0.3259
# [Epoch 66] Step 50/737 - Loss: 0.3109
# [Epoch 66] Step 100/737 - Loss: 0.2863
# [Epoch 66] Step 150/737 - Loss: 0.3249
# [Epoch 66] Step 200/737 - Loss: 0.5502
# [Epoch 66] Step 250/737 - Loss: 0.1529
# [Epoch 66] Step 300/737 - Loss: 0.3312
# [Epoch 66] Step 350/737 - Loss: 0.2855
# [Epoch 66] Step 400/737 - Loss: 0.6575
# [Epoch 66] Step 450/737 - Loss: 0.2074
# [Epoch 66] Step 500/737 - Loss: 0.2137
# [Epoch 66] Step 550/737 - Loss: 0.3066
# [Epoch 66] Step 600/737 - Loss: 0.5803
# [Epoch 66] Step 650/737 - Loss: 0.3616
# [Epoch 66] Step 700/737 - Loss: 0.2614
# Epoch 066 | TrainLoss(step): 0.3663 | TrainLoss(eval): 0.3113 | ValLoss: 1.9814 | Train mIoU: 0.6427 | Val mIoU: 0.2988 | Val Dice: 2.9157 | Val F1: 0.4331 | Val Acc: 0.7441 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_66_wce.pth
#
# ===== Epoch 67/80 (resumed with weighted CE) =====
# [Epoch 67] Step 1/737 - Loss: 0.8189
# [Epoch 67] Step 50/737 - Loss: 0.2853
# [Epoch 67] Step 100/737 - Loss: 0.2147
# [Epoch 67] Step 150/737 - Loss: 0.3323
# [Epoch 67] Step 200/737 - Loss: 0.3733
# [Epoch 67] Step 250/737 - Loss: 0.2691
# [Epoch 67] Step 300/737 - Loss: 0.2502
# [Epoch 67] Step 350/737 - Loss: 0.2793
# [Epoch 67] Step 400/737 - Loss: 0.5374
# [Epoch 67] Step 450/737 - Loss: 0.7891
# [Epoch 67] Step 500/737 - Loss: 0.2052
# [Epoch 67] Step 550/737 - Loss: 0.2287
# [Epoch 67] Step 600/737 - Loss: 0.4075
# [Epoch 67] Step 650/737 - Loss: 0.3301
# [Epoch 67] Step 700/737 - Loss: 0.2876
# Epoch 067 | TrainLoss(step): 0.3660 | TrainLoss(eval): 0.3194 | ValLoss: 2.1006 | Train mIoU: 0.6507 | Val mIoU: 0.3000 | Val Dice: 2.8927 | Val F1: 0.4341 | Val Acc: 0.7504 | LR: 0.000000
#
# ===== Epoch 68/80 (resumed with weighted CE) =====
# [Epoch 68] Step 1/737 - Loss: 0.2262
# [Epoch 68] Step 50/737 - Loss: 0.4733
# [Epoch 68] Step 100/737 - Loss: 0.3030
# [Epoch 68] Step 150/737 - Loss: 0.3726
# [Epoch 68] Step 200/737 - Loss: 0.2786
# [Epoch 68] Step 250/737 - Loss: 0.1993
# [Epoch 68] Step 300/737 - Loss: 0.2670
# [Epoch 68] Step 350/737 - Loss: 0.3389
# [Epoch 68] Step 400/737 - Loss: 0.3076
# [Epoch 68] Step 450/737 - Loss: 0.7373
# [Epoch 68] Step 500/737 - Loss: 0.2643
# [Epoch 68] Step 550/737 - Loss: 0.3428
# [Epoch 68] Step 600/737 - Loss: 0.3857
# [Epoch 68] Step 650/737 - Loss: 0.4911
# [Epoch 68] Step 700/737 - Loss: 0.3357
# Epoch 068 | TrainLoss(step): 0.3645 | TrainLoss(eval): 0.3154 | ValLoss: 2.0384 | Train mIoU: 0.6451 | Val mIoU: 0.2998 | Val Dice: 2.9114 | Val F1: 0.4338 | Val Acc: 0.7477 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_68_wce.pth
#
# ===== Epoch 69/80 (resumed with weighted CE) =====
# [Epoch 69] Step 1/737 - Loss: 0.2662
# [Epoch 69] Step 50/737 - Loss: 0.4277
# [Epoch 69] Step 100/737 - Loss: 0.5160
# [Epoch 69] Step 150/737 - Loss: 0.5362
# [Epoch 69] Step 200/737 - Loss: 0.2500
# [Epoch 69] Step 250/737 - Loss: 0.4100
# [Epoch 69] Step 300/737 - Loss: 0.3346
# [Epoch 69] Step 350/737 - Loss: 0.3691
# [Epoch 69] Step 400/737 - Loss: 0.3322
# [Epoch 69] Step 450/737 - Loss: 0.1299
# [Epoch 69] Step 500/737 - Loss: 0.4302
# [Epoch 69] Step 550/737 - Loss: 0.5711
# [Epoch 69] Step 600/737 - Loss: 0.2522
# [Epoch 69] Step 650/737 - Loss: 0.3947
# [Epoch 69] Step 700/737 - Loss: 0.4296
# Epoch 069 | TrainLoss(step): 0.3643 | TrainLoss(eval): 0.3189 | ValLoss: 2.0393 | Train mIoU: 0.6288 | Val mIoU: 0.2977 | Val Dice: 2.9432 | Val F1: 0.4304 | Val Acc: 0.7426 | LR: 0.000000
#
# ===== Epoch 70/80 (resumed with weighted CE) =====
# [Epoch 70] Step 1/737 - Loss: 0.1315
# [Epoch 70] Step 50/737 - Loss: 0.3587
# [Epoch 70] Step 100/737 - Loss: 0.3468
# [Epoch 70] Step 150/737 - Loss: 0.2427
# [Epoch 70] Step 200/737 - Loss: 0.3219
# [Epoch 70] Step 250/737 - Loss: 0.4837
# [Epoch 70] Step 300/737 - Loss: 0.4136
# [Epoch 70] Step 350/737 - Loss: 0.2245
# [Epoch 70] Step 400/737 - Loss: 0.2912
# [Epoch 70] Step 450/737 - Loss: 0.3720
# [Epoch 70] Step 500/737 - Loss: 0.4101
# [Epoch 70] Step 550/737 - Loss: 0.2126
# [Epoch 70] Step 600/737 - Loss: 0.3726
# [Epoch 70] Step 650/737 - Loss: 0.2221
# [Epoch 70] Step 700/737 - Loss: 0.2559
# Epoch 070 | TrainLoss(step): 0.3664 | TrainLoss(eval): 0.3187 | ValLoss: 2.0159 | Train mIoU: 0.6377 | Val mIoU: 0.2960 | Val Dice: 2.9160 | Val F1: 0.4298 | Val Acc: 0.7455 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_70_wce.pth
#
# ===== Epoch 71/80 (resumed with weighted CE) =====
# [Epoch 71] Step 1/737 - Loss: 0.2407
# [Epoch 71] Step 50/737 - Loss: 0.2362
# [Epoch 71] Step 100/737 - Loss: 0.4067
# [Epoch 71] Step 150/737 - Loss: 0.7926
# [Epoch 71] Step 200/737 - Loss: 0.4640
# [Epoch 71] Step 250/737 - Loss: 0.4920
# [Epoch 71] Step 300/737 - Loss: 0.2435
# [Epoch 71] Step 350/737 - Loss: 0.2399
# [Epoch 71] Step 400/737 - Loss: 0.3851
# [Epoch 71] Step 450/737 - Loss: 0.1351
# [Epoch 71] Step 500/737 - Loss: 0.3270
# [Epoch 71] Step 550/737 - Loss: 0.4759
# [Epoch 71] Step 600/737 - Loss: 0.3472
# [Epoch 71] Step 650/737 - Loss: 0.3639
# [Epoch 71] Step 700/737 - Loss: 0.5702
# Epoch 071 | TrainLoss(step): 0.3660 | TrainLoss(eval): 0.3084 | ValLoss: 1.9265 | Train mIoU: 0.6289 | Val mIoU: 0.2960 | Val Dice: 2.9338 | Val F1: 0.4287 | Val Acc: 0.7364 | LR: 0.000000
#
# ===== Epoch 72/80 (resumed with weighted CE) =====
# [Epoch 72] Step 1/737 - Loss: 0.3407
# [Epoch 72] Step 50/737 - Loss: 0.1150
# [Epoch 72] Step 100/737 - Loss: 0.3105
# [Epoch 72] Step 150/737 - Loss: 0.2618
# [Epoch 72] Step 200/737 - Loss: 0.3360
# [Epoch 72] Step 250/737 - Loss: 0.4854
# [Epoch 72] Step 300/737 - Loss: 0.3863
# [Epoch 72] Step 350/737 - Loss: 0.5324
# [Epoch 72] Step 400/737 - Loss: 0.5082
# [Epoch 72] Step 450/737 - Loss: 0.5153
# [Epoch 72] Step 500/737 - Loss: 0.5784
# [Epoch 72] Step 550/737 - Loss: 0.4524
# [Epoch 72] Step 600/737 - Loss: 0.5063
# [Epoch 72] Step 650/737 - Loss: 0.8085
# [Epoch 72] Step 700/737 - Loss: 0.2429
# Epoch 072 | TrainLoss(step): 0.3635 | TrainLoss(eval): 0.3200 | ValLoss: 2.0651 | Train mIoU: 0.6408 | Val mIoU: 0.2976 | Val Dice: 2.9281 | Val F1: 0.4311 | Val Acc: 0.7473 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_72_wce.pth
#
# ===== Epoch 73/80 (resumed with weighted CE) =====
# [Epoch 73] Step 1/737 - Loss: 0.4051
# [Epoch 73] Step 50/737 - Loss: 0.4109
# [Epoch 73] Step 100/737 - Loss: 0.2426
# [Epoch 73] Step 150/737 - Loss: 0.2502
# [Epoch 73] Step 200/737 - Loss: 0.3850
# [Epoch 73] Step 250/737 - Loss: 0.2195
# [Epoch 73] Step 300/737 - Loss: 0.3027
# [Epoch 73] Step 350/737 - Loss: 0.3058
# [Epoch 73] Step 400/737 - Loss: 0.2392
# [Epoch 73] Step 450/737 - Loss: 0.2536
# [Epoch 73] Step 500/737 - Loss: 0.6378
# [Epoch 73] Step 550/737 - Loss: 0.5629
# [Epoch 73] Step 600/737 - Loss: 0.3331
# [Epoch 73] Step 650/737 - Loss: 0.1525
# [Epoch 73] Step 700/737 - Loss: 0.2969
# Epoch 073 | TrainLoss(step): 0.3597 | TrainLoss(eval): 0.3176 | ValLoss: 1.9806 | Train mIoU: 0.6462 | Val mIoU: 0.2999 | Val Dice: 2.9245 | Val F1: 0.4348 | Val Acc: 0.7442 | LR: 0.000000
#
# ===== Epoch 74/80 (resumed with weighted CE) =====
# [Epoch 74] Step 1/737 - Loss: 0.3243
# [Epoch 74] Step 50/737 - Loss: 0.7716
# [Epoch 74] Step 100/737 - Loss: 0.3385
# [Epoch 74] Step 150/737 - Loss: 0.3533
# [Epoch 74] Step 200/737 - Loss: 0.3026
# [Epoch 74] Step 250/737 - Loss: 0.4107
# [Epoch 74] Step 300/737 - Loss: 0.4001
# [Epoch 74] Step 350/737 - Loss: 0.5840
# [Epoch 74] Step 400/737 - Loss: 0.3896
# [Epoch 74] Step 450/737 - Loss: 0.2166
# [Epoch 74] Step 500/737 - Loss: 0.2773
# [Epoch 74] Step 550/737 - Loss: 0.3989
# [Epoch 74] Step 600/737 - Loss: 0.2905
# [Epoch 74] Step 650/737 - Loss: 0.4665
# [Epoch 74] Step 700/737 - Loss: 0.1669
# Epoch 074 | TrainLoss(step): 0.3614 | TrainLoss(eval): 0.3152 | ValLoss: 2.0047 | Train mIoU: 0.6354 | Val mIoU: 0.2969 | Val Dice: 2.9267 | Val F1: 0.4296 | Val Acc: 0.7418 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_74_wce.pth
#
# ===== Epoch 75/80 (resumed with weighted CE) =====
# [Epoch 75] Step 1/737 - Loss: 0.5894
# [Epoch 75] Step 50/737 - Loss: 0.4211
# [Epoch 75] Step 100/737 - Loss: 0.4089
# [Epoch 75] Step 150/737 - Loss: 0.3958
# [Epoch 75] Step 200/737 - Loss: 0.3230
# [Epoch 75] Step 250/737 - Loss: 0.2722
# [Epoch 75] Step 300/737 - Loss: 0.2140
# [Epoch 75] Step 350/737 - Loss: 0.5063
# [Epoch 75] Step 400/737 - Loss: 0.1959
# [Epoch 75] Step 450/737 - Loss: 0.3921
# [Epoch 75] Step 500/737 - Loss: 0.2818
# [Epoch 75] Step 550/737 - Loss: 0.4282
# [Epoch 75] Step 600/737 - Loss: 0.2024
# [Epoch 75] Step 650/737 - Loss: 0.3967
# [Epoch 75] Step 700/737 - Loss: 0.4580
# Epoch 075 | TrainLoss(step): 0.3609 | TrainLoss(eval): 0.3102 | ValLoss: 1.9598 | Train mIoU: 0.6211 | Val mIoU: 0.2919 | Val Dice: 2.9237 | Val F1: 0.4243 | Val Acc: 0.7357 | LR: 0.000000
#
# ===== Epoch 76/80 (resumed with weighted CE) =====
# [Epoch 76] Step 1/737 - Loss: 0.3198
# [Epoch 76] Step 50/737 - Loss: 0.4203
# [Epoch 76] Step 100/737 - Loss: 0.5582
# [Epoch 76] Step 150/737 - Loss: 0.4108
# [Epoch 76] Step 200/737 - Loss: 0.5417
# [Epoch 76] Step 250/737 - Loss: 0.6993
# [Epoch 76] Step 300/737 - Loss: 0.9359
# [Epoch 76] Step 350/737 - Loss: 0.4987
# [Epoch 76] Step 400/737 - Loss: 0.4402
# [Epoch 76] Step 450/737 - Loss: 0.1534
# [Epoch 76] Step 500/737 - Loss: 0.3540
# [Epoch 76] Step 550/737 - Loss: 0.2552
# [Epoch 76] Step 600/737 - Loss: 0.6198
# [Epoch 76] Step 650/737 - Loss: 0.3973
# [Epoch 76] Step 700/737 - Loss: 0.2322
# Epoch 076 | TrainLoss(step): 0.3674 | TrainLoss(eval): 0.3146 | ValLoss: 1.9868 | Train mIoU: 0.6360 | Val mIoU: 0.2979 | Val Dice: 2.9297 | Val F1: 0.4319 | Val Acc: 0.7419 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_76_wce.pth
#
# ===== Epoch 77/80 (resumed with weighted CE) =====
# [Epoch 77] Step 1/737 - Loss: 0.3871
# [Epoch 77] Step 50/737 - Loss: 0.5391
# [Epoch 77] Step 100/737 - Loss: 0.4483
# [Epoch 77] Step 150/737 - Loss: 0.2945
# [Epoch 77] Step 200/737 - Loss: 0.3896
# [Epoch 77] Step 250/737 - Loss: 0.7602
# [Epoch 77] Step 300/737 - Loss: 0.3462
# [Epoch 77] Step 350/737 - Loss: 0.4300
# [Epoch 77] Step 400/737 - Loss: 0.3427
# [Epoch 77] Step 450/737 - Loss: 0.4092
# [Epoch 77] Step 500/737 - Loss: 0.3290
# [Epoch 77] Step 550/737 - Loss: 0.4007
# [Epoch 77] Step 600/737 - Loss: 0.3399
# [Epoch 77] Step 650/737 - Loss: 0.2995
# [Epoch 77] Step 700/737 - Loss: 0.4214
# Epoch 077 | TrainLoss(step): 0.3604 | TrainLoss(eval): 0.3101 | ValLoss: 1.9670 | Train mIoU: 0.6264 | Val mIoU: 0.2918 | Val Dice: 2.9082 | Val F1: 0.4255 | Val Acc: 0.7353 | LR: 0.000000
#
# ===== Epoch 78/80 (resumed with weighted CE) =====
# [Epoch 78] Step 1/737 - Loss: 0.7288
# [Epoch 78] Step 50/737 - Loss: 0.4422
# [Epoch 78] Step 100/737 - Loss: 0.3983
# [Epoch 78] Step 150/737 - Loss: 0.2184
# [Epoch 78] Step 200/737 - Loss: 0.3121
# [Epoch 78] Step 250/737 - Loss: 0.4542
# [Epoch 78] Step 300/737 - Loss: 0.4109
# [Epoch 78] Step 350/737 - Loss: 0.1792
# [Epoch 78] Step 400/737 - Loss: 0.4439
# [Epoch 78] Step 450/737 - Loss: 0.3752
# [Epoch 78] Step 500/737 - Loss: 0.4321
# [Epoch 78] Step 550/737 - Loss: 0.1828
# [Epoch 78] Step 600/737 - Loss: 0.2491
# [Epoch 78] Step 650/737 - Loss: 0.2196
# [Epoch 78] Step 700/737 - Loss: 0.5388
# Epoch 078 | TrainLoss(step): 0.3634 | TrainLoss(eval): 0.3095 | ValLoss: 2.0414 | Train mIoU: 0.6281 | Val mIoU: 0.2936 | Val Dice: 2.8651 | Val F1: 0.4253 | Val Acc: 0.7445 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_78_wce.pth
#
# ===== Epoch 79/80 (resumed with weighted CE) =====
# [Epoch 79] Step 1/737 - Loss: 0.4304
# [Epoch 79] Step 50/737 - Loss: 0.3670
# [Epoch 79] Step 100/737 - Loss: 0.4600
# [Epoch 79] Step 150/737 - Loss: 0.1454
# [Epoch 79] Step 200/737 - Loss: 0.2973
# [Epoch 79] Step 250/737 - Loss: 0.3102
# [Epoch 79] Step 300/737 - Loss: 0.2265
# [Epoch 79] Step 350/737 - Loss: 0.2546
# [Epoch 79] Step 400/737 - Loss: 0.6524
# [Epoch 79] Step 450/737 - Loss: 0.2520
# [Epoch 79] Step 500/737 - Loss: 0.2080
# [Epoch 79] Step 550/737 - Loss: 0.3227
# [Epoch 79] Step 600/737 - Loss: 0.3746
# [Epoch 79] Step 650/737 - Loss: 0.5309
# [Epoch 79] Step 700/737 - Loss: 0.1671
# Epoch 079 | TrainLoss(step): 0.3621 | TrainLoss(eval): 0.3065 | ValLoss: 1.9635 | Train mIoU: 0.6322 | Val mIoU: 0.2943 | Val Dice: 2.9091 | Val F1: 0.4277 | Val Acc: 0.7407 | LR: 0.000000
#
# ===== Epoch 80/80 (resumed with weighted CE) =====
# [Epoch 80] Step 1/737 - Loss: 0.3187
# [Epoch 80] Step 50/737 - Loss: 0.2742
# [Epoch 80] Step 100/737 - Loss: 0.4300
# [Epoch 80] Step 150/737 - Loss: 0.7744
# [Epoch 80] Step 200/737 - Loss: 0.2446
# [Epoch 80] Step 250/737 - Loss: 0.2879
# [Epoch 80] Step 300/737 - Loss: 0.2313
# [Epoch 80] Step 350/737 - Loss: 0.3506
# [Epoch 80] Step 400/737 - Loss: 0.2887
# [Epoch 80] Step 450/737 - Loss: 0.2802
# [Epoch 80] Step 500/737 - Loss: 0.4336
# [Epoch 80] Step 550/737 - Loss: 0.5419
# [Epoch 80] Step 600/737 - Loss: 0.5152
# [Epoch 80] Step 650/737 - Loss: 0.7768
# [Epoch 80] Step 700/737 - Loss: 0.4007
# Epoch 080 | TrainLoss(step): 0.3623 | TrainLoss(eval): 0.3029 | ValLoss: 1.9371 | Train mIoU: 0.6116 | Val mIoU: 0.2884 | Val Dice: 2.9176 | Val F1: 0.4192 | Val Acc: 0.7293 | LR: 0.000000
#   -> Checkpoint saved to deeplab_checkpoint_epoch_80_wce.pth
#
# Training complete. Best mIoU: 0.3138713240623474
# Saved metrics to: /kaggle/working/deeplab_results_wce.json
# /kaggle/working/deeplab_results_wce.json
