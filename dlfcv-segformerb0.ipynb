# %% [markdown]
# # **Imports**

# %%
# !pip install -q segmentation-models-pytorch torchmetrics transformers timm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.6 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.3 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.0 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.

# %%
import json
from pathlib import Path

import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset

import segmentation_models_pytorch as smp
from torchmetrics import JaccardIndex, Accuracy, F1Score
from torchmetrics.segmentation import DiceScore
from torchvision import transforms
from torchvision.transforms import InterpolationMode
from torch.amp import GradScaler, autocast

from transformers import SegformerForSemanticSegmentation

import torch.nn.functional as F

from PIL import Image
import numpy as np

from IPython.display import FileLink

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# # **Setup**

# %% [markdown]
# ## **Dataset**

# %%
# Initial setup
DATA_ROOT = Path("/kaggle/input/data-clean")
IMG_DIR = DATA_ROOT / "images"
MSK_DIR = DATA_ROOT / "masks"

train_img_dir = IMG_DIR / "train"
val_img_dir   = IMG_DIR / "validation"
test_img_dir  = IMG_DIR / "test"

train_msk_dir = MSK_DIR / "train"
val_msk_dir   = MSK_DIR / "validation"
test_msk_dir  = MSK_DIR / "test"

CONFIG = {
    "experiment_name": "segformer_b0_dacl10k_512",
    "model": "SegFormer-B0",
    "encoder": "segformer-b0",      # just for bookkeeping
    "encoder_weights": "ade20k",    # pretraining source (informational)
    "num_classes": 14,
    "image_size": [512, 512],
    "batch_size": 4,                # SegFormer is heavier; start with 4
    "epochs": 40,
    "learning_rate": 6e-5,          # SegFormer defaults are small (1e-4–6e-5)
    "loss": "CrossEntropyLoss",
    "optimizer": "AdamW",           # typical for transformers
    "scheduler": "ReduceLROnPlateau",
    "metrics": [
        "mean_iou",
        "f1_macro",
        "global_pixel_accuracy",
    ],
}


NUM_CLASSES = CONFIG["num_classes"]
BATCH_SIZE  = CONFIG["batch_size"]
EPOCHS      = CONFIG["epochs"]
LR          = CONFIG["learning_rate"]
IMAGE_SIZE  = CONFIG["image_size"]

# %%
# Dataset setup
class Dacl10kDataset(Dataset):
    def __init__(self, img_dir, msk_dir, image_size=(512, 512)):
        self.img_dir = Path(img_dir)
        self.msk_dir = Path(msk_dir)
        self.image_size = image_size

        self.img_paths = sorted([p for p in self.img_dir.iterdir()])

        # Transformations for training images
        self.img_transform = transforms.Compose([
            transforms.Resize(self.image_size, interpolation=transforms.InterpolationMode.BILINEAR),
            transforms.ToTensor(),
            transforms.Normalize(  # Normalize each channel with ImageNet normalization values
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
        ])

        self.mask_resize = transforms.Resize(
            self.image_size,
            interpolation=transforms.InterpolationMode.NEAREST, # Change interpolation value to keep integers
        )

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        msk_path = self.msk_dir / img_path.name.replace("jpg", "png") # same filename, jpg -> png

        # Image
        img = Image.open(img_path).convert("RGB")
        img = self.img_transform(img)

        # Mask
        mask = Image.open(msk_path)
        mask = self.mask_resize(mask)
        mask = torch.from_numpy(np.array(mask, dtype=np.int64))  # [H, W] long with 0..13

        return img, mask

# %%
# Dataset definition
train_dataset = Dacl10kDataset(train_img_dir, train_msk_dir, IMAGE_SIZE)
val_dataset   = Dacl10kDataset(val_img_dir,   val_msk_dir,   IMAGE_SIZE)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2,
    pin_memory=True,
)

print("Train samples:", len(train_dataset), " | batches:", len(train_loader))
print("Val samples:  ", len(val_dataset),   " | batches:", len(val_loader))
# Out:
# Train samples: 5895  | batches: 1474
# Val samples:   1040  | batches: 260

# %% [markdown]
# ## **Model, loss, optimizer, metrics**

# %%
# Model
id2label = {i: f"class_{i}" for i in range(NUM_CLASSES)}  # or use real names
label2id = {v: k for k, v in id2label.items()}

model = SegformerForSemanticSegmentation.from_pretrained(
    "nvidia/segformer-b0-finetuned-ade-512-512",
    num_labels=NUM_CLASSES,
    id2label=id2label,
    label2id=label2id,
    ignore_mismatched_sizes=True,  # head resized from 150 -> 14
).to(device)


# Otimizer and scheduler. Scheduler will decrease learning rate bu half when val_loss does not improve fort 3 epochs
optimizer = torch.optim.AdamW(model.parameters(), lr=CONFIG["learning_rate"])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=3,
    verbose=True,
)

# Metrics
# 1) Mean IoU per class (Jaccard)
miou_metric = JaccardIndex(
    task="multiclass",
    num_classes=NUM_CLASSES,
    average="macro"
).to(device)

# 2) Dice score (macro over classes)
dice_metric = DiceScore(
    num_classes=NUM_CLASSES,
    include_background=True,      # or False if you want to drop class 0
    average="macro",               # scalar
    input_format="index",         # <-- IMPORTANT
    aggregation_level="global",   # accumulate over dataset
).to(device)

# 3) F1 Score (macro over classes)
f1_metric = F1Score(
    task="multiclass",
    num_classes=NUM_CLASSES,
    average="macro",
).to(device)

# 4) Global Pixel Accuracy
acc_metric = Accuracy(
    task="multiclass",
    num_classes=NUM_CLASSES,
).to(device)

print("SegFormerB0 params (M):", sum(p.numel() for p in model.parameters()) / 1e6)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/15.0M [00:00<?, ?B/s]
# Some weights of SegformerForSemanticSegmentation were not initialized from the model checkpoint at nvidia/segformer-b0-finetuned-ade-512-512 and are newly initialized because the shapes did not match:
# - decode_head.classifier.bias: found shape torch.Size([150]) in the checkpoint and torch.Size([14]) in the model instantiated
# - decode_head.classifier.weight: found shape torch.Size([150, 256, 1, 1]) in the checkpoint and torch.Size([14, 256, 1, 1]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# SegFormerB0 params (M): 3.717742

# %%
scaler = GradScaler(enabled=(device.type == "cuda")) # Uses AMP to speed up training

CHECKPOINT_EVERY = 2  # epochs

def train_one_epoch(model, loader, optimizer, epoch):
    model.train() # set model to training mode
    running_loss = 0.0 # start total loss at 0.0

    for step, (images, masks) in enumerate(loader, start=1):
        images = images.to(device, non_blocking=True)
        masks  = masks.to(device, non_blocking=True)

        optimizer.zero_grad() # zero the gradients

         # Uses AMP to speed up training
        with autocast(device_type="cuda", enabled=(device.type == "cuda")):
            # SegFormer computes CE loss internally if you pass labels
            outputs = model(pixel_values=images, labels=masks)
            loss = outputs.loss    # scalar

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item() # add losses in each step

        if step % 50 == 0 or step == 1:
            print(f"[Epoch {epoch}] Step {step}/{len(loader)} - Loss: {loss.item():.4f}")

    return running_loss / len(loader) # return mean loss across an epoch


@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    val_loss = 0.0

    # Reset metrics each evaluation
    miou_metric.reset()
    dice_metric.reset()
    f1_metric.reset()
    acc_metric.reset()

    for images, masks in loader:
        images = images.to(device, non_blocking=True)
        masks  = masks.to(device, non_blocking=True)

        # Uses AMP to speed up training
        with autocast(device_type="cuda", enabled=(device.type == "cuda")):
            outputs = model(pixel_values=images, labels=masks)
            loss = outputs.loss      # scalar
            logits = outputs.logits  # [B, num_labels, H/4, W/4]

        val_loss += loss.item()

        # Upsample logits back to mask size (512x512) for metrics
        logits_upsampled = F.interpolate(
            logits,
            size=masks.shape[-2:],      # (H, W)
            mode="bilinear",
            align_corners=False,
        )

        preds = torch.argmax(logits_upsampled, dim=1)  # [B,H,W]

        # Update metrics 
        miou_metric.update(preds, masks)
        dice_metric.update(preds, masks)
        f1_metric.update(preds, masks)
        acc_metric.update(preds, masks)

    val_loss /= len(loader) # compute mean loss

    miou = miou_metric.compute().item()   # mean IoU per class
    dice = dice_metric.compute().item()   # macro Dice
    mf1  = f1_metric.compute().item()     # macro F1
    acc  = acc_metric.compute().item()    # global pixel accuracy

    return val_loss, miou, dice, mf1, acc

# %% [markdown]
# # **Train**

# %%
history = [] 
best_miou = 0.0

for epoch in range(1, EPOCHS + 1):
    print(f"\n===== Epoch {epoch}/{EPOCHS} =====")

    # Training epoch
    train_loss = train_one_epoch(model, train_loader, optimizer, epoch)

    # Metrics for train and validation sets
    train_loss_eval, train_miou, train_dice, train_f1, train_acc = evaluate(model, train_loader)
    val_loss, val_miou, val_dice, val_f1, val_acc = evaluate(model, val_loader)

    # step scheduler on val_loss
    scheduler.step(val_loss)

    current_lr = optimizer.param_groups[0]["lr"]
    
    print(
        f"Epoch {epoch:03d} | "
        f"TrainLoss(step): {train_loss:.4f} | "
        f"TrainLoss(eval): {train_loss_eval:.4f} | "
        f"ValLoss: {val_loss:.4f} | "
        f"Train mIoU: {train_miou:.4f} | "
        f"Val mIoU: {val_miou:.4f} | "
        f"Val Dice: {val_dice:.4f} | "
        f"Val F1: {val_f1:.4f} | "
        f"Val Acc: {val_acc:.4f} | "
        f"LR: {current_lr:.6f}"
    )

    # Store metrics
    history.append({
        "epoch": epoch,
        # training loss from the actual training loop
        "train_loss_step": float(train_loss),
        # training loss recomputed in eval mode (no dropout, BN in eval)
        "train_loss_eval": float(train_loss_eval),
        "train_miou": float(train_miou),
        "train_dice": float(train_dice),
        "train_f1_macro": float(train_f1),
        "train_global_pixel_accuracy": float(train_acc),
        "val_loss": float(val_loss),
        "val_miou": float(val_miou),
        "val_dice": float(val_dice),
        "val_f1_macro": float(val_f1),
        "val_global_pixel_accuracy": float(val_acc),
        "lr": float(current_lr),
    })

    # save best model by mIoU
    if val_miou > best_miou:
        best_miou = val_miou
        torch.save(model.state_dict(), "segformer_best_miou.pth")
        print("  -> New best mIoU; weights saved to segformer_best_miou.pth")

    # periodic full checkpoint save
    if epoch % CHECKPOINT_EVERY == 0:
        ckpt_path = f"segformer_checkpoint_epoch_{epoch}.pth"
        torch.save({
            "config": CONFIG,
            "epoch": epoch,
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "scheduler_state_dict": scheduler.state_dict(),
            "best_miou": best_miou,
            "history": history,
        }, ckpt_path)
        print(f"  -> Checkpoint saved to {ckpt_path}")

# final "last" checkpoint
torch.save({
    "config": CONFIG,
    "epoch": EPOCHS,
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "scheduler_state_dict": scheduler.state_dict(),
    "best_miou": best_miou,
    "history": history,
}, "segformer_last.pth")

print("\nTraining complete. Best mIoU:", best_miou)

# Store training logs in JSON format

output_path = Path("/kaggle/working/segformer_results.json")

results = {
    "config": CONFIG,
    "history": history,
}

with open(output_path, "w") as f:
    json.dump(results, f, indent=2)

print("Saved metrics to:", output_path)

# Download link for results
FileLink('/kaggle/working/segformer_results.json')
# Out:
# ===== Epoch 1/40 =====
# [Epoch 1] Step 1/1474 - Loss: 2.6916
# [Epoch 1] Step 50/1474 - Loss: 2.3649
# [Epoch 1] Step 100/1474 - Loss: 1.8830
# [Epoch 1] Step 150/1474 - Loss: 1.6227
# [Epoch 1] Step 200/1474 - Loss: 1.2534
# [Epoch 1] Step 250/1474 - Loss: 0.9543
# [Epoch 1] Step 300/1474 - Loss: 1.4341
# [Epoch 1] Step 350/1474 - Loss: 1.1236
# [Epoch 1] Step 400/1474 - Loss: 0.8278
# [Epoch 1] Step 450/1474 - Loss: 0.7750
# [Epoch 1] Step 500/1474 - Loss: 0.5660
# [Epoch 1] Step 550/1474 - Loss: 1.4163
# [Epoch 1] Step 600/1474 - Loss: 1.6932
# [Epoch 1] Step 650/1474 - Loss: 1.1965
# [Epoch 1] Step 700/1474 - Loss: 1.2037
# [Epoch 1] Step 750/1474 - Loss: 0.5148
# [Epoch 1] Step 800/1474 - Loss: 0.4693
# [Epoch 1] Step 850/1474 - Loss: 1.5832
# [Epoch 1] Step 900/1474 - Loss: 0.5555
# [Epoch 1] Step 950/1474 - Loss: 0.6670
# [Epoch 1] Step 1000/1474 - Loss: 0.9260
# [Epoch 1] Step 1050/1474 - Loss: 0.6068
# [Epoch 1] Step 1100/1474 - Loss: 0.6969
# [Epoch 1] Step 1150/1474 - Loss: 1.4538
# [Epoch 1] Step 1200/1474 - Loss: 0.7707
# [Epoch 1] Step 1250/1474 - Loss: 0.9808
# [Epoch 1] Step 1300/1474 - Loss: 0.5279
# [Epoch 1] Step 1350/1474 - Loss: 1.3980
# [Epoch 1] Step 1400/1474 - Loss: 0.6908
# [Epoch 1] Step 1450/1474 - Loss: 1.3202
# Epoch 001 | TrainLoss(step): 1.0940 | TrainLoss(eval): 0.7730 | ValLoss: 0.8133 | Train mIoU: 0.1321 | Val mIoU: 0.1215 | Val Dice: 0.1686 | Val F1: 0.1686 | Val Acc: 0.7661 | LR: 0.000060
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#
# ===== Epoch 2/40 =====
# [Epoch 2] Step 1/1474 - Loss: 0.9299
# [Epoch 2] Step 50/1474 - Loss: 0.7717
# [Epoch 2] Step 100/1474 - Loss: 0.6248
# [Epoch 2] Step 150/1474 - Loss: 0.4089
# [Epoch 2] Step 200/1474 - Loss: 1.2783
# [Epoch 2] Step 250/1474 - Loss: 0.9496
# [Epoch 2] Step 300/1474 - Loss: 0.4929
# [Epoch 2] Step 350/1474 - Loss: 0.4919
# [Epoch 2] Step 400/1474 - Loss: 0.4584
# [Epoch 2] Step 450/1474 - Loss: 1.0067
# [Epoch 2] Step 500/1474 - Loss: 0.8508
# [Epoch 2] Step 550/1474 - Loss: 1.1025
# [Epoch 2] Step 600/1474 - Loss: 0.8034
# [Epoch 2] Step 650/1474 - Loss: 0.7861
# [Epoch 2] Step 700/1474 - Loss: 0.7509
# [Epoch 2] Step 750/1474 - Loss: 0.9200
# [Epoch 2] Step 800/1474 - Loss: 0.6291
# [Epoch 2] Step 850/1474 - Loss: 1.1875
# [Epoch 2] Step 900/1474 - Loss: 0.4507
# [Epoch 2] Step 950/1474 - Loss: 1.0709
# [Epoch 2] Step 1000/1474 - Loss: 1.2586
# [Epoch 2] Step 1050/1474 - Loss: 1.1692
# [Epoch 2] Step 1100/1474 - Loss: 0.8653
# [Epoch 2] Step 1150/1474 - Loss: 0.8178
# [Epoch 2] Step 1200/1474 - Loss: 0.7429
# [Epoch 2] Step 1250/1474 - Loss: 0.5381
# [Epoch 2] Step 1300/1474 - Loss: 0.7305
# [Epoch 2] Step 1350/1474 - Loss: 0.5084
# [Epoch 2] Step 1400/1474 - Loss: 1.4112
# [Epoch 2] Step 1450/1474 - Loss: 0.3409
# Epoch 002 | TrainLoss(step): 0.7895 | TrainLoss(eval): 0.6880 | ValLoss: 0.7685 | Train mIoU: 0.1910 | Val mIoU: 0.1623 | Val Dice: 0.2283 | Val F1: 0.2283 | Val Acc: 0.7530 | LR: 0.000060
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#   -> Checkpoint saved to segformer_checkpoint_epoch_2.pth
#
# ===== Epoch 3/40 =====
# [Epoch 3] Step 1/1474 - Loss: 0.4817
# [Epoch 3] Step 50/1474 - Loss: 0.5639
# [Epoch 3] Step 100/1474 - Loss: 0.5459
# [Epoch 3] Step 150/1474 - Loss: 0.7491
# [Epoch 3] Step 200/1474 - Loss: 0.4314
# [Epoch 3] Step 250/1474 - Loss: 0.4624
# [Epoch 3] Step 300/1474 - Loss: 0.4453
# [Epoch 3] Step 350/1474 - Loss: 0.3142
# [Epoch 3] Step 400/1474 - Loss: 0.5438
# [Epoch 3] Step 450/1474 - Loss: 0.3762
# [Epoch 3] Step 500/1474 - Loss: 0.5641
# [Epoch 3] Step 550/1474 - Loss: 0.9342
# [Epoch 3] Step 600/1474 - Loss: 0.9122
# [Epoch 3] Step 650/1474 - Loss: 0.3950
# [Epoch 3] Step 700/1474 - Loss: 0.4993
# [Epoch 3] Step 750/1474 - Loss: 1.0697
# [Epoch 3] Step 800/1474 - Loss: 1.3818
# [Epoch 3] Step 850/1474 - Loss: 0.3385
# [Epoch 3] Step 900/1474 - Loss: 0.4252
# [Epoch 3] Step 950/1474 - Loss: 0.9637
# [Epoch 3] Step 1000/1474 - Loss: 1.0275
# [Epoch 3] Step 1050/1474 - Loss: 0.6171
# [Epoch 3] Step 1100/1474 - Loss: 0.9845
# [Epoch 3] Step 1150/1474 - Loss: 1.1941
# [Epoch 3] Step 1200/1474 - Loss: 0.8850
# [Epoch 3] Step 1250/1474 - Loss: 0.3491
# [Epoch 3] Step 1300/1474 - Loss: 0.4199
# [Epoch 3] Step 1350/1474 - Loss: 0.8249
# [Epoch 3] Step 1400/1474 - Loss: 1.5905
# [Epoch 3] Step 1450/1474 - Loss: 0.3208
# Epoch 003 | TrainLoss(step): 0.7135 | TrainLoss(eval): 0.6102 | ValLoss: 0.7107 | Train mIoU: 0.2271 | Val mIoU: 0.1899 | Val Dice: 0.2656 | Val F1: 0.2656 | Val Acc: 0.7806 | LR: 0.000060
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#
# ===== Epoch 4/40 =====
# [Epoch 4] Step 1/1474 - Loss: 0.3788
# [Epoch 4] Step 50/1474 - Loss: 0.6108
# [Epoch 4] Step 100/1474 - Loss: 0.6900
# [Epoch 4] Step 150/1474 - Loss: 0.3309
# [Epoch 4] Step 200/1474 - Loss: 0.5063
# [Epoch 4] Step 250/1474 - Loss: 0.8976
# [Epoch 4] Step 300/1474 - Loss: 0.4777
# [Epoch 4] Step 350/1474 - Loss: 0.3850
# [Epoch 4] Step 400/1474 - Loss: 0.4219
# [Epoch 4] Step 450/1474 - Loss: 0.5682
# [Epoch 4] Step 500/1474 - Loss: 0.3024
# [Epoch 4] Step 550/1474 - Loss: 1.1959
# [Epoch 4] Step 600/1474 - Loss: 0.4512
# [Epoch 4] Step 650/1474 - Loss: 0.3060
# [Epoch 4] Step 700/1474 - Loss: 0.4377
# [Epoch 4] Step 750/1474 - Loss: 0.6904
# [Epoch 4] Step 800/1474 - Loss: 1.2068
# [Epoch 4] Step 850/1474 - Loss: 0.9985
# [Epoch 4] Step 900/1474 - Loss: 0.6020
# [Epoch 4] Step 950/1474 - Loss: 0.4425
# [Epoch 4] Step 1000/1474 - Loss: 0.5446
# [Epoch 4] Step 1050/1474 - Loss: 0.4023
# [Epoch 4] Step 1100/1474 - Loss: 0.6485
# [Epoch 4] Step 1150/1474 - Loss: 0.5345
# [Epoch 4] Step 1200/1474 - Loss: 0.9557
# [Epoch 4] Step 1250/1474 - Loss: 0.5155
# [Epoch 4] Step 1300/1474 - Loss: 1.9824
# [Epoch 4] Step 1350/1474 - Loss: 0.6479
# [Epoch 4] Step 1400/1474 - Loss: 0.4087
# [Epoch 4] Step 1450/1474 - Loss: 0.3914
# Epoch 004 | TrainLoss(step): 0.6606 | TrainLoss(eval): 0.5397 | ValLoss: 0.6826 | Train mIoU: 0.2741 | Val mIoU: 0.2221 | Val Dice: 0.3155 | Val F1: 0.3155 | Val Acc: 0.7884 | LR: 0.000060
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#   -> Checkpoint saved to segformer_checkpoint_epoch_4.pth
#
# ===== Epoch 5/40 =====
# [Epoch 5] Step 1/1474 - Loss: 0.7085
# [Epoch 5] Step 50/1474 - Loss: 0.3027
# [Epoch 5] Step 100/1474 - Loss: 0.3216
# [Epoch 5] Step 150/1474 - Loss: 0.3858
# [Epoch 5] Step 200/1474 - Loss: 0.4703
# [Epoch 5] Step 250/1474 - Loss: 0.3100
# [Epoch 5] Step 300/1474 - Loss: 0.3957
# [Epoch 5] Step 350/1474 - Loss: 0.4669
# [Epoch 5] Step 400/1474 - Loss: 0.3690
# [Epoch 5] Step 450/1474 - Loss: 0.5776
# [Epoch 5] Step 500/1474 - Loss: 0.4741
# [Epoch 5] Step 550/1474 - Loss: 0.3648
# [Epoch 5] Step 600/1474 - Loss: 0.8061
# [Epoch 5] Step 650/1474 - Loss: 0.4406
# [Epoch 5] Step 700/1474 - Loss: 0.5023
# [Epoch 5] Step 750/1474 - Loss: 0.3250
# [Epoch 5] Step 800/1474 - Loss: 0.3604
# [Epoch 5] Step 850/1474 - Loss: 0.8013
# [Epoch 5] Step 900/1474 - Loss: 0.2770
# [Epoch 5] Step 950/1474 - Loss: 0.4328
# [Epoch 5] Step 1000/1474 - Loss: 0.3629
# [Epoch 5] Step 1050/1474 - Loss: 0.7893
# [Epoch 5] Step 1100/1474 - Loss: 1.3302
# [Epoch 5] Step 1150/1474 - Loss: 0.4481
# [Epoch 5] Step 1200/1474 - Loss: 0.3372
# [Epoch 5] Step 1250/1474 - Loss: 0.9674
# [Epoch 5] Step 1300/1474 - Loss: 0.5184
# [Epoch 5] Step 1350/1474 - Loss: 0.6511
# [Epoch 5] Step 1400/1474 - Loss: 0.3373
# [Epoch 5] Step 1450/1474 - Loss: 0.5258
# Epoch 005 | TrainLoss(step): 0.6044 | TrainLoss(eval): 0.4945 | ValLoss: 0.6954 | Train mIoU: 0.3144 | Val mIoU: 0.2407 | Val Dice: 0.3361 | Val F1: 0.3361 | Val Acc: 0.7811 | LR: 0.000060
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#
# ===== Epoch 6/40 =====
# [Epoch 6] Step 1/1474 - Loss: 0.6515
# [Epoch 6] Step 50/1474 - Loss: 0.3146
# [Epoch 6] Step 100/1474 - Loss: 0.3867
# [Epoch 6] Step 150/1474 - Loss: 0.5905
# [Epoch 6] Step 200/1474 - Loss: 1.4456
# [Epoch 6] Step 250/1474 - Loss: 0.3711
# [Epoch 6] Step 300/1474 - Loss: 0.4461
# [Epoch 6] Step 350/1474 - Loss: 0.8898
# [Epoch 6] Step 400/1474 - Loss: 0.3444
# [Epoch 6] Step 450/1474 - Loss: 0.8738
# [Epoch 6] Step 500/1474 - Loss: 0.5911
# [Epoch 6] Step 550/1474 - Loss: 0.4449
# [Epoch 6] Step 600/1474 - Loss: 0.2964
# [Epoch 6] Step 650/1474 - Loss: 0.2105
# [Epoch 6] Step 700/1474 - Loss: 0.4241
# [Epoch 6] Step 750/1474 - Loss: 0.6636
# [Epoch 6] Step 800/1474 - Loss: 0.7804
# [Epoch 6] Step 850/1474 - Loss: 0.9598
# [Epoch 6] Step 900/1474 - Loss: 0.3950
# [Epoch 6] Step 950/1474 - Loss: 0.7324
# [Epoch 6] Step 1000/1474 - Loss: 0.9314
# [Epoch 6] Step 1050/1474 - Loss: 0.8044
# [Epoch 6] Step 1100/1474 - Loss: 0.7471
# [Epoch 6] Step 1150/1474 - Loss: 0.7471
# [Epoch 6] Step 1200/1474 - Loss: 0.6657
# [Epoch 6] Step 1250/1474 - Loss: 0.4929
# [Epoch 6] Step 1300/1474 - Loss: 0.7613
# [Epoch 6] Step 1350/1474 - Loss: 0.9732
# [Epoch 6] Step 1400/1474 - Loss: 0.4721
# [Epoch 6] Step 1450/1474 - Loss: 0.4211
# Epoch 006 | TrainLoss(step): 0.5624 | TrainLoss(eval): 0.4590 | ValLoss: 0.7271 | Train mIoU: 0.3322 | Val mIoU: 0.2307 | Val Dice: 0.3262 | Val F1: 0.3262 | Val Acc: 0.7697 | LR: 0.000060
#   -> Checkpoint saved to segformer_checkpoint_epoch_6.pth
#
# ===== Epoch 7/40 =====
# [Epoch 7] Step 1/1474 - Loss: 0.7240
# [Epoch 7] Step 50/1474 - Loss: 0.4257
# [Epoch 7] Step 100/1474 - Loss: 0.5409
# [Epoch 7] Step 150/1474 - Loss: 0.5702
# [Epoch 7] Step 200/1474 - Loss: 0.3097
# [Epoch 7] Step 250/1474 - Loss: 0.3360
# [Epoch 7] Step 300/1474 - Loss: 0.8033
# [Epoch 7] Step 350/1474 - Loss: 0.6392
# [Epoch 7] Step 400/1474 - Loss: 0.3166
# [Epoch 7] Step 450/1474 - Loss: 0.3632
# [Epoch 7] Step 500/1474 - Loss: 0.6083
# [Epoch 7] Step 550/1474 - Loss: 0.3402
# [Epoch 7] Step 600/1474 - Loss: 0.2945
# [Epoch 7] Step 650/1474 - Loss: 0.3740
# [Epoch 7] Step 700/1474 - Loss: 0.1795
# [Epoch 7] Step 750/1474 - Loss: 0.6006
# [Epoch 7] Step 800/1474 - Loss: 0.5498
# [Epoch 7] Step 850/1474 - Loss: 0.2372
# [Epoch 7] Step 900/1474 - Loss: 0.4812
# [Epoch 7] Step 950/1474 - Loss: 1.1616
# [Epoch 7] Step 1000/1474 - Loss: 0.5810
# [Epoch 7] Step 1050/1474 - Loss: 0.4017
# [Epoch 7] Step 1100/1474 - Loss: 0.5228
# [Epoch 7] Step 1150/1474 - Loss: 0.2427
# [Epoch 7] Step 1200/1474 - Loss: 0.4964
# [Epoch 7] Step 1250/1474 - Loss: 0.9075
# [Epoch 7] Step 1300/1474 - Loss: 1.1655
# [Epoch 7] Step 1350/1474 - Loss: 0.5503
# [Epoch 7] Step 1400/1474 - Loss: 0.2692
# [Epoch 7] Step 1450/1474 - Loss: 0.5601
# Epoch 007 | TrainLoss(step): 0.5235 | TrainLoss(eval): 0.4139 | ValLoss: 0.7043 | Train mIoU: 0.3703 | Val mIoU: 0.2408 | Val Dice: 0.3406 | Val F1: 0.3406 | Val Acc: 0.7822 | LR: 0.000060
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#
# ===== Epoch 8/40 =====
# [Epoch 8] Step 1/1474 - Loss: 0.9638
# [Epoch 8] Step 50/1474 - Loss: 0.6072
# [Epoch 8] Step 100/1474 - Loss: 0.2274
# [Epoch 8] Step 150/1474 - Loss: 0.6557
# [Epoch 8] Step 200/1474 - Loss: 0.4479
# [Epoch 8] Step 250/1474 - Loss: 0.3182
# [Epoch 8] Step 300/1474 - Loss: 0.6207
# [Epoch 8] Step 350/1474 - Loss: 0.3679
# [Epoch 8] Step 400/1474 - Loss: 0.4028
# [Epoch 8] Step 450/1474 - Loss: 0.4396
# [Epoch 8] Step 500/1474 - Loss: 0.3452
# [Epoch 8] Step 550/1474 - Loss: 0.3670
# [Epoch 8] Step 600/1474 - Loss: 0.4997
# [Epoch 8] Step 650/1474 - Loss: 0.3323
# [Epoch 8] Step 700/1474 - Loss: 0.6792
# [Epoch 8] Step 750/1474 - Loss: 0.6072
# [Epoch 8] Step 800/1474 - Loss: 0.4849
# [Epoch 8] Step 850/1474 - Loss: 0.5651
# [Epoch 8] Step 900/1474 - Loss: 0.6720
# [Epoch 8] Step 950/1474 - Loss: 0.7635
# [Epoch 8] Step 1000/1474 - Loss: 0.7032
# [Epoch 8] Step 1050/1474 - Loss: 0.3456
# [Epoch 8] Step 1100/1474 - Loss: 0.6311
# [Epoch 8] Step 1150/1474 - Loss: 1.0897
# [Epoch 8] Step 1200/1474 - Loss: 0.5393
# [Epoch 8] Step 1250/1474 - Loss: 0.7023
# [Epoch 8] Step 1300/1474 - Loss: 0.4190
# [Epoch 8] Step 1350/1474 - Loss: 0.3497
# [Epoch 8] Step 1400/1474 - Loss: 0.7902
# [Epoch 8] Step 1450/1474 - Loss: 0.4018
# Epoch 008 | TrainLoss(step): 0.4916 | TrainLoss(eval): 0.4071 | ValLoss: 0.7444 | Train mIoU: 0.3886 | Val mIoU: 0.2507 | Val Dice: 0.3537 | Val F1: 0.3537 | Val Acc: 0.7691 | LR: 0.000030
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#   -> Checkpoint saved to segformer_checkpoint_epoch_8.pth
#
# ===== Epoch 9/40 =====
# [Epoch 9] Step 1/1474 - Loss: 0.5015
# [Epoch 9] Step 50/1474 - Loss: 0.5841
# [Epoch 9] Step 100/1474 - Loss: 0.7345
# [Epoch 9] Step 150/1474 - Loss: 0.3000
# [Epoch 9] Step 200/1474 - Loss: 0.2099
# [Epoch 9] Step 250/1474 - Loss: 0.2824
# [Epoch 9] Step 300/1474 - Loss: 0.2528
# [Epoch 9] Step 350/1474 - Loss: 0.3652
# [Epoch 9] Step 400/1474 - Loss: 0.4055
# [Epoch 9] Step 450/1474 - Loss: 0.2333
# [Epoch 9] Step 500/1474 - Loss: 0.2586
# [Epoch 9] Step 550/1474 - Loss: 0.2282
# [Epoch 9] Step 600/1474 - Loss: 0.1593
# [Epoch 9] Step 650/1474 - Loss: 0.5628
# [Epoch 9] Step 700/1474 - Loss: 0.4326
# [Epoch 9] Step 750/1474 - Loss: 0.3788
# [Epoch 9] Step 800/1474 - Loss: 0.3606
# [Epoch 9] Step 850/1474 - Loss: 0.3825
# [Epoch 9] Step 900/1474 - Loss: 0.5188
# [Epoch 9] Step 950/1474 - Loss: 0.5998
# [Epoch 9] Step 1000/1474 - Loss: 0.5603
# [Epoch 9] Step 1050/1474 - Loss: 0.4032
# [Epoch 9] Step 1100/1474 - Loss: 0.4564
# [Epoch 9] Step 1150/1474 - Loss: 0.3744
# [Epoch 9] Step 1200/1474 - Loss: 0.2816
# [Epoch 9] Step 1250/1474 - Loss: 0.3318
# [Epoch 9] Step 1300/1474 - Loss: 0.6982
# [Epoch 9] Step 1350/1474 - Loss: 0.2487
# [Epoch 9] Step 1400/1474 - Loss: 0.2759
# [Epoch 9] Step 1450/1474 - Loss: 0.6326
# Epoch 009 | TrainLoss(step): 0.4294 | TrainLoss(eval): 0.3556 | ValLoss: 0.7324 | Train mIoU: 0.4229 | Val mIoU: 0.2633 | Val Dice: 0.3701 | Val F1: 0.3701 | Val Acc: 0.7724 | LR: 0.000030
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#
# ===== Epoch 10/40 =====
# [Epoch 10] Step 1/1474 - Loss: 0.2798
# [Epoch 10] Step 50/1474 - Loss: 0.4805
# [Epoch 10] Step 100/1474 - Loss: 0.3495
# [Epoch 10] Step 150/1474 - Loss: 0.3233
# [Epoch 10] Step 200/1474 - Loss: 0.5483
# [Epoch 10] Step 250/1474 - Loss: 0.3009
# [Epoch 10] Step 300/1474 - Loss: 0.5313
# [Epoch 10] Step 350/1474 - Loss: 0.1440
# [Epoch 10] Step 400/1474 - Loss: 0.1899
# [Epoch 10] Step 450/1474 - Loss: 0.2720
# [Epoch 10] Step 500/1474 - Loss: 0.2696
# [Epoch 10] Step 550/1474 - Loss: 0.4013
# [Epoch 10] Step 600/1474 - Loss: 0.2866
# [Epoch 10] Step 650/1474 - Loss: 0.3864
# [Epoch 10] Step 700/1474 - Loss: 0.3503
# [Epoch 10] Step 750/1474 - Loss: 0.5451
# [Epoch 10] Step 800/1474 - Loss: 0.2616
# [Epoch 10] Step 850/1474 - Loss: 0.2523
# [Epoch 10] Step 900/1474 - Loss: 0.1488
# [Epoch 10] Step 950/1474 - Loss: 0.5540
# [Epoch 10] Step 1000/1474 - Loss: 0.4460
# [Epoch 10] Step 1050/1474 - Loss: 0.4108
# [Epoch 10] Step 1100/1474 - Loss: 0.3328
# [Epoch 10] Step 1150/1474 - Loss: 0.7268
# [Epoch 10] Step 1200/1474 - Loss: 0.2087
# [Epoch 10] Step 1250/1474 - Loss: 0.6275
# [Epoch 10] Step 1300/1474 - Loss: 0.2161
# [Epoch 10] Step 1350/1474 - Loss: 0.4903
# [Epoch 10] Step 1400/1474 - Loss: 0.3794
# [Epoch 10] Step 1450/1474 - Loss: 0.5014
# Epoch 010 | TrainLoss(step): 0.4073 | TrainLoss(eval): 0.3267 | ValLoss: 0.7482 | Train mIoU: 0.4467 | Val mIoU: 0.2687 | Val Dice: 0.3775 | Val F1: 0.3775 | Val Acc: 0.7838 | LR: 0.000030
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#   -> Checkpoint saved to segformer_checkpoint_epoch_10.pth
#
# ===== Epoch 11/40 =====
# [Epoch 11] Step 1/1474 - Loss: 0.3273
# [Epoch 11] Step 50/1474 - Loss: 0.4770
# [Epoch 11] Step 100/1474 - Loss: 0.1340
# [Epoch 11] Step 150/1474 - Loss: 0.1742
# [Epoch 11] Step 200/1474 - Loss: 0.1894
# [Epoch 11] Step 250/1474 - Loss: 0.2799
# [Epoch 11] Step 300/1474 - Loss: 0.3093
# [Epoch 11] Step 350/1474 - Loss: 0.3415
# [Epoch 11] Step 400/1474 - Loss: 0.3343
# [Epoch 11] Step 450/1474 - Loss: 0.3758
# [Epoch 11] Step 500/1474 - Loss: 0.2013
# [Epoch 11] Step 550/1474 - Loss: 0.3727
# [Epoch 11] Step 600/1474 - Loss: 0.5987
# [Epoch 11] Step 650/1474 - Loss: 0.4017
# [Epoch 11] Step 700/1474 - Loss: 0.7588
# [Epoch 11] Step 750/1474 - Loss: 0.4603
# [Epoch 11] Step 800/1474 - Loss: 0.1752
# [Epoch 11] Step 850/1474 - Loss: 0.2456
# [Epoch 11] Step 900/1474 - Loss: 0.2215
# [Epoch 11] Step 950/1474 - Loss: 0.2511
# [Epoch 11] Step 1000/1474 - Loss: 0.8616
# [Epoch 11] Step 1050/1474 - Loss: 0.4786
# [Epoch 11] Step 1100/1474 - Loss: 0.1344
# [Epoch 11] Step 1150/1474 - Loss: 0.3441
# [Epoch 11] Step 1200/1474 - Loss: 0.4961
# [Epoch 11] Step 1250/1474 - Loss: 0.4427
# [Epoch 11] Step 1300/1474 - Loss: 0.3625
# [Epoch 11] Step 1350/1474 - Loss: 0.4041
# [Epoch 11] Step 1400/1474 - Loss: 0.3765
# [Epoch 11] Step 1450/1474 - Loss: 0.2065
# Epoch 011 | TrainLoss(step): 0.3877 | TrainLoss(eval): 0.3086 | ValLoss: 0.7675 | Train mIoU: 0.4666 | Val mIoU: 0.2681 | Val Dice: 0.3799 | Val F1: 0.3799 | Val Acc: 0.7829 | LR: 0.000030
#
# ===== Epoch 12/40 =====
# [Epoch 12] Step 1/1474 - Loss: 0.3505
# [Epoch 12] Step 50/1474 - Loss: 0.3025
# [Epoch 12] Step 100/1474 - Loss: 0.2534
# [Epoch 12] Step 150/1474 - Loss: 0.4045
# [Epoch 12] Step 200/1474 - Loss: 0.1906
# [Epoch 12] Step 250/1474 - Loss: 1.1285
# [Epoch 12] Step 300/1474 - Loss: 0.7537
# [Epoch 12] Step 350/1474 - Loss: 0.4123
# [Epoch 12] Step 400/1474 - Loss: 0.2044
# [Epoch 12] Step 450/1474 - Loss: 0.3284
# [Epoch 12] Step 500/1474 - Loss: 0.4613
# [Epoch 12] Step 550/1474 - Loss: 0.2735
# [Epoch 12] Step 600/1474 - Loss: 0.1295
# [Epoch 12] Step 650/1474 - Loss: 0.9264
# [Epoch 12] Step 700/1474 - Loss: 0.1198
# [Epoch 12] Step 750/1474 - Loss: 0.4021
# [Epoch 12] Step 800/1474 - Loss: 0.1757
# [Epoch 12] Step 850/1474 - Loss: 0.4871
# [Epoch 12] Step 900/1474 - Loss: 0.3316
# [Epoch 12] Step 950/1474 - Loss: 0.4152
# [Epoch 12] Step 1000/1474 - Loss: 0.4749
# [Epoch 12] Step 1050/1474 - Loss: 0.4259
# [Epoch 12] Step 1100/1474 - Loss: 0.2400
# [Epoch 12] Step 1150/1474 - Loss: 0.5862
# [Epoch 12] Step 1200/1474 - Loss: 0.3396
# [Epoch 12] Step 1250/1474 - Loss: 0.2316
# [Epoch 12] Step 1300/1474 - Loss: 0.3690
# [Epoch 12] Step 1350/1474 - Loss: 0.1788
# [Epoch 12] Step 1400/1474 - Loss: 0.2509
# [Epoch 12] Step 1450/1474 - Loss: 0.2120
# Epoch 012 | TrainLoss(step): 0.3758 | TrainLoss(eval): 0.2945 | ValLoss: 0.7854 | Train mIoU: 0.4816 | Val mIoU: 0.2681 | Val Dice: 0.3792 | Val F1: 0.3792 | Val Acc: 0.7844 | LR: 0.000015
#   -> Checkpoint saved to segformer_checkpoint_epoch_12.pth
#
# ===== Epoch 13/40 =====
# [Epoch 13] Step 1/1474 - Loss: 0.7505
# [Epoch 13] Step 50/1474 - Loss: 0.4850
# [Epoch 13] Step 100/1474 - Loss: 0.2945
# [Epoch 13] Step 150/1474 - Loss: 0.5009
# [Epoch 13] Step 200/1474 - Loss: 0.4214
# [Epoch 13] Step 250/1474 - Loss: 0.1412
# [Epoch 13] Step 300/1474 - Loss: 0.4130
# [Epoch 13] Step 350/1474 - Loss: 0.1565
# [Epoch 13] Step 400/1474 - Loss: 0.2533
# [Epoch 13] Step 450/1474 - Loss: 0.2055
# [Epoch 13] Step 500/1474 - Loss: 0.3749
# [Epoch 13] Step 550/1474 - Loss: 0.6815
# [Epoch 13] Step 600/1474 - Loss: 0.7163
# [Epoch 13] Step 650/1474 - Loss: 0.2932
# [Epoch 13] Step 700/1474 - Loss: 0.4089
# [Epoch 13] Step 750/1474 - Loss: 0.2926
# [Epoch 13] Step 800/1474 - Loss: 0.3089
# [Epoch 13] Step 850/1474 - Loss: 0.2012
# [Epoch 13] Step 900/1474 - Loss: 0.3145
# [Epoch 13] Step 950/1474 - Loss: 0.1890
# [Epoch 13] Step 1000/1474 - Loss: 0.3179
# [Epoch 13] Step 1050/1474 - Loss: 0.2891
# [Epoch 13] Step 1100/1474 - Loss: 0.4737
# [Epoch 13] Step 1150/1474 - Loss: 0.4738
# [Epoch 13] Step 1200/1474 - Loss: 0.4151
# [Epoch 13] Step 1250/1474 - Loss: 0.1955
# [Epoch 13] Step 1300/1474 - Loss: 0.2350
# [Epoch 13] Step 1350/1474 - Loss: 0.2266
# [Epoch 13] Step 1400/1474 - Loss: 0.1399
# [Epoch 13] Step 1450/1474 - Loss: 0.6538
# Epoch 013 | TrainLoss(step): 0.3487 | TrainLoss(eval): 0.2802 | ValLoss: 0.7970 | Train mIoU: 0.4982 | Val mIoU: 0.2745 | Val Dice: 0.3894 | Val F1: 0.3894 | Val Acc: 0.7821 | LR: 0.000015
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#
# ===== Epoch 14/40 =====
# [Epoch 14] Step 1/1474 - Loss: 0.3269
# [Epoch 14] Step 50/1474 - Loss: 0.7138
# [Epoch 14] Step 100/1474 - Loss: 0.4880
# [Epoch 14] Step 150/1474 - Loss: 0.4481
# [Epoch 14] Step 200/1474 - Loss: 0.3824
# [Epoch 14] Step 250/1474 - Loss: 0.4419
# [Epoch 14] Step 300/1474 - Loss: 0.1386
# [Epoch 14] Step 350/1474 - Loss: 0.1640
# [Epoch 14] Step 400/1474 - Loss: 0.4260
# [Epoch 14] Step 450/1474 - Loss: 0.3129
# [Epoch 14] Step 500/1474 - Loss: 0.3246
# [Epoch 14] Step 550/1474 - Loss: 0.4024
# [Epoch 14] Step 600/1474 - Loss: 0.2700
# [Epoch 14] Step 650/1474 - Loss: 0.4567
# [Epoch 14] Step 700/1474 - Loss: 0.3034
# [Epoch 14] Step 750/1474 - Loss: 0.8564
# [Epoch 14] Step 800/1474 - Loss: 0.1046
# [Epoch 14] Step 850/1474 - Loss: 0.1981
# [Epoch 14] Step 900/1474 - Loss: 0.2552
# [Epoch 14] Step 950/1474 - Loss: 0.2377
# [Epoch 14] Step 1000/1474 - Loss: 0.2991
# [Epoch 14] Step 1050/1474 - Loss: 0.4300
# [Epoch 14] Step 1100/1474 - Loss: 0.1846
# [Epoch 14] Step 1150/1474 - Loss: 0.4347
# [Epoch 14] Step 1200/1474 - Loss: 0.2707
# [Epoch 14] Step 1250/1474 - Loss: 0.3931
# [Epoch 14] Step 1300/1474 - Loss: 0.4101
# [Epoch 14] Step 1350/1474 - Loss: 0.3358
# [Epoch 14] Step 1400/1474 - Loss: 0.1997
# [Epoch 14] Step 1450/1474 - Loss: 0.3069
# Epoch 014 | TrainLoss(step): 0.3354 | TrainLoss(eval): 0.2776 | ValLoss: 0.8184 | Train mIoU: 0.4988 | Val mIoU: 0.2730 | Val Dice: 0.3876 | Val F1: 0.3876 | Val Acc: 0.7776 | LR: 0.000015
#   -> Checkpoint saved to segformer_checkpoint_epoch_14.pth
#
# ===== Epoch 15/40 =====
# [Epoch 15] Step 1/1474 - Loss: 0.4704
# [Epoch 15] Step 50/1474 - Loss: 0.6012
# [Epoch 15] Step 100/1474 - Loss: 0.2543
# [Epoch 15] Step 150/1474 - Loss: 0.4273
# [Epoch 15] Step 200/1474 - Loss: 0.3533
# [Epoch 15] Step 250/1474 - Loss: 0.6194
# [Epoch 15] Step 300/1474 - Loss: 0.2428
# [Epoch 15] Step 350/1474 - Loss: 0.2133
# [Epoch 15] Step 400/1474 - Loss: 0.3510
# [Epoch 15] Step 450/1474 - Loss: 0.5856
# [Epoch 15] Step 500/1474 - Loss: 0.1790
# [Epoch 15] Step 550/1474 - Loss: 0.1703
# [Epoch 15] Step 600/1474 - Loss: 0.1529
# [Epoch 15] Step 650/1474 - Loss: 0.5068
# [Epoch 15] Step 700/1474 - Loss: 0.1353
# [Epoch 15] Step 750/1474 - Loss: 0.2875
# [Epoch 15] Step 800/1474 - Loss: 0.2586
# [Epoch 15] Step 850/1474 - Loss: 0.3258
# [Epoch 15] Step 900/1474 - Loss: 0.2242
# [Epoch 15] Step 950/1474 - Loss: 0.2950
# [Epoch 15] Step 1000/1474 - Loss: 0.2905
# [Epoch 15] Step 1050/1474 - Loss: 0.7241
# [Epoch 15] Step 1100/1474 - Loss: 0.2193
# [Epoch 15] Step 1150/1474 - Loss: 0.4466
# [Epoch 15] Step 1200/1474 - Loss: 0.1677
# [Epoch 15] Step 1250/1474 - Loss: 0.2634
# [Epoch 15] Step 1300/1474 - Loss: 0.1425
# [Epoch 15] Step 1350/1474 - Loss: 0.7876
# [Epoch 15] Step 1400/1474 - Loss: 0.1371
# [Epoch 15] Step 1450/1474 - Loss: 0.7188
# Epoch 015 | TrainLoss(step): 0.3296 | TrainLoss(eval): 0.2643 | ValLoss: 0.8171 | Train mIoU: 0.5203 | Val mIoU: 0.2781 | Val Dice: 0.3953 | Val F1: 0.3953 | Val Acc: 0.7844 | LR: 0.000015
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#
# ===== Epoch 16/40 =====
# [Epoch 16] Step 1/1474 - Loss: 0.3522
# [Epoch 16] Step 50/1474 - Loss: 0.2047
# [Epoch 16] Step 100/1474 - Loss: 0.3330
# [Epoch 16] Step 150/1474 - Loss: 0.2917
# [Epoch 16] Step 200/1474 - Loss: 0.2757
# [Epoch 16] Step 250/1474 - Loss: 0.2944
# [Epoch 16] Step 300/1474 - Loss: 0.2236
# [Epoch 16] Step 350/1474 - Loss: 0.2915
# [Epoch 16] Step 400/1474 - Loss: 0.3738
# [Epoch 16] Step 450/1474 - Loss: 0.4926
# [Epoch 16] Step 500/1474 - Loss: 0.3294
# [Epoch 16] Step 550/1474 - Loss: 0.3096
# [Epoch 16] Step 600/1474 - Loss: 0.0982
# [Epoch 16] Step 650/1474 - Loss: 0.1422
# [Epoch 16] Step 700/1474 - Loss: 0.3176
# [Epoch 16] Step 750/1474 - Loss: 0.2131
# [Epoch 16] Step 800/1474 - Loss: 0.1436
# [Epoch 16] Step 850/1474 - Loss: 0.1471
# [Epoch 16] Step 900/1474 - Loss: 0.4260
# [Epoch 16] Step 950/1474 - Loss: 0.3275
# [Epoch 16] Step 1000/1474 - Loss: 0.2784
# [Epoch 16] Step 1050/1474 - Loss: 0.2598
# [Epoch 16] Step 1100/1474 - Loss: 0.8682
# [Epoch 16] Step 1150/1474 - Loss: 0.2487
# [Epoch 16] Step 1200/1474 - Loss: 0.2269
# [Epoch 16] Step 1250/1474 - Loss: 0.2725
# [Epoch 16] Step 1300/1474 - Loss: 0.2104
# [Epoch 16] Step 1350/1474 - Loss: 0.4822
# [Epoch 16] Step 1400/1474 - Loss: 0.4184
# [Epoch 16] Step 1450/1474 - Loss: 0.1783
# Epoch 016 | TrainLoss(step): 0.3198 | TrainLoss(eval): 0.2611 | ValLoss: 0.8025 | Train mIoU: 0.5251 | Val mIoU: 0.2786 | Val Dice: 0.3959 | Val F1: 0.3959 | Val Acc: 0.7853 | LR: 0.000008
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#   -> Checkpoint saved to segformer_checkpoint_epoch_16.pth
#
# ===== Epoch 17/40 =====
# [Epoch 17] Step 1/1474 - Loss: 0.2350
# [Epoch 17] Step 50/1474 - Loss: 0.6087
# [Epoch 17] Step 100/1474 - Loss: 0.2966
# [Epoch 17] Step 150/1474 - Loss: 0.1644
# [Epoch 17] Step 200/1474 - Loss: 0.1730
# [Epoch 17] Step 250/1474 - Loss: 0.1250
# [Epoch 17] Step 300/1474 - Loss: 0.4546
# [Epoch 17] Step 350/1474 - Loss: 0.2169
# [Epoch 17] Step 400/1474 - Loss: 0.2778
# [Epoch 17] Step 450/1474 - Loss: 0.3415
# [Epoch 17] Step 500/1474 - Loss: 0.1545
# [Epoch 17] Step 550/1474 - Loss: 0.2241
# [Epoch 17] Step 600/1474 - Loss: 0.2442
# [Epoch 17] Step 650/1474 - Loss: 0.1105
# [Epoch 17] Step 700/1474 - Loss: 0.3705
# [Epoch 17] Step 750/1474 - Loss: 0.3039
# [Epoch 17] Step 800/1474 - Loss: 0.2876
# [Epoch 17] Step 850/1474 - Loss: 0.4122
# [Epoch 17] Step 900/1474 - Loss: 0.4114
# [Epoch 17] Step 950/1474 - Loss: 0.2055
# [Epoch 17] Step 1000/1474 - Loss: 0.3591
# [Epoch 17] Step 1050/1474 - Loss: 0.1288
# [Epoch 17] Step 1100/1474 - Loss: 0.3014
# [Epoch 17] Step 1150/1474 - Loss: 0.3882
# [Epoch 17] Step 1200/1474 - Loss: 0.1646
# [Epoch 17] Step 1250/1474 - Loss: 0.2134
# [Epoch 17] Step 1300/1474 - Loss: 0.2317
# [Epoch 17] Step 1350/1474 - Loss: 0.1539
# [Epoch 17] Step 1400/1474 - Loss: 0.1916
# [Epoch 17] Step 1450/1474 - Loss: 0.3778
# Epoch 017 | TrainLoss(step): 0.3096 | TrainLoss(eval): 0.2493 | ValLoss: 0.8210 | Train mIoU: 0.5313 | Val mIoU: 0.2783 | Val Dice: 0.3944 | Val F1: 0.3944 | Val Acc: 0.7866 | LR: 0.000008
#
# ===== Epoch 18/40 =====
# [Epoch 18] Step 1/1474 - Loss: 0.3808
# [Epoch 18] Step 50/1474 - Loss: 0.6155
# [Epoch 18] Step 100/1474 - Loss: 0.2031
# [Epoch 18] Step 150/1474 - Loss: 0.3650
# [Epoch 18] Step 200/1474 - Loss: 0.1925
# [Epoch 18] Step 250/1474 - Loss: 0.5416
# [Epoch 18] Step 300/1474 - Loss: 0.2302
# [Epoch 18] Step 350/1474 - Loss: 0.3294
# [Epoch 18] Step 400/1474 - Loss: 0.4210
# [Epoch 18] Step 450/1474 - Loss: 0.3641
# [Epoch 18] Step 500/1474 - Loss: 0.1967
# [Epoch 18] Step 550/1474 - Loss: 0.3499
# [Epoch 18] Step 600/1474 - Loss: 0.2260
# [Epoch 18] Step 650/1474 - Loss: 0.1820
# [Epoch 18] Step 700/1474 - Loss: 0.2096
# [Epoch 18] Step 750/1474 - Loss: 0.2728
# [Epoch 18] Step 800/1474 - Loss: 0.6300
# [Epoch 18] Step 850/1474 - Loss: 0.2039
# [Epoch 18] Step 900/1474 - Loss: 0.1374
# [Epoch 18] Step 950/1474 - Loss: 0.1704
# [Epoch 18] Step 1000/1474 - Loss: 0.1381
# [Epoch 18] Step 1050/1474 - Loss: 0.2929
# [Epoch 18] Step 1100/1474 - Loss: 0.1905
# [Epoch 18] Step 1150/1474 - Loss: 0.3144
# [Epoch 18] Step 1200/1474 - Loss: 0.1449
# [Epoch 18] Step 1250/1474 - Loss: 0.1961
# [Epoch 18] Step 1300/1474 - Loss: 0.3327
# [Epoch 18] Step 1350/1474 - Loss: 0.1890
# [Epoch 18] Step 1400/1474 - Loss: 0.1907
# [Epoch 18] Step 1450/1474 - Loss: 0.2260
# Epoch 018 | TrainLoss(step): 0.3073 | TrainLoss(eval): 0.2447 | ValLoss: 0.8283 | Train mIoU: 0.5380 | Val mIoU: 0.2805 | Val Dice: 0.3977 | Val F1: 0.3977 | Val Acc: 0.7851 | LR: 0.000008
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#   -> Checkpoint saved to segformer_checkpoint_epoch_18.pth
#
# ===== Epoch 19/40 =====
# [Epoch 19] Step 1/1474 - Loss: 0.2754
# [Epoch 19] Step 50/1474 - Loss: 0.2136
# [Epoch 19] Step 100/1474 - Loss: 0.2022
# [Epoch 19] Step 150/1474 - Loss: 0.1792
# [Epoch 19] Step 200/1474 - Loss: 1.0141
# [Epoch 19] Step 250/1474 - Loss: 0.2386
# [Epoch 19] Step 300/1474 - Loss: 0.2696
# [Epoch 19] Step 350/1474 - Loss: 0.2850
# [Epoch 19] Step 400/1474 - Loss: 0.3150
# [Epoch 19] Step 450/1474 - Loss: 0.3647
# [Epoch 19] Step 500/1474 - Loss: 0.1462
# [Epoch 19] Step 550/1474 - Loss: 0.6412
# [Epoch 19] Step 600/1474 - Loss: 0.5031
# [Epoch 19] Step 650/1474 - Loss: 0.2031
# [Epoch 19] Step 700/1474 - Loss: 0.2174
# [Epoch 19] Step 750/1474 - Loss: 0.1312
# [Epoch 19] Step 800/1474 - Loss: 0.1453
# [Epoch 19] Step 850/1474 - Loss: 0.2120
# [Epoch 19] Step 900/1474 - Loss: 0.2849
# [Epoch 19] Step 950/1474 - Loss: 0.7230
# [Epoch 19] Step 1000/1474 - Loss: 0.4041
# [Epoch 19] Step 1050/1474 - Loss: 0.4068
# [Epoch 19] Step 1100/1474 - Loss: 0.1975
# [Epoch 19] Step 1150/1474 - Loss: 0.2337
# [Epoch 19] Step 1200/1474 - Loss: 0.4669
# [Epoch 19] Step 1250/1474 - Loss: 0.1442
# [Epoch 19] Step 1300/1474 - Loss: 0.1538
# [Epoch 19] Step 1350/1474 - Loss: 0.2613
# [Epoch 19] Step 1400/1474 - Loss: 0.1492
# [Epoch 19] Step 1450/1474 - Loss: 0.2199
# Epoch 019 | TrainLoss(step): 0.3029 | TrainLoss(eval): 0.2454 | ValLoss: 0.8300 | Train mIoU: 0.5412 | Val mIoU: 0.2807 | Val Dice: 0.3983 | Val F1: 0.3983 | Val Acc: 0.7840 | LR: 0.000008
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#
# ===== Epoch 20/40 =====
# [Epoch 20] Step 1/1474 - Loss: 0.5009
# [Epoch 20] Step 50/1474 - Loss: 0.4971
# [Epoch 20] Step 100/1474 - Loss: 0.2084
# [Epoch 20] Step 150/1474 - Loss: 0.1252
# [Epoch 20] Step 200/1474 - Loss: 0.4444
# [Epoch 20] Step 250/1474 - Loss: 0.4610
# [Epoch 20] Step 300/1474 - Loss: 0.1486
# [Epoch 20] Step 350/1474 - Loss: 0.3411
# [Epoch 20] Step 400/1474 - Loss: 0.3684
# [Epoch 20] Step 450/1474 - Loss: 0.2806
# [Epoch 20] Step 500/1474 - Loss: 0.2218
# [Epoch 20] Step 550/1474 - Loss: 0.2468
# [Epoch 20] Step 600/1474 - Loss: 0.3440
# [Epoch 20] Step 650/1474 - Loss: 0.5413
# [Epoch 20] Step 700/1474 - Loss: 0.3093
# [Epoch 20] Step 750/1474 - Loss: 0.2398
# [Epoch 20] Step 800/1474 - Loss: 0.1185
# [Epoch 20] Step 850/1474 - Loss: 0.7260
# [Epoch 20] Step 900/1474 - Loss: 0.2134
# [Epoch 20] Step 950/1474 - Loss: 0.2298
# [Epoch 20] Step 1000/1474 - Loss: 0.1774
# [Epoch 20] Step 1050/1474 - Loss: 0.1788
# [Epoch 20] Step 1100/1474 - Loss: 0.1762
# [Epoch 20] Step 1150/1474 - Loss: 0.1582
# [Epoch 20] Step 1200/1474 - Loss: 0.3057
# [Epoch 20] Step 1250/1474 - Loss: 0.2452
# [Epoch 20] Step 1300/1474 - Loss: 0.1990
# [Epoch 20] Step 1350/1474 - Loss: 0.3614
# [Epoch 20] Step 1400/1474 - Loss: 0.2122
# [Epoch 20] Step 1450/1474 - Loss: 0.1160
# Epoch 020 | TrainLoss(step): 0.2992 | TrainLoss(eval): 0.2470 | ValLoss: 0.8416 | Train mIoU: 0.5427 | Val mIoU: 0.2817 | Val Dice: 0.4002 | Val F1: 0.4002 | Val Acc: 0.7765 | LR: 0.000004
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#   -> Checkpoint saved to segformer_checkpoint_epoch_20.pth
#
# ===== Epoch 21/40 =====
# [Epoch 21] Step 1/1474 - Loss: 0.2869
# [Epoch 21] Step 50/1474 - Loss: 0.3206
# [Epoch 21] Step 100/1474 - Loss: 0.5404
# [Epoch 21] Step 150/1474 - Loss: 0.4474
# [Epoch 21] Step 200/1474 - Loss: 0.2647
# [Epoch 21] Step 250/1474 - Loss: 0.1844
# [Epoch 21] Step 300/1474 - Loss: 0.2042
# [Epoch 21] Step 350/1474 - Loss: 0.4231
# [Epoch 21] Step 400/1474 - Loss: 0.2764
# [Epoch 21] Step 450/1474 - Loss: 0.1273
# [Epoch 21] Step 500/1474 - Loss: 0.4849
# [Epoch 21] Step 550/1474 - Loss: 0.2887
# [Epoch 21] Step 600/1474 - Loss: 0.2674
# [Epoch 21] Step 650/1474 - Loss: 0.2827
# [Epoch 21] Step 700/1474 - Loss: 0.1574
# [Epoch 21] Step 750/1474 - Loss: 0.2674
# [Epoch 21] Step 800/1474 - Loss: 0.0677
# [Epoch 21] Step 850/1474 - Loss: 0.2432
# [Epoch 21] Step 900/1474 - Loss: 0.2661
# [Epoch 21] Step 950/1474 - Loss: 0.4667
# [Epoch 21] Step 1000/1474 - Loss: 0.2754
# [Epoch 21] Step 1050/1474 - Loss: 0.2429
# [Epoch 21] Step 1100/1474 - Loss: 0.3716
# [Epoch 21] Step 1150/1474 - Loss: 0.3503
# [Epoch 21] Step 1200/1474 - Loss: 0.1846
# [Epoch 21] Step 1250/1474 - Loss: 0.2442
# [Epoch 21] Step 1300/1474 - Loss: 0.2379
# [Epoch 21] Step 1350/1474 - Loss: 0.2360
# [Epoch 21] Step 1400/1474 - Loss: 0.4160
# [Epoch 21] Step 1450/1474 - Loss: 0.3735
# Epoch 021 | TrainLoss(step): 0.2921 | TrainLoss(eval): 0.2337 | ValLoss: 0.8431 | Train mIoU: 0.5528 | Val mIoU: 0.2811 | Val Dice: 0.3983 | Val F1: 0.3983 | Val Acc: 0.7869 | LR: 0.000004
#
# ===== Epoch 22/40 =====
# [Epoch 22] Step 1/1474 - Loss: 0.2691
# [Epoch 22] Step 50/1474 - Loss: 0.1609
# [Epoch 22] Step 100/1474 - Loss: 0.5297
# [Epoch 22] Step 150/1474 - Loss: 0.5724
# [Epoch 22] Step 200/1474 - Loss: 0.1879
# [Epoch 22] Step 250/1474 - Loss: 0.2378
# [Epoch 22] Step 300/1474 - Loss: 0.1440
# [Epoch 22] Step 350/1474 - Loss: 0.7071
# [Epoch 22] Step 400/1474 - Loss: 0.0919
# [Epoch 22] Step 450/1474 - Loss: 0.2090
# [Epoch 22] Step 500/1474 - Loss: 0.3576
# [Epoch 22] Step 550/1474 - Loss: 0.2347
# [Epoch 22] Step 600/1474 - Loss: 0.4479
# [Epoch 22] Step 650/1474 - Loss: 0.4602
# [Epoch 22] Step 700/1474 - Loss: 0.2258
# [Epoch 22] Step 750/1474 - Loss: 0.3849
# [Epoch 22] Step 800/1474 - Loss: 0.1809
# [Epoch 22] Step 850/1474 - Loss: 0.1736
# [Epoch 22] Step 900/1474 - Loss: 0.3403
# [Epoch 22] Step 950/1474 - Loss: 0.4053
# [Epoch 22] Step 1000/1474 - Loss: 0.2849
# [Epoch 22] Step 1050/1474 - Loss: 0.1686
# [Epoch 22] Step 1100/1474 - Loss: 0.1914
# [Epoch 22] Step 1150/1474 - Loss: 0.2011
# [Epoch 22] Step 1200/1474 - Loss: 0.2244
# [Epoch 22] Step 1250/1474 - Loss: 0.5405
# [Epoch 22] Step 1300/1474 - Loss: 0.2255
# [Epoch 22] Step 1350/1474 - Loss: 0.4077
# [Epoch 22] Step 1400/1474 - Loss: 0.1880
# [Epoch 22] Step 1450/1474 - Loss: 0.2958
# Epoch 022 | TrainLoss(step): 0.2899 | TrainLoss(eval): 0.2336 | ValLoss: 0.8586 | Train mIoU: 0.5555 | Val mIoU: 0.2812 | Val Dice: 0.4000 | Val F1: 0.4000 | Val Acc: 0.7859 | LR: 0.000004
#   -> Checkpoint saved to segformer_checkpoint_epoch_22.pth
#
# ===== Epoch 23/40 =====
# [Epoch 23] Step 1/1474 - Loss: 0.3184
# [Epoch 23] Step 50/1474 - Loss: 0.5771
# [Epoch 23] Step 100/1474 - Loss: 0.5098
# [Epoch 23] Step 150/1474 - Loss: 0.1900
# [Epoch 23] Step 200/1474 - Loss: 0.3455
# [Epoch 23] Step 250/1474 - Loss: 0.5664
# [Epoch 23] Step 300/1474 - Loss: 0.1881
# [Epoch 23] Step 350/1474 - Loss: 0.1933
# [Epoch 23] Step 400/1474 - Loss: 0.6286
# [Epoch 23] Step 450/1474 - Loss: 0.3132
# [Epoch 23] Step 500/1474 - Loss: 0.4724
# [Epoch 23] Step 550/1474 - Loss: 0.3028
# [Epoch 23] Step 600/1474 - Loss: 0.1386
# [Epoch 23] Step 650/1474 - Loss: 0.1917
# [Epoch 23] Step 700/1474 - Loss: 0.3946
# [Epoch 23] Step 750/1474 - Loss: 0.3089
# [Epoch 23] Step 800/1474 - Loss: 0.2344
# [Epoch 23] Step 850/1474 - Loss: 0.5096
# [Epoch 23] Step 900/1474 - Loss: 0.2027
# [Epoch 23] Step 950/1474 - Loss: 0.2179
# [Epoch 23] Step 1000/1474 - Loss: 0.4044
# [Epoch 23] Step 1050/1474 - Loss: 0.3768
# [Epoch 23] Step 1100/1474 - Loss: 0.2127
# [Epoch 23] Step 1150/1474 - Loss: 0.2120
# [Epoch 23] Step 1200/1474 - Loss: 0.1924
# [Epoch 23] Step 1250/1474 - Loss: 0.3163
# [Epoch 23] Step 1300/1474 - Loss: 0.2608
# [Epoch 23] Step 1350/1474 - Loss: 0.1879
# [Epoch 23] Step 1400/1474 - Loss: 0.1855
# [Epoch 23] Step 1450/1474 - Loss: 0.2067
# Epoch 023 | TrainLoss(step): 0.2860 | TrainLoss(eval): 0.2329 | ValLoss: 0.8476 | Train mIoU: 0.5579 | Val mIoU: 0.2835 | Val Dice: 0.4032 | Val F1: 0.4032 | Val Acc: 0.7860 | LR: 0.000004
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#
# ===== Epoch 24/40 =====
# [Epoch 24] Step 1/1474 - Loss: 0.2305
# [Epoch 24] Step 50/1474 - Loss: 0.2554
# [Epoch 24] Step 100/1474 - Loss: 0.1743
# [Epoch 24] Step 150/1474 - Loss: 0.2209
# [Epoch 24] Step 200/1474 - Loss: 0.3474
# [Epoch 24] Step 250/1474 - Loss: 0.3263
# [Epoch 24] Step 300/1474 - Loss: 0.1278
# [Epoch 24] Step 350/1474 - Loss: 0.1918
# [Epoch 24] Step 400/1474 - Loss: 0.2050
# [Epoch 24] Step 450/1474 - Loss: 0.2263
# [Epoch 24] Step 500/1474 - Loss: 0.2498
# [Epoch 24] Step 550/1474 - Loss: 0.1775
# [Epoch 24] Step 600/1474 - Loss: 0.2473
# [Epoch 24] Step 650/1474 - Loss: 0.6235
# [Epoch 24] Step 700/1474 - Loss: 0.3305
# [Epoch 24] Step 750/1474 - Loss: 0.3664
# [Epoch 24] Step 800/1474 - Loss: 0.2865
# [Epoch 24] Step 850/1474 - Loss: 0.3822
# [Epoch 24] Step 900/1474 - Loss: 0.3437
# [Epoch 24] Step 950/1474 - Loss: 0.2929
# [Epoch 24] Step 1000/1474 - Loss: 0.1310
# [Epoch 24] Step 1050/1474 - Loss: 0.3544
# [Epoch 24] Step 1100/1474 - Loss: 0.3040
# [Epoch 24] Step 1150/1474 - Loss: 0.3203
# [Epoch 24] Step 1200/1474 - Loss: 0.2176
# [Epoch 24] Step 1250/1474 - Loss: 0.2105
# [Epoch 24] Step 1300/1474 - Loss: 0.3334
# [Epoch 24] Step 1350/1474 - Loss: 0.2776
# [Epoch 24] Step 1400/1474 - Loss: 0.2479
# [Epoch 24] Step 1450/1474 - Loss: 0.5803
# Epoch 024 | TrainLoss(step): 0.2846 | TrainLoss(eval): 0.2304 | ValLoss: 0.8598 | Train mIoU: 0.5587 | Val mIoU: 0.2801 | Val Dice: 0.3987 | Val F1: 0.3987 | Val Acc: 0.7848 | LR: 0.000002
#   -> Checkpoint saved to segformer_checkpoint_epoch_24.pth
#
# ===== Epoch 25/40 =====
# [Epoch 25] Step 1/1474 - Loss: 0.1657
# [Epoch 25] Step 50/1474 - Loss: 0.7621
# [Epoch 25] Step 100/1474 - Loss: 0.1311
# [Epoch 25] Step 150/1474 - Loss: 0.2847
# [Epoch 25] Step 200/1474 - Loss: 0.1592
# [Epoch 25] Step 250/1474 - Loss: 0.1804
# [Epoch 25] Step 300/1474 - Loss: 0.4413
# [Epoch 25] Step 350/1474 - Loss: 0.1546
# [Epoch 25] Step 400/1474 - Loss: 0.2946
# [Epoch 25] Step 450/1474 - Loss: 0.3284
# [Epoch 25] Step 500/1474 - Loss: 0.2635
# [Epoch 25] Step 550/1474 - Loss: 0.2697
# [Epoch 25] Step 600/1474 - Loss: 0.2725
# [Epoch 25] Step 650/1474 - Loss: 0.2011
# [Epoch 25] Step 700/1474 - Loss: 0.3680
# [Epoch 25] Step 750/1474 - Loss: 0.3007
# [Epoch 25] Step 800/1474 - Loss: 0.1669
# [Epoch 25] Step 850/1474 - Loss: 0.3802
# [Epoch 25] Step 900/1474 - Loss: 0.0799
# [Epoch 25] Step 950/1474 - Loss: 0.5082
# [Epoch 25] Step 1000/1474 - Loss: 0.6506
# [Epoch 25] Step 1050/1474 - Loss: 0.1521
# [Epoch 25] Step 1100/1474 - Loss: 0.1058
# [Epoch 25] Step 1150/1474 - Loss: 0.2245
# [Epoch 25] Step 1200/1474 - Loss: 0.2858
# [Epoch 25] Step 1250/1474 - Loss: 0.9626
# [Epoch 25] Step 1300/1474 - Loss: 0.1559
# [Epoch 25] Step 1350/1474 - Loss: 0.2888
# [Epoch 25] Step 1400/1474 - Loss: 0.2502
# [Epoch 25] Step 1450/1474 - Loss: 0.1373
# Epoch 025 | TrainLoss(step): 0.2829 | TrainLoss(eval): 0.2294 | ValLoss: 0.8595 | Train mIoU: 0.5617 | Val mIoU: 0.2820 | Val Dice: 0.4012 | Val F1: 0.4012 | Val Acc: 0.7858 | LR: 0.000002
#
# ===== Epoch 26/40 =====
# [Epoch 26] Step 1/1474 - Loss: 0.5003
# [Epoch 26] Step 50/1474 - Loss: 0.4086
# [Epoch 26] Step 100/1474 - Loss: 0.1884
# [Epoch 26] Step 150/1474 - Loss: 0.3830
# [Epoch 26] Step 200/1474 - Loss: 0.4050
# [Epoch 26] Step 250/1474 - Loss: 0.5072
# [Epoch 26] Step 300/1474 - Loss: 0.5257
# [Epoch 26] Step 350/1474 - Loss: 0.1573
# [Epoch 26] Step 400/1474 - Loss: 0.5809
# [Epoch 26] Step 450/1474 - Loss: 0.1765
# [Epoch 26] Step 500/1474 - Loss: 0.1042
# [Epoch 26] Step 550/1474 - Loss: 0.2576
# [Epoch 26] Step 600/1474 - Loss: 0.0971
# [Epoch 26] Step 650/1474 - Loss: 0.1797
# [Epoch 26] Step 700/1474 - Loss: 0.3257
# [Epoch 26] Step 750/1474 - Loss: 0.3733
# [Epoch 26] Step 800/1474 - Loss: 0.1919
# [Epoch 26] Step 850/1474 - Loss: 0.2283
# [Epoch 26] Step 900/1474 - Loss: 0.1286
# [Epoch 26] Step 950/1474 - Loss: 0.3382
# [Epoch 26] Step 1000/1474 - Loss: 0.1701
# [Epoch 26] Step 1050/1474 - Loss: 0.1919
# [Epoch 26] Step 1100/1474 - Loss: 0.5784
# [Epoch 26] Step 1150/1474 - Loss: 0.2188
# [Epoch 26] Step 1200/1474 - Loss: 0.1174
# [Epoch 26] Step 1250/1474 - Loss: 0.1774
# [Epoch 26] Step 1300/1474 - Loss: 0.1552
# [Epoch 26] Step 1350/1474 - Loss: 0.1866
# [Epoch 26] Step 1400/1474 - Loss: 0.2509
# [Epoch 26] Step 1450/1474 - Loss: 0.1693
# Epoch 026 | TrainLoss(step): 0.2816 | TrainLoss(eval): 0.2292 | ValLoss: 0.8381 | Train mIoU: 0.5638 | Val mIoU: 0.2812 | Val Dice: 0.4000 | Val F1: 0.4000 | Val Acc: 0.7838 | LR: 0.000002
#   -> Checkpoint saved to segformer_checkpoint_epoch_26.pth
#
# ===== Epoch 27/40 =====
# [Epoch 27] Step 1/1474 - Loss: 0.4216
# [Epoch 27] Step 50/1474 - Loss: 0.2891
# [Epoch 27] Step 100/1474 - Loss: 0.5100
# [Epoch 27] Step 150/1474 - Loss: 0.3268
# [Epoch 27] Step 200/1474 - Loss: 0.2047
# [Epoch 27] Step 250/1474 - Loss: 0.1113
# [Epoch 27] Step 300/1474 - Loss: 0.3683
# [Epoch 27] Step 350/1474 - Loss: 0.1760
# [Epoch 27] Step 400/1474 - Loss: 0.2896
# [Epoch 27] Step 450/1474 - Loss: 0.3160
# [Epoch 27] Step 500/1474 - Loss: 0.3447
# [Epoch 27] Step 550/1474 - Loss: 0.6443
# [Epoch 27] Step 600/1474 - Loss: 0.4105
# [Epoch 27] Step 650/1474 - Loss: 0.2176
# [Epoch 27] Step 700/1474 - Loss: 0.3106
# [Epoch 27] Step 750/1474 - Loss: 0.2229
# [Epoch 27] Step 800/1474 - Loss: 0.1904
# [Epoch 27] Step 850/1474 - Loss: 0.2654
# [Epoch 27] Step 900/1474 - Loss: 0.3922
# [Epoch 27] Step 950/1474 - Loss: 0.9822
# [Epoch 27] Step 1000/1474 - Loss: 0.1779
# [Epoch 27] Step 1050/1474 - Loss: 0.2185
# [Epoch 27] Step 1100/1474 - Loss: 0.2330
# [Epoch 27] Step 1150/1474 - Loss: 0.2769
# [Epoch 27] Step 1200/1474 - Loss: 0.4797
# [Epoch 27] Step 1250/1474 - Loss: 0.1257
# [Epoch 27] Step 1300/1474 - Loss: 0.2652
# [Epoch 27] Step 1350/1474 - Loss: 0.3265
# [Epoch 27] Step 1400/1474 - Loss: 0.2353
# [Epoch 27] Step 1450/1474 - Loss: 0.2718
# Epoch 027 | TrainLoss(step): 0.2826 | TrainLoss(eval): 0.2248 | ValLoss: 0.8730 | Train mIoU: 0.5625 | Val mIoU: 0.2798 | Val Dice: 0.3969 | Val F1: 0.3969 | Val Acc: 0.7879 | LR: 0.000002
#
# ===== Epoch 28/40 =====
# [Epoch 28] Step 1/1474 - Loss: 0.1134
# [Epoch 28] Step 50/1474 - Loss: 0.3142
# [Epoch 28] Step 100/1474 - Loss: 0.4023
# [Epoch 28] Step 150/1474 - Loss: 0.4128
# [Epoch 28] Step 200/1474 - Loss: 0.2252
# [Epoch 28] Step 250/1474 - Loss: 0.1778
# [Epoch 28] Step 300/1474 - Loss: 0.2681
# [Epoch 28] Step 350/1474 - Loss: 0.1783
# [Epoch 28] Step 400/1474 - Loss: 0.1785
# [Epoch 28] Step 450/1474 - Loss: 0.5166
# [Epoch 28] Step 500/1474 - Loss: 0.2443
# [Epoch 28] Step 550/1474 - Loss: 0.1453
# [Epoch 28] Step 600/1474 - Loss: 0.4077
# [Epoch 28] Step 650/1474 - Loss: 0.5347
# [Epoch 28] Step 700/1474 - Loss: 0.6322
# [Epoch 28] Step 750/1474 - Loss: 0.2165
# [Epoch 28] Step 800/1474 - Loss: 0.1865
# [Epoch 28] Step 850/1474 - Loss: 0.4940
# [Epoch 28] Step 900/1474 - Loss: 0.1977
# [Epoch 28] Step 950/1474 - Loss: 0.6284
# [Epoch 28] Step 1000/1474 - Loss: 0.3970
# [Epoch 28] Step 1050/1474 - Loss: 0.2205
# [Epoch 28] Step 1100/1474 - Loss: 0.2609
# [Epoch 28] Step 1150/1474 - Loss: 0.3909
# [Epoch 28] Step 1200/1474 - Loss: 0.3387
# [Epoch 28] Step 1250/1474 - Loss: 0.1539
# [Epoch 28] Step 1300/1474 - Loss: 0.2662
# [Epoch 28] Step 1350/1474 - Loss: 0.3744
# [Epoch 28] Step 1400/1474 - Loss: 0.4225
# [Epoch 28] Step 1450/1474 - Loss: 0.2012
# Epoch 028 | TrainLoss(step): 0.2783 | TrainLoss(eval): 0.2278 | ValLoss: 0.8408 | Train mIoU: 0.5669 | Val mIoU: 0.2847 | Val Dice: 0.4047 | Val F1: 0.4047 | Val Acc: 0.7855 | LR: 0.000001
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#   -> Checkpoint saved to segformer_checkpoint_epoch_28.pth
#
# ===== Epoch 29/40 =====
# [Epoch 29] Step 1/1474 - Loss: 0.2452
# [Epoch 29] Step 50/1474 - Loss: 0.2094
# [Epoch 29] Step 100/1474 - Loss: 0.1638
# [Epoch 29] Step 150/1474 - Loss: 0.3138
# [Epoch 29] Step 200/1474 - Loss: 0.1691
# [Epoch 29] Step 250/1474 - Loss: 0.3661
# [Epoch 29] Step 300/1474 - Loss: 0.1730
# [Epoch 29] Step 350/1474 - Loss: 0.1678
# [Epoch 29] Step 400/1474 - Loss: 0.8945
# [Epoch 29] Step 450/1474 - Loss: 0.2620
# [Epoch 29] Step 500/1474 - Loss: 0.1542
# [Epoch 29] Step 550/1474 - Loss: 0.2544
# [Epoch 29] Step 600/1474 - Loss: 0.3774
# [Epoch 29] Step 650/1474 - Loss: 0.1380
# [Epoch 29] Step 700/1474 - Loss: 0.3017
# [Epoch 29] Step 750/1474 - Loss: 0.3379
# [Epoch 29] Step 800/1474 - Loss: 0.3082
# [Epoch 29] Step 850/1474 - Loss: 0.3018
# [Epoch 29] Step 900/1474 - Loss: 0.3614
# [Epoch 29] Step 950/1474 - Loss: 0.2307
# [Epoch 29] Step 1000/1474 - Loss: 0.3038
# [Epoch 29] Step 1050/1474 - Loss: 0.3470
# [Epoch 29] Step 1100/1474 - Loss: 0.4299
# [Epoch 29] Step 1150/1474 - Loss: 0.1075
# [Epoch 29] Step 1200/1474 - Loss: 0.4722
# [Epoch 29] Step 1250/1474 - Loss: 0.1132
# [Epoch 29] Step 1300/1474 - Loss: 0.2200
# [Epoch 29] Step 1350/1474 - Loss: 0.1807
# [Epoch 29] Step 1400/1474 - Loss: 0.1743
# [Epoch 29] Step 1450/1474 - Loss: 0.2252
# Epoch 029 | TrainLoss(step): 0.2763 | TrainLoss(eval): 0.2261 | ValLoss: 0.8547 | Train mIoU: 0.5673 | Val mIoU: 0.2836 | Val Dice: 0.4033 | Val F1: 0.4033 | Val Acc: 0.7858 | LR: 0.000001
#
# ===== Epoch 30/40 =====
# [Epoch 30] Step 1/1474 - Loss: 0.1356
# [Epoch 30] Step 50/1474 - Loss: 0.1992
# [Epoch 30] Step 100/1474 - Loss: 0.3256
# [Epoch 30] Step 150/1474 - Loss: 0.3937
# [Epoch 30] Step 200/1474 - Loss: 0.3233
# [Epoch 30] Step 250/1474 - Loss: 0.2752
# [Epoch 30] Step 300/1474 - Loss: 0.2416
# [Epoch 30] Step 350/1474 - Loss: 0.1631
# [Epoch 30] Step 400/1474 - Loss: 0.1237
# [Epoch 30] Step 450/1474 - Loss: 0.5079
# [Epoch 30] Step 500/1474 - Loss: 0.5236
# [Epoch 30] Step 550/1474 - Loss: 0.2859
# [Epoch 30] Step 600/1474 - Loss: 0.3928
# [Epoch 30] Step 650/1474 - Loss: 0.3922
# [Epoch 30] Step 700/1474 - Loss: 0.2285
# [Epoch 30] Step 750/1474 - Loss: 0.3656
# [Epoch 30] Step 800/1474 - Loss: 0.1103
# [Epoch 30] Step 850/1474 - Loss: 0.5077
# [Epoch 30] Step 900/1474 - Loss: 0.2398
# [Epoch 30] Step 950/1474 - Loss: 0.3704
# [Epoch 30] Step 1000/1474 - Loss: 0.3336
# [Epoch 30] Step 1050/1474 - Loss: 0.2845
# [Epoch 30] Step 1100/1474 - Loss: 0.1390
# [Epoch 30] Step 1150/1474 - Loss: 0.2573
# [Epoch 30] Step 1200/1474 - Loss: 0.7266
# [Epoch 30] Step 1250/1474 - Loss: 0.2557
# [Epoch 30] Step 1300/1474 - Loss: 0.1364
# [Epoch 30] Step 1350/1474 - Loss: 0.1995
# [Epoch 30] Step 1400/1474 - Loss: 0.3290
# [Epoch 30] Step 1450/1474 - Loss: 0.1764
# Epoch 030 | TrainLoss(step): 0.2734 | TrainLoss(eval): 0.2240 | ValLoss: 0.8814 | Train mIoU: 0.5667 | Val mIoU: 0.2818 | Val Dice: 0.4004 | Val F1: 0.4004 | Val Acc: 0.7886 | LR: 0.000001
#   -> Checkpoint saved to segformer_checkpoint_epoch_30.pth
#
# ===== Epoch 31/40 =====
# [Epoch 31] Step 1/1474 - Loss: 0.2869
# [Epoch 31] Step 50/1474 - Loss: 0.3223
# [Epoch 31] Step 100/1474 - Loss: 0.5375
# [Epoch 31] Step 150/1474 - Loss: 0.2890
# [Epoch 31] Step 200/1474 - Loss: 0.2159
# [Epoch 31] Step 250/1474 - Loss: 0.3956
# [Epoch 31] Step 300/1474 - Loss: 0.1125
# [Epoch 31] Step 350/1474 - Loss: 0.5172
# [Epoch 31] Step 400/1474 - Loss: 0.2129
# [Epoch 31] Step 450/1474 - Loss: 0.0944
# [Epoch 31] Step 500/1474 - Loss: 0.2998
# [Epoch 31] Step 550/1474 - Loss: 0.1359
# [Epoch 31] Step 600/1474 - Loss: 0.4600
# [Epoch 31] Step 650/1474 - Loss: 0.2435
# [Epoch 31] Step 700/1474 - Loss: 0.3621
# [Epoch 31] Step 750/1474 - Loss: 0.1935
# [Epoch 31] Step 800/1474 - Loss: 0.2410
# [Epoch 31] Step 850/1474 - Loss: 0.2603
# [Epoch 31] Step 900/1474 - Loss: 0.6670
# [Epoch 31] Step 950/1474 - Loss: 0.2048
# [Epoch 31] Step 1000/1474 - Loss: 0.2178
# [Epoch 31] Step 1050/1474 - Loss: 0.1731
# [Epoch 31] Step 1100/1474 - Loss: 0.2104
# [Epoch 31] Step 1150/1474 - Loss: 0.2746
# [Epoch 31] Step 1200/1474 - Loss: 0.2318
# [Epoch 31] Step 1250/1474 - Loss: 0.1317
# [Epoch 31] Step 1300/1474 - Loss: 0.1532
# [Epoch 31] Step 1350/1474 - Loss: 0.3115
# [Epoch 31] Step 1400/1474 - Loss: 0.3533
# [Epoch 31] Step 1450/1474 - Loss: 0.2767
# Epoch 031 | TrainLoss(step): 0.2797 | TrainLoss(eval): 0.2240 | ValLoss: 0.8779 | Train mIoU: 0.5663 | Val mIoU: 0.2830 | Val Dice: 0.4021 | Val F1: 0.4021 | Val Acc: 0.7873 | LR: 0.000001
#
# ===== Epoch 32/40 =====
# [Epoch 32] Step 1/1474 - Loss: 0.3271
# [Epoch 32] Step 50/1474 - Loss: 0.2178
# [Epoch 32] Step 100/1474 - Loss: 0.3618
# [Epoch 32] Step 150/1474 - Loss: 0.2658
# [Epoch 32] Step 200/1474 - Loss: 0.1876
# [Epoch 32] Step 250/1474 - Loss: 0.3853
# [Epoch 32] Step 300/1474 - Loss: 0.2760
# [Epoch 32] Step 350/1474 - Loss: 0.1836
# [Epoch 32] Step 400/1474 - Loss: 0.3622
# [Epoch 32] Step 450/1474 - Loss: 0.2462
# [Epoch 32] Step 500/1474 - Loss: 0.1401
# [Epoch 32] Step 550/1474 - Loss: 0.2707
# [Epoch 32] Step 600/1474 - Loss: 0.2485
# [Epoch 32] Step 650/1474 - Loss: 0.2521
# [Epoch 32] Step 700/1474 - Loss: 0.1677
# [Epoch 32] Step 750/1474 - Loss: 0.3581
# [Epoch 32] Step 800/1474 - Loss: 0.3430
# [Epoch 32] Step 850/1474 - Loss: 0.1895
# [Epoch 32] Step 900/1474 - Loss: 0.4118
# [Epoch 32] Step 950/1474 - Loss: 0.0832
# [Epoch 32] Step 1000/1474 - Loss: 0.3247
# [Epoch 32] Step 1050/1474 - Loss: 0.3431
# [Epoch 32] Step 1100/1474 - Loss: 0.3609
# [Epoch 32] Step 1150/1474 - Loss: 0.2228
# [Epoch 32] Step 1200/1474 - Loss: 0.1988
# [Epoch 32] Step 1250/1474 - Loss: 0.1245
# [Epoch 32] Step 1300/1474 - Loss: 0.2057
# [Epoch 32] Step 1350/1474 - Loss: 0.2019
# [Epoch 32] Step 1400/1474 - Loss: 0.4478
# [Epoch 32] Step 1450/1474 - Loss: 0.3636
# Epoch 032 | TrainLoss(step): 0.2779 | TrainLoss(eval): 0.2227 | ValLoss: 0.8875 | Train mIoU: 0.5643 | Val mIoU: 0.2795 | Val Dice: 0.3967 | Val F1: 0.3967 | Val Acc: 0.7887 | LR: 0.000000
#   -> Checkpoint saved to segformer_checkpoint_epoch_32.pth
#
# ===== Epoch 33/40 =====
# [Epoch 33] Step 1/1474 - Loss: 0.3575
# [Epoch 33] Step 50/1474 - Loss: 0.1090
# [Epoch 33] Step 100/1474 - Loss: 0.2887
# [Epoch 33] Step 150/1474 - Loss: 0.3532
# [Epoch 33] Step 200/1474 - Loss: 0.2677
# [Epoch 33] Step 250/1474 - Loss: 0.5313
# [Epoch 33] Step 300/1474 - Loss: 0.4196
# [Epoch 33] Step 350/1474 - Loss: 0.1179
# [Epoch 33] Step 400/1474 - Loss: 0.3946
# [Epoch 33] Step 450/1474 - Loss: 0.2805
# [Epoch 33] Step 500/1474 - Loss: 0.1665
# [Epoch 33] Step 550/1474 - Loss: 0.1432
# [Epoch 33] Step 600/1474 - Loss: 0.8710
# [Epoch 33] Step 650/1474 - Loss: 0.4093
# [Epoch 33] Step 700/1474 - Loss: 0.2036
# [Epoch 33] Step 750/1474 - Loss: 0.3866
# [Epoch 33] Step 800/1474 - Loss: 0.2080
# [Epoch 33] Step 850/1474 - Loss: 0.2160
# [Epoch 33] Step 900/1474 - Loss: 0.1270
# [Epoch 33] Step 950/1474 - Loss: 0.5722
# [Epoch 33] Step 1000/1474 - Loss: 0.2447
# [Epoch 33] Step 1050/1474 - Loss: 0.1267
# [Epoch 33] Step 1100/1474 - Loss: 0.3979
# [Epoch 33] Step 1150/1474 - Loss: 0.1440
# [Epoch 33] Step 1200/1474 - Loss: 0.3643
# [Epoch 33] Step 1250/1474 - Loss: 0.3782
# [Epoch 33] Step 1300/1474 - Loss: 0.2436
# [Epoch 33] Step 1350/1474 - Loss: 0.2969
# [Epoch 33] Step 1400/1474 - Loss: 0.5432
# [Epoch 33] Step 1450/1474 - Loss: 0.2652
# Epoch 033 | TrainLoss(step): 0.2765 | TrainLoss(eval): 0.2238 | ValLoss: 0.8615 | Train mIoU: 0.5695 | Val mIoU: 0.2836 | Val Dice: 0.4034 | Val F1: 0.4034 | Val Acc: 0.7861 | LR: 0.000000
#
# ===== Epoch 34/40 =====
# [Epoch 34] Step 1/1474 - Loss: 0.2588
# [Epoch 34] Step 50/1474 - Loss: 0.1712
# [Epoch 34] Step 100/1474 - Loss: 0.2759
# [Epoch 34] Step 150/1474 - Loss: 0.3094
# [Epoch 34] Step 200/1474 - Loss: 0.3523
# [Epoch 34] Step 250/1474 - Loss: 0.1387
# [Epoch 34] Step 300/1474 - Loss: 0.3885
# [Epoch 34] Step 350/1474 - Loss: 0.5262
# [Epoch 34] Step 400/1474 - Loss: 0.3385
# [Epoch 34] Step 450/1474 - Loss: 0.1785
# [Epoch 34] Step 500/1474 - Loss: 0.2781
# [Epoch 34] Step 550/1474 - Loss: 0.2068
# [Epoch 34] Step 600/1474 - Loss: 0.3688
# [Epoch 34] Step 650/1474 - Loss: 0.4425
# [Epoch 34] Step 700/1474 - Loss: 0.2484
# [Epoch 34] Step 750/1474 - Loss: 0.1532
# [Epoch 34] Step 800/1474 - Loss: 0.2554
# [Epoch 34] Step 850/1474 - Loss: 0.4681
# [Epoch 34] Step 900/1474 - Loss: 0.3127
# [Epoch 34] Step 950/1474 - Loss: 0.1431
# [Epoch 34] Step 1000/1474 - Loss: 0.2909
# [Epoch 34] Step 1050/1474 - Loss: 0.4603
# [Epoch 34] Step 1100/1474 - Loss: 0.1283
# [Epoch 34] Step 1150/1474 - Loss: 0.3349
# [Epoch 34] Step 1200/1474 - Loss: 0.3330
# [Epoch 34] Step 1250/1474 - Loss: 0.2980
# [Epoch 34] Step 1300/1474 - Loss: 0.1139
# [Epoch 34] Step 1350/1474 - Loss: 0.2018
# [Epoch 34] Step 1400/1474 - Loss: 0.2377
# [Epoch 34] Step 1450/1474 - Loss: 0.2490
# Epoch 034 | TrainLoss(step): 0.2770 | TrainLoss(eval): 0.2234 | ValLoss: 0.8980 | Train mIoU: 0.5673 | Val mIoU: 0.2805 | Val Dice: 0.3984 | Val F1: 0.3984 | Val Acc: 0.7873 | LR: 0.000000
#   -> Checkpoint saved to segformer_checkpoint_epoch_34.pth
#
# ===== Epoch 35/40 =====
# [Epoch 35] Step 1/1474 - Loss: 0.6072
# [Epoch 35] Step 50/1474 - Loss: 0.3237
# [Epoch 35] Step 100/1474 - Loss: 0.1862
# [Epoch 35] Step 150/1474 - Loss: 0.1708
# [Epoch 35] Step 200/1474 - Loss: 0.1613
# [Epoch 35] Step 250/1474 - Loss: 0.1662
# [Epoch 35] Step 300/1474 - Loss: 0.1487
# [Epoch 35] Step 350/1474 - Loss: 0.2801
# [Epoch 35] Step 400/1474 - Loss: 0.1953
# [Epoch 35] Step 450/1474 - Loss: 0.1509
# [Epoch 35] Step 500/1474 - Loss: 0.1234
# [Epoch 35] Step 550/1474 - Loss: 0.4820
# [Epoch 35] Step 600/1474 - Loss: 0.2005
# [Epoch 35] Step 650/1474 - Loss: 0.2293
# [Epoch 35] Step 700/1474 - Loss: 0.1310
# [Epoch 35] Step 750/1474 - Loss: 0.3357
# [Epoch 35] Step 800/1474 - Loss: 0.1161
# [Epoch 35] Step 850/1474 - Loss: 0.2470
# [Epoch 35] Step 900/1474 - Loss: 0.2924
# [Epoch 35] Step 950/1474 - Loss: 0.5262
# [Epoch 35] Step 1000/1474 - Loss: 0.2844
# [Epoch 35] Step 1050/1474 - Loss: 0.2334
# [Epoch 35] Step 1100/1474 - Loss: 0.2439
# [Epoch 35] Step 1150/1474 - Loss: 0.2748
# [Epoch 35] Step 1200/1474 - Loss: 0.5365
# [Epoch 35] Step 1250/1474 - Loss: 0.2370
# [Epoch 35] Step 1300/1474 - Loss: 0.2787
# [Epoch 35] Step 1350/1474 - Loss: 0.2335
# [Epoch 35] Step 1400/1474 - Loss: 0.4972
# [Epoch 35] Step 1450/1474 - Loss: 0.2708
# Epoch 035 | TrainLoss(step): 0.2754 | TrainLoss(eval): 0.2229 | ValLoss: 0.8712 | Train mIoU: 0.5676 | Val mIoU: 0.2806 | Val Dice: 0.3986 | Val F1: 0.3986 | Val Acc: 0.7879 | LR: 0.000000
#
# ===== Epoch 36/40 =====
# [Epoch 36] Step 1/1474 - Loss: 0.2950
# [Epoch 36] Step 50/1474 - Loss: 0.3182
# [Epoch 36] Step 100/1474 - Loss: 0.4395
# [Epoch 36] Step 150/1474 - Loss: 0.1539
# [Epoch 36] Step 200/1474 - Loss: 0.5253
# [Epoch 36] Step 250/1474 - Loss: 0.1674
# [Epoch 36] Step 300/1474 - Loss: 0.5209
# [Epoch 36] Step 350/1474 - Loss: 0.0808
# [Epoch 36] Step 400/1474 - Loss: 0.1441
# [Epoch 36] Step 450/1474 - Loss: 0.2906
# [Epoch 36] Step 500/1474 - Loss: 0.2258
# [Epoch 36] Step 550/1474 - Loss: 0.3511
# [Epoch 36] Step 600/1474 - Loss: 0.1073
# [Epoch 36] Step 650/1474 - Loss: 0.4980
# [Epoch 36] Step 700/1474 - Loss: 0.1856
# [Epoch 36] Step 750/1474 - Loss: 0.2758
# [Epoch 36] Step 800/1474 - Loss: 0.1458
# [Epoch 36] Step 850/1474 - Loss: 0.2025
# [Epoch 36] Step 900/1474 - Loss: 0.2097
# [Epoch 36] Step 950/1474 - Loss: 0.3061
# [Epoch 36] Step 1000/1474 - Loss: 0.3488
# [Epoch 36] Step 1050/1474 - Loss: 0.4464
# [Epoch 36] Step 1100/1474 - Loss: 0.2362
# [Epoch 36] Step 1150/1474 - Loss: 0.2869
# [Epoch 36] Step 1200/1474 - Loss: 0.1822
# [Epoch 36] Step 1250/1474 - Loss: 0.2218
# [Epoch 36] Step 1300/1474 - Loss: 0.2911
# [Epoch 36] Step 1350/1474 - Loss: 0.4708
# [Epoch 36] Step 1400/1474 - Loss: 0.1472
# [Epoch 36] Step 1450/1474 - Loss: 0.0915
# Epoch 036 | TrainLoss(step): 0.2734 | TrainLoss(eval): 0.2222 | ValLoss: 0.8659 | Train mIoU: 0.5695 | Val mIoU: 0.2828 | Val Dice: 0.4017 | Val F1: 0.4017 | Val Acc: 0.7872 | LR: 0.000000
#   -> Checkpoint saved to segformer_checkpoint_epoch_36.pth
#
# ===== Epoch 37/40 =====
# [Epoch 37] Step 1/1474 - Loss: 0.3898
# [Epoch 37] Step 50/1474 - Loss: 0.2514
# [Epoch 37] Step 100/1474 - Loss: 0.1697
# [Epoch 37] Step 150/1474 - Loss: 0.0796
# [Epoch 37] Step 200/1474 - Loss: 0.5649
# [Epoch 37] Step 250/1474 - Loss: 0.2211
# [Epoch 37] Step 300/1474 - Loss: 0.1795
# [Epoch 37] Step 350/1474 - Loss: 0.1986
# [Epoch 37] Step 400/1474 - Loss: 0.4755
# [Epoch 37] Step 450/1474 - Loss: 0.2800
# [Epoch 37] Step 500/1474 - Loss: 0.2661
# [Epoch 37] Step 550/1474 - Loss: 0.2648
# [Epoch 37] Step 600/1474 - Loss: 0.2134
# [Epoch 37] Step 650/1474 - Loss: 0.1646
# [Epoch 37] Step 700/1474 - Loss: 0.3478
# [Epoch 37] Step 750/1474 - Loss: 0.2211
# [Epoch 37] Step 800/1474 - Loss: 0.1960
# [Epoch 37] Step 850/1474 - Loss: 0.1218
# [Epoch 37] Step 900/1474 - Loss: 0.1641
# [Epoch 37] Step 950/1474 - Loss: 0.1594
# [Epoch 37] Step 1000/1474 - Loss: 0.3967
# [Epoch 37] Step 1050/1474 - Loss: 0.3584
# [Epoch 37] Step 1100/1474 - Loss: 0.1229
# [Epoch 37] Step 1150/1474 - Loss: 0.2774
# [Epoch 37] Step 1200/1474 - Loss: 0.3438
# [Epoch 37] Step 1250/1474 - Loss: 0.2435
# [Epoch 37] Step 1300/1474 - Loss: 0.3570
# [Epoch 37] Step 1350/1474 - Loss: 0.3266
# [Epoch 37] Step 1400/1474 - Loss: 0.1376
# [Epoch 37] Step 1450/1474 - Loss: 0.1607
# Epoch 037 | TrainLoss(step): 0.2735 | TrainLoss(eval): 0.2238 | ValLoss: 0.8488 | Train mIoU: 0.5711 | Val mIoU: 0.2842 | Val Dice: 0.4044 | Val F1: 0.4044 | Val Acc: 0.7852 | LR: 0.000000
#
# ===== Epoch 38/40 =====
# [Epoch 38] Step 1/1474 - Loss: 0.2955
# [Epoch 38] Step 50/1474 - Loss: 0.2620
# [Epoch 38] Step 100/1474 - Loss: 0.2504
# [Epoch 38] Step 150/1474 - Loss: 0.3239
# [Epoch 38] Step 200/1474 - Loss: 0.1803
# [Epoch 38] Step 250/1474 - Loss: 0.2953
# [Epoch 38] Step 300/1474 - Loss: 0.2535
# [Epoch 38] Step 350/1474 - Loss: 0.1943
# [Epoch 38] Step 400/1474 - Loss: 0.4371
# [Epoch 38] Step 450/1474 - Loss: 0.1493
# [Epoch 38] Step 500/1474 - Loss: 0.5697
# [Epoch 38] Step 550/1474 - Loss: 0.3227
# [Epoch 38] Step 600/1474 - Loss: 0.2537
# [Epoch 38] Step 650/1474 - Loss: 0.1923
# [Epoch 38] Step 700/1474 - Loss: 0.1438
# [Epoch 38] Step 750/1474 - Loss: 0.1663
# [Epoch 38] Step 800/1474 - Loss: 0.1471
# [Epoch 38] Step 850/1474 - Loss: 0.1687
# [Epoch 38] Step 900/1474 - Loss: 0.2165
# [Epoch 38] Step 950/1474 - Loss: 0.5317
# [Epoch 38] Step 1000/1474 - Loss: 0.3039
# [Epoch 38] Step 1050/1474 - Loss: 0.2602
# [Epoch 38] Step 1100/1474 - Loss: 0.1329
# [Epoch 38] Step 1150/1474 - Loss: 0.2277
# [Epoch 38] Step 1200/1474 - Loss: 0.2037
# [Epoch 38] Step 1250/1474 - Loss: 0.1310
# [Epoch 38] Step 1300/1474 - Loss: 0.4026
# [Epoch 38] Step 1350/1474 - Loss: 0.2671
# [Epoch 38] Step 1400/1474 - Loss: 0.2409
# [Epoch 38] Step 1450/1474 - Loss: 0.1810
# Epoch 038 | TrainLoss(step): 0.2752 | TrainLoss(eval): 0.2228 | ValLoss: 0.8753 | Train mIoU: 0.5679 | Val mIoU: 0.2826 | Val Dice: 0.4015 | Val F1: 0.4015 | Val Acc: 0.7856 | LR: 0.000000
#   -> Checkpoint saved to segformer_checkpoint_epoch_38.pth
#
# ===== Epoch 39/40 =====
# [Epoch 39] Step 1/1474 - Loss: 0.2184
# [Epoch 39] Step 50/1474 - Loss: 0.3886
# [Epoch 39] Step 100/1474 - Loss: 0.1262
# [Epoch 39] Step 150/1474 - Loss: 0.2016
# [Epoch 39] Step 200/1474 - Loss: 0.4036
# [Epoch 39] Step 250/1474 - Loss: 0.1134
# [Epoch 39] Step 300/1474 - Loss: 0.1968
# [Epoch 39] Step 350/1474 - Loss: 0.1510
# [Epoch 39] Step 400/1474 - Loss: 0.2742
# [Epoch 39] Step 450/1474 - Loss: 0.2406
# [Epoch 39] Step 500/1474 - Loss: 0.0957
# [Epoch 39] Step 550/1474 - Loss: 0.4179
# [Epoch 39] Step 600/1474 - Loss: 0.5374
# [Epoch 39] Step 650/1474 - Loss: 0.1971
# [Epoch 39] Step 700/1474 - Loss: 0.1618
# [Epoch 39] Step 750/1474 - Loss: 0.1369
# [Epoch 39] Step 800/1474 - Loss: 0.0794
# [Epoch 39] Step 850/1474 - Loss: 0.1639
# [Epoch 39] Step 900/1474 - Loss: 0.1928
# [Epoch 39] Step 950/1474 - Loss: 0.1998
# [Epoch 39] Step 1000/1474 - Loss: 0.1599
# [Epoch 39] Step 1050/1474 - Loss: 0.1975
# [Epoch 39] Step 1100/1474 - Loss: 0.4102
# [Epoch 39] Step 1150/1474 - Loss: 0.1590
# [Epoch 39] Step 1200/1474 - Loss: 0.1013
# [Epoch 39] Step 1250/1474 - Loss: 0.1331
# [Epoch 39] Step 1300/1474 - Loss: 0.2570
# [Epoch 39] Step 1350/1474 - Loss: 0.2401
# [Epoch 39] Step 1400/1474 - Loss: 0.1852
# [Epoch 39] Step 1450/1474 - Loss: 0.3025
# Epoch 039 | TrainLoss(step): 0.2754 | TrainLoss(eval): 0.2215 | ValLoss: 0.8687 | Train mIoU: 0.5708 | Val mIoU: 0.2830 | Val Dice: 0.4022 | Val F1: 0.4022 | Val Acc: 0.7867 | LR: 0.000000
#
# ===== Epoch 40/40 =====
# [Epoch 40] Step 1/1474 - Loss: 0.2509
# [Epoch 40] Step 50/1474 - Loss: 0.3288
# [Epoch 40] Step 100/1474 - Loss: 0.2037
# [Epoch 40] Step 150/1474 - Loss: 0.3319
# [Epoch 40] Step 200/1474 - Loss: 0.2811
# [Epoch 40] Step 250/1474 - Loss: 0.3335
# [Epoch 40] Step 300/1474 - Loss: 0.2746
# [Epoch 40] Step 350/1474 - Loss: 0.4509
# [Epoch 40] Step 400/1474 - Loss: 0.1099
# [Epoch 40] Step 450/1474 - Loss: 0.1996
# [Epoch 40] Step 500/1474 - Loss: 0.1807
# [Epoch 40] Step 550/1474 - Loss: 0.3882
# [Epoch 40] Step 600/1474 - Loss: 0.1671
# [Epoch 40] Step 650/1474 - Loss: 0.1612
# [Epoch 40] Step 700/1474 - Loss: 0.2700
# [Epoch 40] Step 750/1474 - Loss: 0.2538
# [Epoch 40] Step 800/1474 - Loss: 0.2328
# [Epoch 40] Step 850/1474 - Loss: 0.1347
# [Epoch 40] Step 900/1474 - Loss: 0.3166
# [Epoch 40] Step 950/1474 - Loss: 0.1805
# [Epoch 40] Step 1000/1474 - Loss: 0.2994
# [Epoch 40] Step 1050/1474 - Loss: 0.2040
# [Epoch 40] Step 1100/1474 - Loss: 0.3676
# [Epoch 40] Step 1150/1474 - Loss: 0.1670
# [Epoch 40] Step 1200/1474 - Loss: 0.1306
# [Epoch 40] Step 1250/1474 - Loss: 0.5482
# [Epoch 40] Step 1300/1474 - Loss: 0.1494
# [Epoch 40] Step 1350/1474 - Loss: 0.2006
# [Epoch 40] Step 1400/1474 - Loss: 0.2085
# [Epoch 40] Step 1450/1474 - Loss: 0.1701
# Epoch 040 | TrainLoss(step): 0.2756 | TrainLoss(eval): 0.2233 | ValLoss: 0.8676 | Train mIoU: 0.5728 | Val mIoU: 0.2851 | Val Dice: 0.4056 | Val F1: 0.4056 | Val Acc: 0.7851 | LR: 0.000000
#   -> New best mIoU; weights saved to segformer_best_miou.pth
#   -> Checkpoint saved to segformer_checkpoint_epoch_40.pth
#
# Training complete. Best mIoU: 0.2850596606731415
# Saved metrics to: /kaggle/working/segformer_results.json
# /kaggle/working/segformer_results.json
